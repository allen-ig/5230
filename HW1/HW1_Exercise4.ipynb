# %% [markdown]
#  # Excercise 4

# %% [markdown]
# ## Problem 1

# %% [markdown]
# After parsing data from 'q2_dataset.txt' and 'q4_dataset.txt', I notice that data from the latter somehow makes more sense. First of all, all the venue names that differ by year are aggregated to one single venue. This change may eventually make the total number of venues smaller, which is more accurate. Also, there is one additional line starts with '#!' for each publication paper which I infer to be comments or notices.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ### Part a

# %%
import os
import pyspark
from pyspark import SparkContext
from pyspark.mllib.fpm import FPGrowth
import re
SparkContext.setSystemProperty('spark.executor.memory','3g')
conf=pyspark.SparkConf().setAppName('test').setMaster('local[1]')
sc=pyspark.SparkContext(conf=conf)
rdd=sc.textFile('q4_dataset.txt')

# %%
rdd_new=rdd.filter(lambda x: re.match(r'^#@(.*)', x)).map(lambda x: re.match(r'^#@(.*)', x).group(1))

# %%
rdd_res = rdd_new.map(lambda line: line.strip().split(',')).map(lambda x: list(set(x)))

# %%
model1 = FPGrowth.train(rdd_res, 1e-4, 2)

# %%
model1.freqItemsets().collect()
# Out:
# [FreqItemset(items=['Vijay Kumar'], freq=349),
#  FreqItemset(items=['David Maier'], freq=227),
#  FreqItemset(items=['Ning Zhong'], freq=303),
#  FreqItemset(items=['Umeshwar Dayal'], freq=225),
#  FreqItemset(items=['Henri Prade'], freq=391),
#  FreqItemset(items=['Daniel A. Keim'], freq=247),
#  FreqItemset(items=['Albert Y. Zomaya'], freq=309),
#  FreqItemset(items=['Dennis Sylvester'], freq=232),
#  FreqItemset(items=['Hao Zhang'], freq=315),
#  FreqItemset(items=['Xin Liu'], freq=290),
#  FreqItemset(items=['Diane Crawford'], freq=250),
#  FreqItemset(items=['Oscar C. Au'], freq=236),
#  FreqItemset(items=['Herbert Edelsbrunner'], freq=239),
#  FreqItemset(items=['Yue Wang'], freq=327),
#  FreqItemset(items=['K. J. Ray Liu'], freq=374),
#  FreqItemset(items=['Wayne Wolf'], freq=243),
#  FreqItemset(items=['Haizhou Li'], freq=230),
#  FreqItemset(items=['Leonidas J. Guibas'], freq=363),
#  FreqItemset(items=['Joel H. Saltz'], freq=253),
#  FreqItemset(items=['José Meseguer'], freq=295),
#  FreqItemset(items=['Qiang Wang'], freq=248),
#  FreqItemset(items=['Yan Wang'], freq=379),
#  FreqItemset(items=['Marianne Winslett'], freq=240),
#  FreqItemset(items=['Rama Chellappa'], freq=368),
#  FreqItemset(items=['Alberto Del Bimbo'], freq=311),
#  FreqItemset(items=['Andrzej Cichocki'], freq=234),
#  FreqItemset(items=['Helmut Krcmar'], freq=321),
#  FreqItemset(items=['Sung-Bae Cho'], freq=250),
#  FreqItemset(items=['Erik D. Demaine'], freq=401),
#  FreqItemset(items=['B. Sundar Rajan'], freq=237),
#  FreqItemset(items=['Laurence Tianruo Yang'], freq=334),
#  FreqItemset(items=['Rui Zhang'], freq=466),
#  FreqItemset(items=['Alex Pentland'], freq=261),
#  FreqItemset(items=['Jin Li'], freq=254),
#  FreqItemset(items=['Li Li'], freq=507),
#  FreqItemset(items=['Xiaoou Tang'], freq=258),
#  FreqItemset(items=['Bart Preneel'], freq=422),
#  FreqItemset(items=["Joseph O'Rourke"], freq=245),
#  FreqItemset(items=['Jun Yang'], freq=352),
#  FreqItemset(items=['Bernd Girod'], freq=264),
#  FreqItemset(items=['Wei Sun'], freq=255),
#  FreqItemset(items=['Joseph Y. Halpern'], freq=433),
#  FreqItemset(items=['Stephan Olariu'], freq=359),
#  FreqItemset(items=['Carlos A. Coello Coello'], freq=220),
#  FreqItemset(items=['Hsiao-Hwa Chen'], freq=259),
#  FreqItemset(items=['Wen Gao'], freq=707),
#  FreqItemset(items=['Alberto L. Sangiovanni-Vincentelli'], freq=481),
#  FreqItemset(items=['Amir Pnueli'], freq=262),
#  FreqItemset(items=['Fan Zhang'], freq=249),
#  FreqItemset(items=['Sudhakar M. Reddy'], freq=549),
#  FreqItemset(items=['Edward A. Fox'], freq=275),
#  FreqItemset(items=['Lei Guo'], freq=267),
#  FreqItemset(items=['Hector Garcia-Molina'], freq=411),
#  FreqItemset(items=['Bo Liu'], freq=281),
#  FreqItemset(items=['Andrzej Skowron'], freq=215),
#  FreqItemset(items=['Yong Shi'], freq=246),
#  FreqItemset(items=['Ying Li'], freq=372),
#  FreqItemset(items=['Xiaodong Zhang'], freq=252),
#  FreqItemset(items=['Donald F. Towsley'], freq=386),
#  FreqItemset(items=['Roger Wattenhofer'], freq=217),
#  FreqItemset(items=['Zhongzhi Shi'], freq=272),
#  FreqItemset(items=['Jian Li'], freq=416),
#  FreqItemset(items=['Edmund M. Clarke'], freq=256),
#  FreqItemset(items=['Moshe Y. Vardi'], freq=447),
#  FreqItemset(items=['Ping Wang'], freq=287),
#  FreqItemset(items=['Min Li'], freq=276),
#  FreqItemset(items=['Feng Liu'], freq=260),
#  FreqItemset(items=['Grzegorz Rozenberg'], freq=490),
#  FreqItemset(items=['Rüdiger Dillmann'], freq=263),
#  FreqItemset(items=['Mark H. Overmars'], freq=224),
#  FreqItemset(items=['Christos Bouras'], freq=227),
#  FreqItemset(items=['Hamid R. Arabnia'], freq=293),
#  FreqItemset(items=['Yang Xu'], freq=221),
#  FreqItemset(items=['Yong Yu'], freq=299),
#  FreqItemset(items=['Ping Li'], freq=270),
#  FreqItemset(items=['Xin Li'], freq=571),
#  FreqItemset(items=['Wei Zhang'], freq=856),
#  FreqItemset(items=['Choong Seon Hong'], freq=229),
#  FreqItemset(items=['Lakhmi C. Jain'], freq=273),
#  FreqItemset(items=['P. Sadayappan'], freq=215),
#  FreqItemset(items=['Wei Huang'], freq=218),
#  FreqItemset(items=['Ramesh Jain'], freq=282),
#  FreqItemset(items=['Filip De Turck'], freq=232),
#  FreqItemset(items=['Hong Chen'], freq=227),
#  FreqItemset(items=['Gang Chen'], freq=315),
#  FreqItemset(items=['Feng Bao'], freq=229),
#  FreqItemset(items=['Xiaolin Wu'], freq=219),
#  FreqItemset(items=['Masahiro Fujita'], freq=239),
#  FreqItemset(items=['Wei-Ying Ma'], freq=289),
#  FreqItemset(items=['Yunhao Liu'], freq=216),
#  FreqItemset(items=['S. Muthukrishnan'], freq=277),
#  FreqItemset(items=['Sachin S. Sapatnekar'], freq=236),
#  FreqItemset(items=['Toshio Fukuda'], freq=326),
#  FreqItemset(items=['Marek Karpinski'], freq=283),
#  FreqItemset(items=['Boi Faltings'], freq=222),
#  FreqItemset(items=['Abhijit Chatterjee'], freq=270),
#  FreqItemset(items=['Jun Zhang'], freq=652),
#  FreqItemset(items=['Christian S. Jensen'], freq=302),
#  FreqItemset(items=['Jianping Wu'], freq=224),
#  FreqItemset(items=['Hong Yan'], freq=309),
#  FreqItemset(items=['Wei Wu'], freq=295),
#  FreqItemset(items=['Tieniu Tan'], freq=274),
#  FreqItemset(items=['Bernard De Baets'], freq=239),
#  FreqItemset(items=['Wei Zhao'], freq=352),
#  FreqItemset(items=['Lane A. Hemaspaandra'], freq=236),
#  FreqItemset(items=['Raouf Boutaba'], freq=226),
#  FreqItemset(items=['Min Chen'], freq=290),
#  FreqItemset(items=['Kian-Lee Tan'], freq=297),
#  FreqItemset(items=['Massoud Pedram'], freq=366),
#  FreqItemset(items=['Liang-Gee Chen'], freq=248),
#  FreqItemset(items=['Yan Liu'], freq=376),
#  FreqItemset(items=['Kee-Young Yoo'], freq=228),
#  FreqItemset(items=['Yang Li'], freq=304),
#  FreqItemset(items=['Selim G. Akl'], freq=230),
#  FreqItemset(items=['Carlos José Pereira de Lucena'], freq=250),
#  FreqItemset(items=['Alok N. Choudhary'], freq=333),
#  FreqItemset(items=['Carole A. Goble'], freq=233),
#  FreqItemset(items=['Xiang Li'], freq=319),
#  FreqItemset(items=['Ling Wang'], freq=223),
#  FreqItemset(items=['Ernesto Damiani'], freq=244),
#  FreqItemset(items=['Ugo Montanari'], freq=310),
#  FreqItemset(items=['Michael R. Lyu'], freq=285),
#  FreqItemset(items=['Katsumi Tanaka'], freq=323),
#  FreqItemset(items=['Noga Alon'], freq=481),
#  FreqItemset(items=['Oded Goldreich'], freq=370),
#  FreqItemset(items=['Xindong Wu'], freq=249),
#  FreqItemset(items=['Franco Zambonelli'], freq=240),
#  FreqItemset(items=['Jian Wang'], freq=358),
#  FreqItemset(items=['Klara Nahrstedt'], freq=306),
#  FreqItemset(items=['Yi Liu'], freq=251),
#  FreqItemset(items=['Yong Zhang'], freq=385),
#  FreqItemset(items=['Gerhard Rigoll'], freq=245),
#  FreqItemset(items=['Bin Wang'], freq=409),
#  FreqItemset(items=['Ian Horrocks'], freq=231),
#  FreqItemset(items=['Niraj K. Jha'], freq=312),
#  FreqItemset(items=['T. Aaron Gulliver'], freq=235),
#  FreqItemset(items=['Floriana Esposito'], freq=254),
#  FreqItemset(items=['Sushil Jajodia'], freq=430),
#  FreqItemset(items=['Shuicheng Yan'], freq=258),
#  FreqItemset(items=['Guillermo Sapiro'], freq=237),
#  FreqItemset(items=['Hartmut Ehrig'], freq=337),
#  FreqItemset(items=['Karl Aberer'], freq=262),
#  FreqItemset(items=['Mihaela van der Schaar'], freq=250),
#  FreqItemset(items=['Yu Wang'], freq=444),
#  FreqItemset(items=['Mohamed Ould-Khaoua'], freq=253),
#  FreqItemset(items=['Yan Li'], freq=389),
#  FreqItemset(items=['Elizabeth Chang'], freq=276),
#  FreqItemset(items=['Andrew Zisserman'], freq=263),
#  FreqItemset(items=['Tao Li'], freq=490),
#  FreqItemset(items=['Alan F. Smeaton'], freq=256),
#  FreqItemset(items=['Yong Liu'], freq=361),
#  FreqItemset(items=['Stefano Ceri'], freq=269),
#  FreqItemset(items=['Wei Li'], freq=805),
#  FreqItemset(items=['Pierangela Samarati'], freq=215),
#  FreqItemset(items=['Miodrag Potkonjak'], freq=259),
#  FreqItemset(items=['Thomas A. Henzinger'], freq=348),
#  FreqItemset(items=['Xian-Sheng Hua'], freq=242),
#  FreqItemset(items=['Wei Chen'], freq=564),
#  FreqItemset(items=['Mario Gerla'], freq=413),
#  FreqItemset(items=['Michael Unser'], freq=246),
#  FreqItemset(items=['Ying Liu'], freq=373),
#  FreqItemset(items=['Peter J. Stuckey'], freq=272),
#  FreqItemset(items=['Yang Liu'], freq=641),
#  FreqItemset(items=['Robert L. Glass'], freq=273),
#  FreqItemset(items=['Prosenjit Bose'], freq=264),
#  FreqItemset(items=['Christoph Meinel'], freq=399),
#  FreqItemset(items=['Hyunseung Choo'], freq=254),
#  FreqItemset(items=['Ying-Chang Liang'], freq=216),
#  FreqItemset(items=['Chintha Tellambura'], freq=219),
#  FreqItemset(items=['C. C. Jay Kuo'], freq=277),
#  FreqItemset(items=['Norman C. Beaulieu'], freq=421),
#  FreqItemset(items=['Sebastian Thrun'], freq=257),
#  FreqItemset(items=['Jie Yang'], freq=460),
#  FreqItemset(items=['Insup Lee'], freq=222),
#  FreqItemset(items=['Bin Zhang'], freq=283),
#  FreqItemset(items=['Ming-Syan Chen'], freq=288),
#  FreqItemset(items=['Avi Wigderson'], freq=270),
#  FreqItemset(items=['Lothar Thiele'], freq=261),
#  FreqItemset(items=['Sajal K. Das'], freq=504),
#  FreqItemset(items=['Bernhard Schölkopf'], freq=224),
#  FreqItemset(items=['Khaled Ben Letaief'], freq=294),
#  FreqItemset(items=['Lei Wang'], freq=690),
#  FreqItemset(items=['Peter Willett'], freq=230),
#  FreqItemset(items=['Shusaku Tsumoto'], freq=275),
#  FreqItemset(items=['Tuomas Sandholm'], freq=233),
#  FreqItemset(items=['Oscar H. Ibarra'], freq=317),
#  FreqItemset(items=['Václav Snásel'], freq=267),
#  FreqItemset(items=['Daniela Rus'], freq=227),
#  FreqItemset(items=['Shlomo Shamai'], freq=304),
#  FreqItemset(items=['Douglas C. Schmidt'], freq=279),
#  FreqItemset(items=['Saharon Shelah'], freq=272),
#  FreqItemset(items=['Subhash Suri'], freq=215),
#  FreqItemset(items=['Guanrong Chen'], freq=310),
#  FreqItemset(items=['Mark Harman'], freq=222),
#  FreqItemset(items=['David Taniar'], freq=285),
#  FreqItemset(items=['Toby Walsh'], freq=290),
#  FreqItemset(items=['David Harel'], freq=217),
#  FreqItemset(items=['Hui Zhang'], freq=529),
#  FreqItemset(items=['Dong Wang'], freq=225),
#  FreqItemset(items=['Gene Tsudik'], freq=220),
#  FreqItemset(items=['Jun Sun'], freq=296),
#  FreqItemset(items=['Dinesh Manocha'], freq=281),
#  FreqItemset(items=['Divyakant Agrawal'], freq=322),
#  FreqItemset(items=['Hussein T. Mouftah'], freq=237),
#  FreqItemset(items=['Ian T. Foster'], freq=336),
#  FreqItemset(items=['Jörg Becker'], freq=221),
#  FreqItemset(items=['Kishor S. Trivedi'], freq=298),
#  FreqItemset(items=['Guang-Zhong Yang'], freq=223),
#  FreqItemset(items=['Minglu Li'], freq=286),
#  FreqItemset(items=['Gunter Saake'], freq=240),
#  FreqItemset(items=['Feng Wu'], freq=245),
#  FreqItemset(items=['Christos H. Papadimitriou'], freq=355),
#  FreqItemset(items=['Kalyanmoy Deb'], freq=228),
#  FreqItemset(items=['Elke A. Rundensteiner'], freq=305),
#  FreqItemset(items=['Bernd Freisleben'], freq=226),
#  FreqItemset(items=['Bin Liu'], freq=369),
#  FreqItemset(items=['Hong Jiang'], freq=235),
#  FreqItemset(items=['Peng Zhang'], freq=292),
#  FreqItemset(items=['Patrick Valduriez'], freq=230),
#  FreqItemset(items=['Azriel Rosenfeld'], freq=312),
#  FreqItemset(items=['Edward R. Dougherty'], freq=218),
#  FreqItemset(items=['Bo Li'], freq=440),
#  FreqItemset(items=['Geoffrey Fox'], freq=314),
#  FreqItemset(items=['Thomas Eiter'], freq=301),
#  FreqItemset(items=['John Mylopoulos'], freq=387),
#  FreqItemset(items=['Roland Siegwart'], freq=238),
#  FreqItemset(items=['Kurt Mehlhorn'], freq=326),
#  FreqItemset(items=['Marc Moonen'], freq=232),
#  FreqItemset(items=['Yannis Manolopoulos'], freq=255),
#  FreqItemset(items=['Hong Zhang'], freq=344),
#  FreqItemset(items=['Robert W. Heath Jr.'], freq=242),
#  FreqItemset(items=['Joseph S. B. Mitchell'], freq=235),
#  FreqItemset(items=['Hans-Peter Kriegel'], freq=360),
#  FreqItemset(items=['Kannan Ramchandran'], freq=227),
#  FreqItemset(items=['Erol Gelenbe'], freq=246),
#  FreqItemset(items=['Luc J. Van Gool'], freq=372),
#  FreqItemset(items=['W. Bruce Croft'], freq=249),
#  FreqItemset(items=['Martin Vetterli'], freq=229),
#  FreqItemset(items=['Ronald R. Yager'], freq=307),
#  FreqItemset(items=['Hossam S. Hassanein'], freq=252),
#  FreqItemset(items=['Moti Yung'], freq=411),
#  FreqItemset(items=['Robert Endre Tarjan'], freq=270),
#  FreqItemset(items=['Andrzej Pelc'], freq=253),
#  FreqItemset(items=['Jiannong Cao'], freq=397),
#  FreqItemset(items=['Evangelos Kranakis'], freq=256),
#  FreqItemset(items=['Lajos Hanzo'], freq=452),
#  FreqItemset(items=['Hanqing Lu'], freq=250),
#  FreqItemset(items=['Leonard Barolli'], freq=417),
#  FreqItemset(items=['Yan Chen'], freq=349),
#  FreqItemset(items=['Xi Zhang'], freq=236),
#  FreqItemset(items=['Yang Wang'], freq=365),
#  FreqItemset(items=['Jan Treur'], freq=329),
#  FreqItemset(items=['Thomas Ertl'], freq=261),
#  FreqItemset(items=['Meng Wang'], freq=247),
#  FreqItemset(items=['Jing Wang'], freq=495),
#  FreqItemset(items=['Chao Wang'], freq=374),
#  FreqItemset(items=['Xiaotie Deng'], freq=239),
#  FreqItemset(items=['Enrico Macii'], freq=244),
#  FreqItemset(items=['Michael I. Jordan'], freq=263),
#  FreqItemset(items=['Wei Liu'], freq=582),
#  FreqItemset(items=['Kaushik Roy'], freq=472),
#  FreqItemset(items=['Reihaneh Safavi-Naini'], freq=261),
#  FreqItemset(items=['Peng Wang'], freq=284),
#  FreqItemset(items=['Tat-Seng Chua'], freq=265),
#  FreqItemset(items=['Chin-Chen Chang'], freq=680),
#  FreqItemset(items=['Nicholas R. Jennings'], freq=403),
#  FreqItemset(items=['Hui Liu'], freq=248),
#  FreqItemset(items=['Lei Chen'], freq=380),
#  FreqItemset(items=['Hans-Peter Meinzer'], freq=215),
#  FreqItemset(items=['Tao Yang'], freq=271),
#  FreqItemset(items=['Masaru Kitsuregawa'], freq=274),
#  FreqItemset(items=['Jie Liu'], freq=258),
#  FreqItemset(items=['Karsten Schwan'], freq=251),
#  FreqItemset(items=['Paul M. B. Vitányi'], freq=217),
#  FreqItemset(items=['János Pach'], freq=220),
#  FreqItemset(items=['Ching Y. Suen'], freq=278),
#  FreqItemset(items=['Xin Wang'], freq=511),
#  FreqItemset(items=['Tao Xie'], freq=222),
#  FreqItemset(items=['Jeffrey Scott Vitter'], freq=254),
#  FreqItemset(items=['Ying Zhang'], freq=425),
#  FreqItemset(items=['Ivan Stojmenovic'], freq=263),
#  FreqItemset(items=['Muriel Médard'], freq=226),
#  FreqItemset(items=['Piet Demeester'], freq=298),
#  FreqItemset(items=['Jing Li'], freq=484),
#  FreqItemset(items=['Oscar Pastor'], freq=221),
#  FreqItemset(items=['Jie Wu'], freq=552),
#  FreqItemset(items=['Tong Zhang'], freq=268),
#  FreqItemset(items=['Antonio González'], freq=259),
#  FreqItemset(items=['Jun Wang'], freq=717),
#  FreqItemset(items=['C. Lee Giles'], freq=291),
#  FreqItemset(items=['Peter Widmayer'], freq=215),
#  FreqItemset(items=['Zhen Liu'], freq=272),
#  FreqItemset(items=['Shojiro Nishio'], freq=275),
#  FreqItemset(items=['Rajiv Gupta'], freq=228),
#  FreqItemset(items=['Biswanath Mukherjee'], freq=218),
#  FreqItemset(items=['Wolfgang Nejdl'], freq=304),
#  FreqItemset(items=['Gang Wang'], freq=281),
#  FreqItemset(items=['Changshui Zhang'], freq=230),
#  FreqItemset(items=['Ian F. Akyildiz'], freq=286),
#  FreqItemset(items=['Dov M. Gabbay'], freq=223),
#  FreqItemset(items=['Victor R. Basili'], freq=216),
#  FreqItemset(items=['Chun Chen'], freq=273),
#  FreqItemset(items=['Katsushi Ikeuchi'], freq=231),
#  FreqItemset(items=['Jian Yang'], freq=342),
#  FreqItemset(items=['Mohammad S. Obaidat'], freq=222),
#  FreqItemset(items=['Mary Jane Irwin'], freq=313),
#  FreqItemset(items=['David E. Goldberg'], freq=235),
#  FreqItemset(items=['Ioannis Pitas'], freq=287),
#  FreqItemset(items=['Jean-Jacques Quisquater'], freq=219),
#  FreqItemset(items=['Xin Yao'], freq=324),
#  FreqItemset(items=['J. J. Garcia-Luna-Aceves'], freq=238),
#  FreqItemset(items=['Ophir Frieder'], freq=227),
#  FreqItemset(items=['Tomoya Enokido'], freq=241),
#  FreqItemset(items=['Tomoya Enokido', 'Makoto Takizawa'], freq=237),
#  FreqItemset(items=['Bertrand Meyer'], freq=224),
#  FreqItemset(items=['Nicholas Ayache'], freq=293),
#  FreqItemset(items=['Jon Crowcroft'], freq=229),
#  FreqItemset(items=['Taghi M. Khoshgoftaar'], freq=300),
#  FreqItemset(items=['Maarten de Rijke'], freq=276),
#  FreqItemset(items=['Giovanni De Micheli'], freq=307),
#  FreqItemset(items=['Heinrich Niemann'], freq=282),
#  FreqItemset(items=[''], freq=16989),
#  FreqItemset(items=['Li Chen'], freq=356),
#  FreqItemset(items=['Vincent K. N. Lau'], freq=226),
#  FreqItemset(items=['Gheorghe Paun'], freq=299),
#  FreqItemset(items=['Emilio Luque'], freq=249),
#  FreqItemset(items=['Paul G. Spirakis'], freq=383),
#  FreqItemset(items=['Vishwani D. Agrawal'], freq=323),
#  FreqItemset(items=['Nicola Santoro'], freq=230),
#  FreqItemset(items=['Reda Alhajj'], freq=305),
#  FreqItemset(items=['Jürgen Teich'], freq=312),
#  FreqItemset(items=['Wil M. P. van der Aalst'], freq=406),
#  FreqItemset(items=['Qian Zhang'], freq=337),
#  FreqItemset(items=['Victor O. K. Li'], freq=240),
#  FreqItemset(items=['Heung-Yeung Shum'], freq=235),
#  FreqItemset(items=['Lei Li'], freq=224),
#  FreqItemset(items=['Dhabaleswar K. Panda'], freq=293),
#  FreqItemset(items=['Calton Pu'], freq=245),
#  FreqItemset(items=['Horst Bunke'], freq=370),
#  FreqItemset(items=['Shlomi Dolev'], freq=228),
#  FreqItemset(items=['John M. Cioffi'], freq=251),
#  FreqItemset(items=['Yang Zhang'], freq=237),
#  FreqItemset(items=['Ajith Abraham'], freq=554),
#  FreqItemset(items=['Ping Zhang'], freq=388),
#  FreqItemset(items=['Narendra Ahuja'], freq=246),
#  FreqItemset(items=['John M. Carroll'], freq=232),
#  FreqItemset(items=['Divesh Srivastava'], freq=256),
#  FreqItemset(items=['Krishnendu Chakrabarty'], freq=361),
#  FreqItemset(items=['Kouichi Sakurai'], freq=249),
#  FreqItemset(items=['Richard T. Snodgrass'], freq=242),
#  FreqItemset(items=['Munindar P. Singh'], freq=253),
#  FreqItemset(items=['Jun Liu'], freq=412),
#  FreqItemset(items=['Rajkumar Buyya'], freq=315),
#  FreqItemset(items=['Wei Yu'], freq=236),
#  FreqItemset(items=['Jacob A. Abraham'], freq=326),
#  FreqItemset(items=['Anil K. Jain'], freq=441),
#  FreqItemset(items=['Jun Xu'], freq=259),
#  FreqItemset(items=['Qing Li'], freq=485),
#  FreqItemset(items=['Eitan Altman'], freq=372),
#  FreqItemset(items=['Timothy K. Shih'], freq=239),
#  FreqItemset(items=['Takeo Kanade'], freq=345),
#  FreqItemset(items=['Ke Wang'], freq=263),
#  FreqItemset(items=['Antonio F. Gómez-Skarmeta'], freq=261),
#  FreqItemset(items=['Hui Wang'], freq=454),
#  FreqItemset(items=['Jie Wang'], freq=254),
#  FreqItemset(items=['Danny Dolev'], freq=219),
#  FreqItemset(items=['Jun Li'], freq=499),
#  FreqItemset(items=['Masayuki Murata'], freq=263),
#  FreqItemset(items=['Yan Zhang'], freq=632),
#  FreqItemset(items=['Peng Li'], freq=366),
#  FreqItemset(items=['Krithi Ramamritham'], freq=270),
#  FreqItemset(items=['Gerhard Fettweis'], freq=250),
#  FreqItemset(items=['Tharam S. Dillon'], freq=397),
#  FreqItemset(items=['Wei-Tek Tsai'], freq=216),
#  FreqItemset(items=['Michael Wooldridge'], freq=277),
#  FreqItemset(items=['Ke Xu'], freq=244),
#  FreqItemset(items=['Lei Xu'], freq=248),
#  FreqItemset(items=['Josef Kittler'], freq=421),
#  FreqItemset(items=['Jing Zhang'], freq=376),
#  FreqItemset(items=['David Blaauw'], freq=273),
#  FreqItemset(items=['Beng Chin Ooi'], freq=257),
#  FreqItemset(items=['Li Zhang'], freq=688),
#  FreqItemset(items=['Enrique Alba'], freq=225),
#  FreqItemset(items=['Albrecht Schmidt'], freq=215),
#  FreqItemset(items=['Donatella Sciuto'], freq=275),
#  FreqItemset(items=['Jeffrey D. Ullman'], freq=254),
#  FreqItemset(items=['Michael J. Carey'], freq=220),
#  FreqItemset(items=['Dacheng Tao'], freq=265),
#  FreqItemset(items=['Mahmut T. Kandemir'], freq=520),
#  FreqItemset(items=['Jian Chen'], freq=258),
#  FreqItemset(items=['Makoto Takizawa'], freq=474),
#  FreqItemset(items=['Robert H. Deng'], freq=222),
#  FreqItemset(items=['Yi Pan'], freq=290),
#  FreqItemset(items=['Bernd Becker'], freq=271),
#  FreqItemset(items=['Sartaj Sahni'], freq=261),
#  FreqItemset(items=['Pankaj K. Agarwal'], freq=296),
#  FreqItemset(items=['Raghu Ramakrishnan'], freq=227),
#  FreqItemset(items=['Jianzhong Li'], freq=217),
#  FreqItemset(items=['Larry S. Davis'], freq=278),
#  FreqItemset(items=['Azzedine Boukerche'], freq=427),
#  FreqItemset(items=['Gerd Hirzinger'], freq=284),
#  FreqItemset(items=['Peter Stone'], freq=272),
#  FreqItemset(items=['H. Vincent Poor'], freq=735),
#  FreqItemset(items=['Dan Suciu'], freq=230),
#  FreqItemset(items=['Yu-Chee Tseng'], freq=221),
#  FreqItemset(items=['Yang Xiao'], freq=311),
#  FreqItemset(items=['Lionel M. Ni'], freq=286),
#  FreqItemset(items=['Victor R. Lesser'], freq=218),
#  FreqItemset(items=['John A. Stankovic'], freq=275),
#  FreqItemset(items=['Mohamed-Slim Alouini'], freq=321),
#  FreqItemset(items=['Hermann A. Maurer'], freq=268),
#  FreqItemset(items=['Ricardo A. Baeza-Yates'], freq=305),
#  FreqItemset(items=['Guy Pujolle'], freq=281),
#  FreqItemset(items=['Ravi S. Sandhu'], freq=215),
#  FreqItemset(items=['Chengqi Zhang'], freq=234),
#  FreqItemset(items=['Brad A. Myers'], freq=223),
#  FreqItemset(items=['Fabrizio Lombardi'], freq=291),
#  FreqItemset(items=['Li Liu'], freq=237),
#  FreqItemset(items=['Roberto Tamassia'], freq=226),
#  FreqItemset(items=['Vojtech Rödl'], freq=228),
#  FreqItemset(items=['Yu Chen'], freq=298),
#  FreqItemset(items=['Majid Sarrafzadeh'], freq=282),
#  FreqItemset(items=['Hans L. Bodlaender'], freq=238),
#  FreqItemset(items=['Vladik Kreinovich'], freq=344),
#  FreqItemset(items=['HongJiang Zhang'], freq=301),
#  FreqItemset(items=['Béla Bollobás'], freq=224),
#  FreqItemset(items=['Tao Wang'], freq=288),
#  FreqItemset(items=['Yi Mu'], freq=229),
#  FreqItemset(items=['Lei He'], freq=246),
#  FreqItemset(items=['José Duato'], freq=359),
#  FreqItemset(items=['Barry W. Boehm'], freq=231),
#  FreqItemset(items=['Hong Liu'], freq=307),
#  FreqItemset(items=['Won Kim'], freq=227),
#  FreqItemset(items=['Michael G. Strintzis'], freq=249),
#  FreqItemset(items=['Jun Ma'], freq=235),
#  FreqItemset(items=['Andrew B. Kahng'], freq=324),
#  FreqItemset(items=['Enrico Pontelli'], freq=222),
#  FreqItemset(items=['Shih-Fu Chang'], freq=242),
#  FreqItemset(items=['Bo Yang'], freq=372),
#  FreqItemset(items=['Francisco Herrera'], freq=314),
#  FreqItemset(items=['Jeffrey Xu Yu'], freq=294),
#  FreqItemset(items=['Kwang-Ting Cheng'], freq=260),
#  FreqItemset(items=['Bo Xu'], freq=247),
#  FreqItemset(items=['Manuela M. Veloso'], freq=316),
#  FreqItemset(items=['Jason Cong'], freq=327),
#  FreqItemset(items=['Michael Stonebraker'], freq=239),
#  FreqItemset(items=['Fedor V. Fomin'], freq=233),
#  FreqItemset(items=['Jürgen Becker'], freq=256),
#  FreqItemset(items=['Vijay Varadharajan'], freq=243),
#  FreqItemset(items=['Hermann Ney'], freq=364),
#  FreqItemset(items=['Dharma P. Agrawal'], freq=309),
#  FreqItemset(items=['Nadia Magnenat-Thalmann'], freq=303),
#  FreqItemset(items=['Hiroshi G. Okuno'], freq=250),
#  FreqItemset(items=['Christos Faloutsos'], freq=374),
#  FreqItemset(items=['Roberto Cipolla'], freq=236),
#  FreqItemset(items=['Yi Wang'], freq=393),
#  FreqItemset(items=['Derick Wood'], freq=230),
#  FreqItemset(items=['Francky Catthoor'], freq=451),
#  FreqItemset(items=['Xiang-Yang Li'], freq=253),
#  FreqItemset(items=['Hsinchun Chen'], freq=416),
#  FreqItemset(items=['Gerhard J. Woeginger'], freq=349),
#  FreqItemset(items=['Matteo Sonza Reorda'], freq=254),
#  FreqItemset(items=['Tao Jiang'], freq=402),
#  FreqItemset(items=['Jian Zhang'], freq=424),
#  FreqItemset(items=['Xuemin Shen'], freq=353),
#  FreqItemset(items=['Douglas R. Stinson'], freq=217),
#  FreqItemset(items=['Steffen Staab'], freq=258),
#  FreqItemset(items=['Xiaodong Wang'], freq=471),
#  FreqItemset(items=['Vipin Kumar'], freq=240),
#  FreqItemset(items=['David J. Evans'], freq=265),
#  FreqItemset(items=['Elisa Bertino'], freq=670),
#  FreqItemset(items=['Oscar Castillo'], freq=245),
#  FreqItemset(items=['Michel Raynal'], freq=369),
#  FreqItemset(items=['Hideki Imai'], freq=335),
#  FreqItemset(items=['Sanjay Jain'], freq=261),
#  FreqItemset(items=['Jan A. Bergstra'], freq=248),
#  FreqItemset(items=['Hans-Peter Seidel'], freq=510),
#  FreqItemset(items=['Bin Li'], freq=380),
#  FreqItemset(items=['Hua Wang'], freq=251),
#  FreqItemset(items=['Rui Wang'], freq=274),
#  FreqItemset(items=['Hiroshi Ishiguro'], freq=270),
#  FreqItemset(items=['Horst Bischof'], freq=262),
#  FreqItemset(items=['Gerhard Weikum'], freq=387),
#  FreqItemset(items=['Moni Naor'], freq=226),
#  FreqItemset(items=['Philip S. Yu'], freq=711),
#  FreqItemset(items=['Yi Zhang'], freq=411),
#  FreqItemset(items=['Qi Tian'], freq=255),
#  FreqItemset(items=['Qi Zhang'], freq=215),
#  FreqItemset(items=['John-Jules Ch. Meyer'], freq=275),
#  FreqItemset(items=['Wolfram Burgard'], freq=259),
#  FreqItemset(items=['Bing Liu'], freq=252),
#  FreqItemset(items=['Irith Pomeranz'], freq=482),
#  FreqItemset(items=['Irith Pomeranz', 'Sudhakar M. Reddy'], freq=410),
#  FreqItemset(items=['Licheng Jiao'], freq=291),
#  FreqItemset(items=['Markus H. Gross'], freq=221),
#  FreqItemset(items=['Ying Chen'], freq=281),
#  FreqItemset(items=['Amr El Abbadi'], freq=285),
#  FreqItemset(items=['Amr El Abbadi', 'Divyakant Agrawal'], freq=242),
#  FreqItemset(items=['Yishay Mansour'], freq=268),
#  FreqItemset(items=['Mario Piattini'], freq=550),
#  FreqItemset(items=['Manuel V. Hermenegildo'], freq=223),
#  FreqItemset(items=['Jie Li'], freq=272),
#  FreqItemset(items=['Yang Yang'], freq=439),
#  FreqItemset(items=['Xiaohua Jia'], freq=218),
#  FreqItemset(items=['Pascal Van Hentenryck'], freq=231),
#  FreqItemset(items=['Fumiyuki Adachi'], freq=227),
#  FreqItemset(items=['Gang Li'], freq=312),
#  FreqItemset(items=['Feng Wang'], freq=300),
#  FreqItemset(items=['Kang G. Shin'], freq=494),
#  FreqItemset(items=['Fang Liu'], freq=270),
#  FreqItemset(items=['Wei Wang'], freq=1293),
#  FreqItemset(items=['Peng Liu'], freq=306),
#  FreqItemset(items=['Qi Li'], freq=216),
#  FreqItemset(items=['Chew Lim Tan'], freq=276),
#  FreqItemset(items=['Tzung-Pei Hong'], freq=235),
#  FreqItemset(items=['Ming Liu'], freq=229),
#  FreqItemset(items=['Jack Snoeyink'], freq=219),
#  FreqItemset(items=['Dimitris N. Metaxas'], freq=282),
#  FreqItemset(items=['Holger Boche'], freq=221),
#  FreqItemset(items=['Howard Jay Siegel'], freq=263),
#  FreqItemset(items=['Jiawei Han'], freq=581),
#  FreqItemset(items=['Katia P. Sycara'], freq=287),
#  FreqItemset(items=['Ge Yu'], freq=224),
#  FreqItemset(items=['Robert Schober'], freq=293),
#  FreqItemset(items=['Nancy A. Lynch'], freq=273),
#  FreqItemset(items=['Hao Wang'], freq=348),
#  FreqItemset(items=['David Peleg'], freq=315),
#  FreqItemset(items=['Michele Zorzi'], freq=236),
#  FreqItemset(items=['Wei Wei'], freq=222),
#  FreqItemset(items=['Mubarak Shah'], freq=225),
#  FreqItemset(items=['Bhavani M. Thuraisingham'], freq=289),
#  FreqItemset(items=['Tsuhan Chen'], freq=243),
#  FreqItemset(items=['Rolf Drechsler'], freq=363),
#  FreqItemset(items=['Zhi-Hua Zhou'], freq=247),
#  FreqItemset(items=['Guang R. Gao'], freq=239),
#  FreqItemset(items=['Huan Liu'], freq=227),
#  FreqItemset(items=['Wayne Luk'], freq=302),
#  FreqItemset(items=['Willy Susilo'], freq=277),
#  FreqItemset(items=['Victor C. M. Leung'], freq=327),
#  FreqItemset(items=['Tughrul Arslan'], freq=232),
#  FreqItemset(items=['Gonzalo Navarro'], freq=295),
#  FreqItemset(items=['John H. Reif'], freq=230),
#  FreqItemset(items=['Mérouane Debbah'], freq=219),
#  FreqItemset(items=['Michael T. Goodrich'], freq=309),
#  FreqItemset(items=['Hong Shen'], freq=283),
#  FreqItemset(items=['Matthias Jarke'], freq=304),
#  FreqItemset(items=['Georgios B. Giannakis'], freq=400),
#  FreqItemset(items=['Manfred Broy'], freq=248),
#  FreqItemset(items=['Bernhard Thalheim'], freq=233),
#  FreqItemset(items=['Georg Gottlob'], freq=320),
#  FreqItemset(items=['Kotagiri Ramamohanarao'], freq=257),
#  FreqItemset(items=['Sarit Kraus'], freq=240),
#  FreqItemset(items=['Ling Liu'], freq=333),
#  FreqItemset(items=['Weijia Jia'], freq=228),
#  FreqItemset(items=['Ying Wang'], freq=352),
#  FreqItemset(items=['Yong Wang'], freq=377),
#  FreqItemset(items=['Simon Parsons'], freq=250),
#  FreqItemset(items=['Svetha Venkatesh'], freq=244),
#  FreqItemset(items=['John H. L. Hansen'], freq=230),
#  FreqItemset(items=['Jing Liu'], freq=366),
#  FreqItemset(items=['Mateo Valero'], freq=311),
#  FreqItemset(items=['V. S. Subrahmanian'], freq=254),
#  FreqItemset(items=['Hui Li'], freq=422),
#  FreqItemset(items=['H. V. Jagadish'], freq=237),
#  FreqItemset(items=['Fatos Xhafa'], freq=297),
#  FreqItemset(items=['Rafail Ostrovsky'], freq=249),
#  FreqItemset(items=['Jie Zhang'], freq=432),
#  FreqItemset(items=['David Eppstein'], freq=385),
#  FreqItemset(items=['Yu Zhang'], freq=481),
#  FreqItemset(items=['Sungyoung Lee'], freq=255),
#  FreqItemset(items=['Satoshi Nakamura'], freq=267),
#  FreqItemset(items=['Daniel Thalmann'], freq=323),
#  FreqItemset(items=['Yu Liu'], freq=258),
#  FreqItemset(items=['Frank Leymann'], freq=251),
#  FreqItemset(items=['Narayanan Vijaykrishnan'], freq=238),
#  FreqItemset(items=['Viktor K. Prasanna'], freq=410),
#  FreqItemset(items=['Schahram Dustdar'], freq=341),
#  FreqItemset(items=['Yves Robert'], freq=241),
#  FreqItemset(items=['Mitsuru Ishizuka'], freq=262),
#  FreqItemset(items=['Witold Pedrycz'], freq=531),
#  FreqItemset(items=['Xianlong Hong'], freq=245),
#  FreqItemset(items=['Didier Dubois'], freq=359),
#  FreqItemset(items=['Didier Dubois', 'Henri Prade'], freq=251),
#  FreqItemset(items=['Bo Zhang'], freq=371),
#  FreqItemset(items=['Ee-Peng Lim'], freq=272),
#  FreqItemset(items=['Thomas S. Huang'], freq=691),
#  FreqItemset(items=['Arto Salomaa'], freq=256),
#  FreqItemset(items=['Edwin R. Hancock'], freq=567),
#  FreqItemset(items=['Luca Benini'], freq=445),
#  FreqItemset(items=['Rachid Guerraoui'], freq=286),
#  FreqItemset(items=['Lei Zhang'], freq=841),
#  FreqItemset(items=['Min Zhang'], freq=272),
#  FreqItemset(items=['Manfred Glesner'], freq=263),
#  FreqItemset(items=['Jianer Chen'], freq=250),
#  FreqItemset(items=['David Zhang'], freq=390),
#  FreqItemset(items=['Patricia Melin'], freq=215),
#  FreqItemset(items=['Fei Wang'], freq=276),
#  FreqItemset(items=['Wei Xu'], freq=269),
#  FreqItemset(items=['Xin Zhang'], freq=413),
#  FreqItemset(items=['Jeffrey G. Andrews'], freq=221),
#  FreqItemset(items=['Tao Zhang'], freq=282),
#  FreqItemset(items=['Serge Abiteboul'], freq=260),
#  FreqItemset(items=['Jack Dongarra'], freq=490),
#  FreqItemset(items=['Ralf Steinmetz'], freq=373),
#  FreqItemset(items=['Prithviraj Banerjee'], freq=253),
#  FreqItemset(items=['Hanan Samet'], freq=218),
#  FreqItemset(items=['Ming Li'], freq=646),
#  FreqItemset(items=['Micha Sharir'], freq=466),
#  FreqItemset(items=['Li Wang'], freq=288),
#  FreqItemset(items=['Liang Zhang'], freq=264),
#  FreqItemset(items=['Hai Jin'], freq=505),
#  FreqItemset(items=['Yang Xiang'], freq=227),
#  FreqItemset(items=['Jiming Liu'], freq=222),
#  FreqItemset(items=['Aggelos K. Katsaggelos'], freq=301),
#  FreqItemset(items=['Zhaohui Wu'], freq=270),
#  FreqItemset(items=['Jian Pei'], freq=229),
#  FreqItemset(items=['Jie Chen'], freq=307),
#  FreqItemset(items=['Wolfgang Rosenstiel'], freq=283),
#  FreqItemset(items=['Barry Smyth'], freq=274),
#  FreqItemset(items=['Jian Liu'], freq=216),
#  FreqItemset(items=['Hao Chen'], freq=277),
#  FreqItemset(items=['Robert K. Brayton'], freq=261),
#  FreqItemset(items=['Yong Li'], freq=224),
#  FreqItemset(items=['Hideharu Amano'], freq=219),
#  FreqItemset(items=['Ming Zhang'], freq=295),
#  FreqItemset(items=['Milind Tambe'], freq=233),
#  FreqItemset(items=['B. John Oommen'], freq=236),
#  FreqItemset(items=['Xi Chen'], freq=319),
#  FreqItemset(items=['Xiaofang Zhou'], freq=220),
#  FreqItemset(items=['Hong Wang'], freq=285),
#  FreqItemset(items=['C. Pandu Rangan'], freq=239),
#  FreqItemset(items=['Qiang Yang'], freq=352),
#  FreqItemset(items=['Xin Chen'], freq=304),
#  FreqItemset(items=['Jürgen Schmidhuber'], freq=225),
#  FreqItemset(items=['Maurizio Lenzerini'], freq=227),
#  FreqItemset(items=['Amit P. Sheth'], freq=280),
#  FreqItemset(items=['Ben Shneiderman'], freq=330),
#  FreqItemset(items=['Loet Leydesdorff'], freq=223),
#  FreqItemset(items=['Alan M. Frieze'], freq=290),
#  FreqItemset(items=['Daphne Koller'], freq=230),
#  FreqItemset(items=['Qing Wang'], freq=310),
#  FreqItemset(items=['Rajeev Alur'], freq=215),
#  FreqItemset(items=['Nassir Navab'], freq=296),
#  FreqItemset(items=['Chung-Kuan Cheng'], freq=217),
#  FreqItemset(items=['Chuang Lin'], freq=275)]

# %%
model2 = FPGrowth.train(rdd_res, 1e-5, 2)
model2.freqItemsets().collect()
# Out:
# [FreqItemset(items=['Philip Levis'], freq=58),
#  FreqItemset(items=['Eva Hudlicka'], freq=26),
#  FreqItemset(items=['Pierre Vandergheynst'], freq=109),
#  FreqItemset(items=['Pierre Vandergheynst', 'Pascal Frossard'], freq=23),
#  FreqItemset(items=['Mark Minas'], freq=81),
#  FreqItemset(items=['Martti Penttonen'], freq=32),
#  FreqItemset(items=['Yen-Hsien Lee'], freq=23),
#  FreqItemset(items=['Terrence S. T. Mak'], freq=30),
#  FreqItemset(items=['Andrew W. Appel'], freq=85),
#  FreqItemset(items=['John MacIntyre'], freq=28),
#  FreqItemset(items=['Pierre Soille'], freq=57),
#  FreqItemset(items=['Ana Cristina Vieira de Melo'], freq=26),
#  FreqItemset(items=['Jan Stallaert'], freq=25),
#  FreqItemset(items=['Tomonari Masada'], freq=26),
#  FreqItemset(items=['Roberto Sabella'], freq=23),
#  FreqItemset(items=['Ricardo C. Farias'], freq=30),
#  FreqItemset(items=['Arnoud Visser'], freq=22),
#  FreqItemset(items=['Ling Zhao'], freq=26),
#  FreqItemset(items=['Darrell D. E. Long'], freq=120),
#  FreqItemset(items=['Peer-Timo Bremer'], freq=31),
#  FreqItemset(items=['Peer-Timo Bremer', 'Valerio Pascucci'], freq=28),
#  FreqItemset(items=['Georg Carle'], freq=90),
#  FreqItemset(items=['Hans van der Heijden'], freq=29),
#  FreqItemset(items=['Martti Hallikainen'], freq=46),
#  FreqItemset(items=['Wieslaw L. Nowinski'], freq=37),
#  FreqItemset(items=['Ed Zaluska'], freq=34),
#  FreqItemset(items=['Wenjing Jia'], freq=45),
#  FreqItemset(items=['Wenjing Jia', 'Qiang Wu'], freq=34),
#  FreqItemset(items=['Wenjing Jia', 'Xiangjian He'], freq=44),
#  FreqItemset(items=['Wenjing Jia', 'Xiangjian He', 'Qiang Wu'], freq=34),
#  FreqItemset(items=['Junji Furusho'], freq=29),
#  FreqItemset(items=['Peter A. Gloor'], freq=41),
#  FreqItemset(items=['Kunio Doi'], freq=37),
#  FreqItemset(items=['Marc Teboulle'], freq=34),
#  FreqItemset(items=['Radha Krishna Ganti'], freq=47),
#  FreqItemset(items=['Radha Krishna Ganti', 'Martin Haenggi'], freq=23),
#  FreqItemset(items=['Radha Krishna Ganti', 'Jeffrey G. Andrews'], freq=27),
#  FreqItemset(items=['Wen-Chih Chang'], freq=38),
#  FreqItemset(items=['Richard J. La'], freq=46),
#  FreqItemset(items=['H. Edwin Romeijn'], freq=48),
#  FreqItemset(items=['Jaakko Kangasharju'], freq=22),
#  FreqItemset(items=['Anthony J. H. Simons'], freq=42),
#  FreqItemset(items=['Tao Hu'], freq=38),
#  FreqItemset(items=['Guido Schryen'], freq=35),
#  FreqItemset(items=['J. Gregory Trafton'], freq=44),
#  FreqItemset(items=['Changyin Sun'], freq=65),
#  FreqItemset(items=['Denis R. Hirschfeldt'], freq=26),
#  FreqItemset(items=["Tiziana D'Orazio"], freq=57),
#  FreqItemset(items=["Tiziana D'Orazio", 'Arcangelo Distante'], freq=27),
#  FreqItemset(items=['Vassil Roussev'], freq=23),
#  FreqItemset(items=['Björn Waske'], freq=22),
#  FreqItemset(items=['Marco Ragni'], freq=23),
#  FreqItemset(items=['Bernard Lidický'], freq=26),
#  FreqItemset(items=['Weimin Chen'], freq=23),
#  FreqItemset(items=['Tim Weitzel'], freq=108),
#  FreqItemset(items=['Jari Nurmi'], freq=85),
#  FreqItemset(items=['Masahiko Yachida'], freq=119),
#  FreqItemset(items=['Masahiko Yachida', 'Yasushi Yagi'], freq=36),
#  FreqItemset(items=['Fabio Salice'], freq=67),
#  FreqItemset(items=['Fabio Salice', 'Donatella Sciuto'], freq=41),
#  FreqItemset(items=['Fabio Salice', 'William Fornaciari'], freq=26),
#  FreqItemset(items=['Fabio Salice', 'Cristiana Bolchini'], freq=33),
#  FreqItemset(items=['Fabio Salice', 'Cristiana Bolchini', 'Donatella Sciuto'], freq=22),
#  FreqItemset(items=['Seung Joon Lee'], freq=26),
#  FreqItemset(items=['Fei He'], freq=59),
#  FreqItemset(items=['Minghua Xia'], freq=25),
#  FreqItemset(items=['Yue Wu'], freq=83),
#  FreqItemset(items=['Jae-Woo Chang'], freq=114),
#  FreqItemset(items=['Kevin A. Schneider'], freq=25),
#  FreqItemset(items=['Xiaoyang Sean Wang'], freq=133),
#  FreqItemset(items=['Xiaoyang Sean Wang', 'Sushil Jajodia'], freq=56),
#  FreqItemset(items=['Bernard Ries'], freq=29),
#  FreqItemset(items=['Tom Vercauteren'], freq=31),
#  FreqItemset(items=['Sem C. Borst'], freq=95),
#  FreqItemset(items=['Sameer Tilak'], freq=25),
#  FreqItemset(items=['Samir Tohmé'], freq=54),
#  FreqItemset(items=['Serge Weber'], freq=31),
#  FreqItemset(items=['Serge Weber', 'Camel Tanougast'], freq=22),
#  FreqItemset(items=['Shaochun Xu'], freq=28),
#  FreqItemset(items=['Liang Zhou'], freq=93),
#  FreqItemset(items=['Masafumi Okada'], freq=29),
#  FreqItemset(items=['Jin S. Lee'], freq=25),
#  FreqItemset(items=['Alexandre David'], freq=46),
#  FreqItemset(items=['Alexandre David', 'Kim Guldstrand Larsen'], freq=26),
#  FreqItemset(items=['Bruno Feijó'], freq=37),
#  FreqItemset(items=['Chaouki T. Abdallah'], freq=38),
#  FreqItemset(items=['Andreas Frommer'], freq=34),
#  FreqItemset(items=['Alexander De Luca'], freq=31),
#  FreqItemset(items=['Manolis Maragoudakis'], freq=46),
#  FreqItemset(items=['Manolis Maragoudakis', 'Nikos Fakotakis'], freq=23),
#  FreqItemset(items=['Adam Przepiórkowski'], freq=29),
#  FreqItemset(items=['Thomas Ehrhard'], freq=47),
#  FreqItemset(items=['Yvonne Dittrich'], freq=43),
#  FreqItemset(items=['Fredrik Heintz'], freq=23),
#  FreqItemset(items=['Long Bao Le'], freq=39),
#  FreqItemset(items=['Richard J. Fateman'], freq=36),
#  FreqItemset(items=['Olivier Simonin'], freq=33),
#  FreqItemset(items=['Michael Eineder'], freq=43),
#  FreqItemset(items=['Mitsunori Ogiwara'], freq=22),
#  FreqItemset(items=['Hamid R. Sadjadpour'], freq=67),
#  FreqItemset(items=['Hamid R. Sadjadpour', 'J. J. Garcia-Luna-Aceves'], freq=40),
#  FreqItemset(items=['Rémy Prost'], freq=57),
#  FreqItemset(items=['José Machado'], freq=44),
#  FreqItemset(items=['José Machado', 'José Neves'], freq=31),
#  FreqItemset(items=['Andreas Czylwik'], freq=22),
#  FreqItemset(items=['Marc Toussaint'], freq=66),
#  FreqItemset(items=['Bernard Mulgrew'], freq=56),
#  FreqItemset(items=['Er-Wei Bai'], freq=58),
#  FreqItemset(items=['Hristo Djidjev'], freq=44),
#  FreqItemset(items=['Sven-Arne Reinemo'], freq=23),
#  FreqItemset(items=['Yong-Sheng Chen'], freq=22),
#  FreqItemset(items=['Bernhard Walke'], freq=89),
#  FreqItemset(items=['Nelly Litvak'], freq=25),
#  FreqItemset(items=['David Horn'], freq=61),
#  FreqItemset(items=['Juan J. Merelo Guervós'], freq=87),
#  FreqItemset(items=['John Matthews'], freq=22),
#  FreqItemset(items=['Zhizheng Zhang'], freq=25),
#  FreqItemset(items=['Yukitoshi Sanada'], freq=60),
#  FreqItemset(items=['Roksana Boreli'], freq=26),
#  FreqItemset(items=['Ji-Huan He'], freq=25),
#  FreqItemset(items=['Opher Etzion'], freq=95),
#  FreqItemset(items=['Atílio Gameiro'], freq=63),
#  FreqItemset(items=['Dave A. Thomas'], freq=37),
#  FreqItemset(items=['Emanouil I. Atanassov'], freq=31),
#  FreqItemset(items=['Samuel Madden'], freq=141),
#  FreqItemset(items=['Samuel Madden', 'Hari Balakrishnan'], freq=23),
#  FreqItemset(items=['Rangasami L. Kashyap'], freq=92),
#  FreqItemset(items=['Andrea Acquaviva'], freq=75),
#  FreqItemset(items=['Andrea Acquaviva', 'Luca Benini'], freq=26),
#  FreqItemset(items=['Patrick Lam'], freq=31),
#  FreqItemset(items=['Cunsheng Ding'], freq=99),
#  FreqItemset(items=['Raman Kazhamiakin'], freq=29),
#  FreqItemset(items=['Raman Kazhamiakin', 'Marco Pistore'], freq=25),
#  FreqItemset(items=['Khalid Daoudi'], freq=27),
#  FreqItemset(items=['Maria J. Martín-Bautista'], freq=37),
#  FreqItemset(items=['Maria J. Martín-Bautista', 'María Amparo Vila Miranda'], freq=25),
#  FreqItemset(items=['Pablo Figueroa'], freq=25),
#  FreqItemset(items=['Cynthia LeRouge'], freq=29),
#  FreqItemset(items=['Klaus Radermacher'], freq=35),
#  FreqItemset(items=['Yosuke Sato'], freq=32),
#  FreqItemset(items=['Lorcan Coyle'], freq=30),
#  FreqItemset(items=['Daxin Jiang'], freq=28),
#  FreqItemset(items=['Daxin Jiang', 'Jian Pei'], freq=22),
#  FreqItemset(items=['Chan-Soo Hwang'], freq=35),
#  FreqItemset(items=['Dae Young Kim'], freq=30),
#  FreqItemset(items=['Marco Callieri'], freq=36),
#  FreqItemset(items=['Marco Callieri', 'Roberto Scopigno'], freq=30),
#  FreqItemset(items=['Wen-Liang Hung'], freq=48),
#  FreqItemset(items=['Wen-Liang Hung', 'Miin-Shen Yang'], freq=25),
#  FreqItemset(items=['Huadong Guo'], freq=44),
#  FreqItemset(items=['Toshinori Munakata'], freq=23),
#  FreqItemset(items=['Mohamed H. Ahmed'], freq=35),
#  FreqItemset(items=['Dietrich Albert'], freq=58),
#  FreqItemset(items=['Mercedes G. Merayo'], freq=45),
#  FreqItemset(items=['Mercedes G. Merayo', 'Manuel Núñez'], freq=38),
#  FreqItemset(items=['Gary Singh'], freq=68),
#  FreqItemset(items=['J. Leo van Hemmen'], freq=58),
#  FreqItemset(items=['Paul G. Sorenson'], freq=51),
#  FreqItemset(items=['Adam Liwo'], freq=23),
#  FreqItemset(items=['Shaahin Hessabi'], freq=45),
#  FreqItemset(items=['Yuval Emek'], freq=41),
#  FreqItemset(items=['Yael Moses'], freq=22),
#  FreqItemset(items=['Helman Stern'], freq=22),
#  FreqItemset(items=['Mike Burmester'], freq=92),
#  FreqItemset(items=['Mike Burmester', 'Yvo Desmedt'], freq=32),
#  FreqItemset(items=['Karl J. Lieberherr'], freq=71),
#  FreqItemset(items=['Jeffrey H. Reed'], freq=62),
#  FreqItemset(items=['Yves Lecourtier'], freq=53),
#  FreqItemset(items=['Luca Roversi'], freq=25),
#  FreqItemset(items=['Amaury Lendasse'], freq=89),
#  FreqItemset(items=['Amaury Lendasse', 'Michel Verleysen'], freq=28),
#  FreqItemset(items=['Richard Cooper'], freq=42),
#  FreqItemset(items=['Carlos D. Martínez-Hinarejos'], freq=22),
#  FreqItemset(items=['Mikael Lindvall'], freq=61),
#  FreqItemset(items=['Jinsuk Baek'], freq=25),
#  FreqItemset(items=['Carlo Gaibisso'], freq=25),
#  FreqItemset(items=['Wentao Zhao'], freq=22),
#  FreqItemset(items=['Yiu-ming Cheung'], freq=98),
#  FreqItemset(items=['Manabu Hagiwara'], freq=29),
#  FreqItemset(items=['Yong Bai'], freq=26),
#  FreqItemset(items=['Riccardo Scandariato'], freq=24),
#  FreqItemset(items=['Andreas Nürnberger'], freq=95),
#  FreqItemset(items=['Leszek Pacholski'], freq=29),
#  FreqItemset(items=['Srinivas Aluru'], freq=102),
#  FreqItemset(items=['A. Ant Ozok'], freq=26),
#  FreqItemset(items=['David Maier'], freq=227),
#  FreqItemset(items=['Xiaohui Yu'], freq=30),
#  FreqItemset(items=['Jack W. Davidson'], freq=83),
#  FreqItemset(items=['Gavin M. Bierman'], freq=38),
#  FreqItemset(items=['Andrea Omicini'], freq=194),
#  FreqItemset(items=['Andrea Omicini', 'Franco Zambonelli'], freq=23),
#  FreqItemset(items=['Lingmei Jiang'], freq=35),
#  FreqItemset(items=['Lingmei Jiang', 'Lixin Zhang'], freq=22),
#  FreqItemset(items=['Vijay Kumar'], freq=349),
#  FreqItemset(items=['Nicholas Carriero'], freq=32),
#  FreqItemset(items=['Nicholas Carriero', 'David Gelernter'], freq=23),
#  FreqItemset(items=['Ki Hwan Yum'], freq=30),
#  FreqItemset(items=['Ki Hwan Yum', 'Eun Jung Kim'], freq=28),
#  FreqItemset(items=['Po-Han Wu'], freq=28),
#  FreqItemset(items=['Christian M. Reidys'], freq=30),
#  FreqItemset(items=['Jingyue Li'], freq=35),
#  FreqItemset(items=['Jingyue Li', 'Reidar Conradi'], freq=31),
#  FreqItemset(items=['Claudio Turchetti'], freq=44),
#  FreqItemset(items=['Spiros Skiadopoulos'], freq=40),
#  FreqItemset(items=['Joseph M. Kahn'], freq=36),
#  FreqItemset(items=['Liang Gu'], freq=34),
#  FreqItemset(items=['Hui Lei'], freq=59),
#  FreqItemset(items=['Misha Tsodyks'], freq=22),
#  FreqItemset(items=['Paul Dalsgaard'], freq=41),
#  FreqItemset(items=['Matthew Ming-Fai Yuen'], freq=46),
#  FreqItemset(items=['Steven Schockaert'], freq=58),
#  FreqItemset(items=['Steven Schockaert', 'Martine De Cock'], freq=38),
#  FreqItemset(items=['Martin Sauerhoff'], freq=34),
#  FreqItemset(items=['Zhihui Wang'], freq=23),
#  FreqItemset(items=['Henrik Boström'], freq=45),
#  FreqItemset(items=['Ralf Mikut'], freq=22),
#  FreqItemset(items=['George Chryssolouris'], freq=22),
#  FreqItemset(items=['Yoichi Muraoka'], freq=62),
#  FreqItemset(items=['Leonidas Georgiadis'], freq=64),
#  FreqItemset(items=['Shin-ichi Tanigawa'], freq=25),
#  FreqItemset(items=['Debargha Mukherjee'], freq=47),
#  FreqItemset(items=['Stanley Osher'], freq=95),
#  FreqItemset(items=['Changle Li'], freq=23),
#  FreqItemset(items=['Hiroshi Shigeno'], freq=61),
#  FreqItemset(items=['Hiroshi Shigeno', 'Ken-ichi Okada'], freq=36),
#  FreqItemset(items=['Rajat Subhra Chakraborty'], freq=27),
#  FreqItemset(items=['Rajat Subhra Chakraborty', 'Swarup Bhunia'], freq=22),
#  FreqItemset(items=['Frank Vetere'], freq=63),
#  FreqItemset(items=['Frank Vetere', 'Steve Howard'], freq=27),
#  FreqItemset(items=['Shen-Fu Hsiao'], freq=25),
#  FreqItemset(items=['Walfredo Cirne'], freq=54),
#  FreqItemset(items=['Walfredo Cirne', 'Francisco Vilar Brasileiro'], freq=23),
#  FreqItemset(items=['Robin Sommer'], freq=24),
#  FreqItemset(items=['David T. Barnard'], freq=22),
#  FreqItemset(items=['Paul Davidsson'], freq=79),
#  FreqItemset(items=['Chai Quek'], freq=102),
#  FreqItemset(items=['Bertil Svensson'], freq=30),
#  FreqItemset(items=['Dieter Merkl'], freq=81),
#  FreqItemset(items=['Dieter Merkl', 'Andreas Rauber'], freq=31),
#  FreqItemset(items=['Rainer Keller'], freq=27),
#  FreqItemset(items=['Frédéric Valette'], freq=26),
#  FreqItemset(items=['Burak Kantarci'], freq=24),
#  FreqItemset(items=['Xiaodong Huang'], freq=29),
#  FreqItemset(items=['Zhenmin Tang'], freq=26),
#  FreqItemset(items=['Ning Zhong'], freq=303),
#  FreqItemset(items=['Kyung-Yong Chwa'], freq=86),
#  FreqItemset(items=['Xiaofeng He'], freq=30),
#  FreqItemset(items=['Xiaofeng He', 'Chris H. Q. Ding'], freq=25),
#  FreqItemset(items=['Johan F. Hoorn'], freq=28),
#  FreqItemset(items=['Rida A. Bazzi'], freq=45),
#  FreqItemset(items=['Ricardo Silva'], freq=37),
#  FreqItemset(items=['Chuan Lin'], freq=33),
#  FreqItemset(items=["Eamonn O'Neill"], freq=44),
#  FreqItemset(items=['Wen-Hsiao Peng'], freq=29),
#  FreqItemset(items=['Chieko Asakawa'], freq=40),
#  FreqItemset(items=['Yiping Ke'], freq=33),
#  FreqItemset(items=['Yiping Ke', 'James Cheng'], freq=25),
#  FreqItemset(items=['Guy Kindler'], freq=36),
#  FreqItemset(items=['Paz Morillo'], freq=34),
#  FreqItemset(items=['Cishen Zhang'], freq=60),
#  FreqItemset(items=['Cishen Zhang', 'Lihua Xie'], freq=25),
#  FreqItemset(items=['Mohammed Belkhatir'], freq=45),
#  FreqItemset(items=['Michel Buffa'], freq=22),
#  FreqItemset(items=['Sven Schuierer'], freq=46),
#  FreqItemset(items=['Emmanuel C. Ifeachor'], freq=41),
#  FreqItemset(items=['Jianjun Hu'], freq=37),
#  FreqItemset(items=['Antti Valmari'], freq=59),
#  FreqItemset(items=['Young-Chon Kim'], freq=34),
#  FreqItemset(items=['Huafei Zhu'], freq=63),
#  FreqItemset(items=['Huafei Zhu', 'Feng Bao'], freq=26),
#  FreqItemset(items=['Joaquín J. Torres'], freq=25),
#  FreqItemset(items=['Herman Schmit'], freq=48),
#  FreqItemset(items=['Victor L. Selivanov'], freq=55),
#  FreqItemset(items=['Stanimire Tomov'], freq=39),
#  FreqItemset(items=['Stanimire Tomov', 'Jack Dongarra'], freq=28),
#  FreqItemset(items=['Claudia Löbbecke'], freq=23),
#  FreqItemset(items=['Tamás Szonyi'], freq=25),
#  FreqItemset(items=['Stephen Winters-Hilt'], freq=23),
#  FreqItemset(items=['Marcel J. T. Reinders'], freq=109),
#  FreqItemset(items=['Patrice Godefroid'], freq=81),
#  FreqItemset(items=['Diana Göhringer'], freq=26),
#  FreqItemset(items=['Diana Göhringer', 'Jürgen Becker'], freq=23),
#  FreqItemset(items=['Bruno Buchberger'], freq=57),
#  FreqItemset(items=['Umeshwar Dayal'], freq=225),
#  FreqItemset(items=['Umeshwar Dayal', 'Daniel A. Keim'], freq=26),
#  FreqItemset(items=['George O. Wesolowsky'], freq=25),
#  FreqItemset(items=['Ojas Parekh'], freq=26),
#  FreqItemset(items=['Pedro López'], freq=105),
#  FreqItemset(items=['Pedro López', 'José Duato'], freq=87),
#  FreqItemset(items=['Stefanie N. Lindstaedt'], freq=79),
#  FreqItemset(items=['Zheng Yuan'], freq=30),
#  FreqItemset(items=['Bernhard Westfechtel'], freq=83),
#  FreqItemset(items=['Stephen J. McKenna'], freq=56),
#  FreqItemset(items=['Yeong-Dae Kim'], freq=24),
#  FreqItemset(items=['Yogesh Simmhan'], freq=26),
#  FreqItemset(items=['Tun-Wen Pai'], freq=28),
#  FreqItemset(items=['Krishna R. Pattipati'], freq=90),
#  FreqItemset(items=['André Schulz'], freq=36),
#  FreqItemset(items=['Elizabeth A. Kemp'], freq=33),
#  FreqItemset(items=['Immanuel M. Bomze'], freq=30),
#  FreqItemset(items=['Ibrahim Matta'], freq=88),
#  FreqItemset(items=['Ibrahim Matta', 'Azer Bestavros'], freq=32),
#  FreqItemset(items=['Steven D. Johnson'], freq=28),
#  FreqItemset(items=['Boting Yang'], freq=45),
#  FreqItemset(items=['Eugenio Roanes-Lozano'], freq=36),
#  FreqItemset(items=['Karl-Friedrich Kraiss'], freq=37),
#  FreqItemset(items=['Hamid Mahmoodi'], freq=34),
#  FreqItemset(items=['Tatsuya Kawahara'], freq=149),
#  FreqItemset(items=['Robert Marti'], freq=45),
#  FreqItemset(items=['Robert Marti', 'Arnau Oliver'], freq=28),
#  FreqItemset(items=['Igor Melatti'], freq=29),
#  FreqItemset(items=['Igor Melatti', 'Enrico Tronci'], freq=24),
#  FreqItemset(items=['Bart Mesman'], freq=46),
#  FreqItemset(items=['Bart Mesman', 'Henk Corporaal'], freq=30),
#  FreqItemset(items=['Konstantinos Votis'], freq=22),
#  FreqItemset(items=['Adolfy Hoisie'], freq=42),
#  FreqItemset(items=['Minghui Wu'], freq=38),
#  FreqItemset(items=['John D. Kececioglu'], freq=32),
#  FreqItemset(items=['Negar Kiyavash'], freq=42),
#  FreqItemset(items=['G. Tanner Jackson'], freq=22),
#  FreqItemset(items=['A. Jefferson Offutt'], freq=55),
#  FreqItemset(items=['Chung-Min Chen'], freq=43),
#  FreqItemset(items=['C. Paul Bonnington'], freq=22),
#  FreqItemset(items=['Stéphan Thomassé'], freq=64),
#  FreqItemset(items=['Hiroshi Saito'], freq=54),
#  FreqItemset(items=['Hong Ji'], freq=56),
#  FreqItemset(items=['Ted Bapty'], freq=26),
#  FreqItemset(items=['Gary M. Olson'], freq=43),
#  FreqItemset(items=['Gary M. Olson', 'Judith S. Olson'], freq=24),
#  FreqItemset(items=['Yevgeniy Bodyanskiy'], freq=23),
#  FreqItemset(items=['Fuhui Long'], freq=22),
#  FreqItemset(items=['Fuhui Long', 'Hanchuan Peng'], freq=22),
#  FreqItemset(items=['Paulo Ferreira'], freq=85),
#  FreqItemset(items=['Beno Benhabib'], freq=59),
#  FreqItemset(items=['Lian Li'], freq=83),
#  FreqItemset(items=['Franco Turini'], freq=114),
#  FreqItemset(items=['Franco Turini', 'Dino Pedreschi'], freq=25),
#  FreqItemset(items=['Görschwin Fey'], freq=70),
#  FreqItemset(items=['Görschwin Fey', 'Rolf Drechsler'], freq=59),
#  FreqItemset(items=['Y. Thomas Hou'], freq=58),
#  FreqItemset(items=['Y. Thomas Hou', 'Yi Shi'], freq=37),
#  FreqItemset(items=['Jean-Pierre Jessel'], freq=26),
#  FreqItemset(items=['Richard A. Brualdi'], freq=52),
#  FreqItemset(items=['Tineke M. Egyedi'], freq=23),
#  FreqItemset(items=['Javier González'], freq=25),
#  FreqItemset(items=['Shi Wang'], freq=28),
#  FreqItemset(items=['Sagi Snir'], freq=36),
#  FreqItemset(items=['Dan Zhang'], freq=127),
#  FreqItemset(items=['Johannes Uhlmann'], freq=31),
#  FreqItemset(items=['Eric W. Brown'], freq=28),
#  FreqItemset(items=['Nobuko Yoshida'], freq=93),
#  FreqItemset(items=['P. John Clarkson'], freq=72),
#  FreqItemset(items=['Davide Adami'], freq=36),
#  FreqItemset(items=['Davide Adami', 'Stefano Giordano'], freq=33),
#  FreqItemset(items=['Davide Adami', 'Michele Pagano'], freq=24),
#  FreqItemset(items=['Davide Adami', 'Michele Pagano', 'Stefano Giordano'], freq=24),
#  FreqItemset(items=['James F. Geelen'], freq=25),
#  FreqItemset(items=['Jean-Paul Jamont'], freq=33),
#  FreqItemset(items=['Jean-Paul Jamont', 'Michel Occello'], freq=29),
#  FreqItemset(items=['Nikhil Jayakumar'], freq=28),
#  FreqItemset(items=['Nikhil Jayakumar', 'Sunil P. Khatri'], freq=27),
#  FreqItemset(items=['K. S. Fu'], freq=31),
#  FreqItemset(items=['Loren G. Terveen'], freq=90),
#  FreqItemset(items=['Eric Pacuit'], freq=29),
#  FreqItemset(items=['Roberto Musmanno'], freq=25),
#  FreqItemset(items=['Francisco J. Pino'], freq=34),
#  FreqItemset(items=['Francisco J. Pino', 'Félix García'], freq=24),
#  FreqItemset(items=['Francisco J. Pino', 'Félix García', 'Mario Piattini'], freq=24),
#  FreqItemset(items=['Francisco J. Pino', 'Mario Piattini'], freq=30),
#  FreqItemset(items=['Peter Z. Yeh'], freq=29),
#  FreqItemset(items=['Ali Tajer'], freq=37),
#  FreqItemset(items=['Ali Tajer', 'Xiaodong Wang'], freq=30),
#  FreqItemset(items=['Yvan Bédard'], freq=34),
#  FreqItemset(items=['Michael Gribskov'], freq=29),
#  FreqItemset(items=['Chorng-Shyong Ong'], freq=42),
#  FreqItemset(items=['Youssef Nasser'], freq=35),
#  FreqItemset(items=['Youssef Nasser', 'Jean-François Hélard'], freq=24),
#  FreqItemset(items=['Laurent El Ghaoui'], freq=47),
#  FreqItemset(items=['Maria Luiza Machado Campos'], freq=42),
#  FreqItemset(items=['Pedro Sánchez'], freq=38),
#  FreqItemset(items=['José Luis Alba-Castro'], freq=43),
#  FreqItemset(items=['Marjan Krisper'], freq=23),
#  FreqItemset(items=['Zhenchang Xing'], freq=32),
#  FreqItemset(items=['Xudong Jiang'], freq=66),
#  FreqItemset(items=['Alexander Zeier'], freq=56),
#  FreqItemset(items=['Max Bramer'], freq=50),
#  FreqItemset(items=['Maarten M. Fokkinga'], freq=23),
#  FreqItemset(items=['Cheeha Kim'], freq=44),
#  FreqItemset(items=['Rayadurgam Srikant'], freq=22),
#  FreqItemset(items=['Will Tracz'], freq=40),
#  FreqItemset(items=['Per Löwenborg'], freq=22),
#  FreqItemset(items=['Peter B. Henderson'], freq=87),
#  FreqItemset(items=['Pranav Ashar'], freq=60),
#  FreqItemset(items=['Pranav Ashar', 'Aarti Gupta'], freq=29),
#  FreqItemset(items=['Patrick Bourdot'], freq=25),
#  FreqItemset(items=['Sumi Helal'], freq=51),
#  FreqItemset(items=['Peter Tarasewich'], freq=30),
#  FreqItemset(items=['Luciano Milanesi'], freq=85),
#  FreqItemset(items=['Carla Manni'], freq=28),
#  FreqItemset(items=['Lucas Layman'], freq=22),
#  FreqItemset(items=['Niels Bjørn-Andersen'], freq=41),
#  FreqItemset(items=['Ana M. D. Moreira'], freq=26),
#  FreqItemset(items=['Ryutaroh Matsumoto'], freq=59),
#  FreqItemset(items=['Vladimir Nikulin'], freq=24),
#  FreqItemset(items=['Kazuhiro Ohkura'], freq=25),
#  FreqItemset(items=['Marilyn M. Mantei'], freq=22),
#  FreqItemset(items=['Pankaj Jalote'], freq=92),
#  FreqItemset(items=['Char-Dir Chung'], freq=29),
#  FreqItemset(items=['Chi-Ying Tsui'], freq=99),
#  FreqItemset(items=['Weidong Zhao'], freq=37),
#  FreqItemset(items=['Shanwen Zhang'], freq=25),
#  FreqItemset(items=['Ying-Hong Wang'], freq=90),
#  FreqItemset(items=['K. G. Srinivasa'], freq=31),
#  FreqItemset(items=['K. G. Srinivasa', 'K. R. Venugopal'], freq=24),
#  FreqItemset(items=['K. G. Srinivasa', 'K. R. Venugopal', 'Lalit M. Patnaik'], freq=23),
#  FreqItemset(items=['K. G. Srinivasa', 'Lalit M. Patnaik'], freq=23),
#  FreqItemset(items=['Paul C. Bressloff'], freq=29),
#  FreqItemset(items=['Peter J. Haas'], freq=74),
#  FreqItemset(items=['Laurent Girin'], freq=27),
#  FreqItemset(items=['James Graham'], freq=25),
#  FreqItemset(items=['Peng Hu'], freq=24),
#  FreqItemset(items=['Sung-Ho Kim'], freq=37),
#  FreqItemset(items=['Guangyu Zhu'], freq=35),
#  FreqItemset(items=['Diane J. Cook'], freq=201),
#  FreqItemset(items=['Edward Dobson'], freq=27),
#  FreqItemset(items=['Kuntal Sengupta'], freq=34),
#  FreqItemset(items=['Kazunori Yamaguchi'], freq=43),
#  FreqItemset(items=['Dieter Spreen'], freq=35),
#  FreqItemset(items=['Henri Prade'], freq=391),
#  FreqItemset(items=['Kamal Premaratne'], freq=33),
#  FreqItemset(items=['Pascal Ochem'], freq=42),
#  FreqItemset(items=['Werner Bailer'], freq=43),
#  FreqItemset(items=['Walter L. Ruzzo'], freq=58),
#  FreqItemset(items=['Jürgen Hesser'], freq=40),
#  FreqItemset(items=['Jürgen Hesser', 'Reinhard Männer'], freq=26),
#  FreqItemset(items=['Pawel Zielinski'], freq=45),
#  FreqItemset(items=['Chenyi Hu'], freq=22),
#  FreqItemset(items=['Nina Taft'], freq=57),
#  FreqItemset(items=['Thomas W. Williams'], freq=51),
#  FreqItemset(items=['Thomas W. Williams', 'Rohit Kapur'], freq=25),
#  FreqItemset(items=['Jean-Luc Marichal'], freq=44),
#  FreqItemset(items=['Eduardo Blanco'], freq=22),
#  FreqItemset(items=['Glenn J. Browne'], freq=23),
#  FreqItemset(items=['Daniel Tihelka'], freq=22),
#  FreqItemset(items=['Christian Piguet'], freq=41),
#  FreqItemset(items=['Martin Alt'], freq=24),
#  FreqItemset(items=['Juha Honkala'], freq=89),
#  FreqItemset(items=['Derek Partridge'], freq=59),
#  FreqItemset(items=['Roberto Setola'], freq=27),
#  FreqItemset(items=['Jiashu Zhang'], freq=52),
#  FreqItemset(items=['Cees J. H. Midden'], freq=25),
#  FreqItemset(items=['Zhong Li'], freq=61),
#  FreqItemset(items=['Miguel A. Atencia Ruiz'], freq=24),
#  FreqItemset(items=['Miguel A. Atencia Ruiz', 'Gonzalo Joya Caparrós'], freq=22),
#  FreqItemset(items=['John Power'], freq=87),
#  FreqItemset(items=['Mateja Jamnik'], freq=22),
#  FreqItemset(items=['Kai-Uwe Sattler'], freq=157),
#  FreqItemset(items=['Kai-Uwe Sattler', 'Gunter Saake'], freq=28),
#  FreqItemset(items=['Takashi Watanabe'], freq=95),
#  FreqItemset(items=['Heming Zhang'], freq=29),
#  FreqItemset(items=['David P. Helmbold'], freq=64),
#  FreqItemset(items=['Giuseppe Manco'], freq=77),
#  FreqItemset(items=['Giuseppe Manco', 'Fosca Giannotti'], freq=28),
#  FreqItemset(items=['Riccardo Marino'], freq=24),
#  FreqItemset(items=['David L. Buckeridge'], freq=26),
#  FreqItemset(items=['Young-Rae Cho'], freq=29),
#  FreqItemset(items=['Young-Rae Cho', 'Aidong Zhang'], freq=22),
#  FreqItemset(items=['Jakob Nordström'], freq=25),
#  FreqItemset(items=['Carlo Cattani'], freq=35),
#  FreqItemset(items=['Rajeev Motwani'], freq=195),
#  FreqItemset(items=['Lingfang Zeng'], freq=35),
#  FreqItemset(items=['Lingfang Zeng', 'Dan Feng'], freq=32),
#  FreqItemset(items=['Lu Ruan'], freq=30),
#  FreqItemset(items=['Maria Cecília Calani Baranauskas'], freq=81),
#  FreqItemset(items=['Roberto Caldelli'], freq=28),
#  FreqItemset(items=['Sourav Chakraborty'], freq=34),
#  FreqItemset(items=['Xin Jin'], freq=174),
#  FreqItemset(items=['Xin Jin', 'Jiawei Han'], freq=30),
#  FreqItemset(items=['Xin Jin', 'Satoshi Goto'], freq=22),
#  FreqItemset(items=['Anders I. Mørch'], freq=35),
#  FreqItemset(items=['Daniel A. Keim'], freq=247),
#  FreqItemset(items=['Flavien Balbo'], freq=32),
#  FreqItemset(items=['Zixue Cheng'], freq=79),
#  FreqItemset(items=['Reino Kurki-Suonio'], freq=28),
#  FreqItemset(items=['Bertrand Thirion'], freq=49),
#  FreqItemset(items=['Kohtaro Tadaki'], freq=43),
#  FreqItemset(items=['Zoran Milosevic'], freq=40),
#  FreqItemset(items=['Siome Goldenstein'], freq=36),
#  FreqItemset(items=['Brendan Tangney'], freq=33),
#  FreqItemset(items=['Ranga Raju Vatsavai'], freq=58),
#  FreqItemset(items=["Paolo Dell'Olmo"], freq=45),
#  FreqItemset(items=['S. Q. Zheng'], freq=40),
#  FreqItemset(items=['Martin R. Frank'], freq=22),
#  FreqItemset(items=['Luc Brun'], freq=58),
#  FreqItemset(items=['David C. Keezer'], freq=45),
#  FreqItemset(items=['Sheng-Ta Hsieh'], freq=22),
#  FreqItemset(items=['Ingo Schmitt'], freq=61),
#  FreqItemset(items=['Tania Cerquitelli'], freq=25),
#  FreqItemset(items=['Tania Cerquitelli', 'Elena Baralis'], freq=23),
#  FreqItemset(items=['Stefan Tai'], freq=54),
#  FreqItemset(items=['E. F. Codd'], freq=47),
#  FreqItemset(items=['Olli Vainio'], freq=22),
#  FreqItemset(items=['Ki-Dong Lee'], freq=25),
#  FreqItemset(items=['Paul Buitelaar'], freq=53),
#  FreqItemset(items=['Morio Yoshida'], freq=24),
#  FreqItemset(items=['Morio Yoshida', 'Suguru Arimoto'], freq=22),
#  FreqItemset(items=['Jean-Pierre Nadal'], freq=22),
#  FreqItemset(items=['Michael R. Berthold'], freq=77),
#  FreqItemset(items=['Hongen Liao'], freq=55),
#  FreqItemset(items=['Hongen Liao', 'Takeyoshi Dohi'], freq=38),
#  FreqItemset(items=['Hongen Liao', 'Ichiro Sakuma'], freq=26),
#  FreqItemset(items=['Inkyu Lee'], freq=172),
#  FreqItemset(items=['Christian Sohler'], freq=75),
#  FreqItemset(items=['Christian Sohler', 'Artur Czumaj'], freq=33),
#  FreqItemset(items=['Zhiyong Liu'], freq=98),
#  FreqItemset(items=['Célia A. Zorzo Barcelos'], freq=29),
#  FreqItemset(items=['Enrico Pagello'], freq=79),
#  FreqItemset(items=['Wei Qian'], freq=25),
#  FreqItemset(items=['Phee Lep Yeoh'], freq=24),
#  FreqItemset(items=['Phee Lep Yeoh', 'Maged Elkashlan'], freq=24),
#  FreqItemset(items=['Albert Y. Zomaya'], freq=309),
#  FreqItemset(items=['Albert Y. Zomaya', 'Stephan Olariu'], freq=37),
#  FreqItemset(items=['Mao Lin Huang'], freq=86),
#  FreqItemset(items=['Dennis Sylvester'], freq=232),
#  FreqItemset(items=['Dennis Sylvester', 'David Blaauw'], freq=153),
#  FreqItemset(items=['Sylvie Gibet'], freq=35),
#  FreqItemset(items=['Michael A. Heroux'], freq=33),
#  FreqItemset(items=['Alejandro López-Ortiz'], freq=119),
#  FreqItemset(items=['Lucas C. Parra'], freq=30),
#  FreqItemset(items=['Toshiyuki Tanaka'], freq=84),
#  FreqItemset(items=['Eduardo de la Torre'], freq=26),
#  FreqItemset(items=['Eduardo de la Torre', 'Teresa Riesgo'], freq=25),
#  FreqItemset(items=['Yoshinobu Hotta'], freq=28),
#  FreqItemset(items=['Patrice Abry'], freq=44),
#  FreqItemset(items=['Rini van Solingen'], freq=33),
#  FreqItemset(items=['PooGyeon Park'], freq=36),
#  FreqItemset(items=['Amedeo Napoli'], freq=132),
#  FreqItemset(items=['Lior Pachter'], freq=44),
#  FreqItemset(items=['Rita Singh'], freq=29),
#  FreqItemset(items=['Rita Singh', 'Bhiksha Raj'], freq=22),
#  FreqItemset(items=['David Smith'], freq=40),
#  FreqItemset(items=['Yoko Uwate'], freq=36),
#  FreqItemset(items=['Yoko Uwate', 'Yoshifumi Nishio'], freq=36),
#  FreqItemset(items=['Carlo Curino'], freq=33),
#  FreqItemset(items=['Tetsuya Hirose'], freq=34),
#  FreqItemset(items=['Haruhisa Kurokawa'], freq=28),
#  FreqItemset(items=['Haruhisa Kurokawa', 'Kohji Tomita'], freq=24),
#  FreqItemset(items=['Haruhisa Kurokawa', 'Kohji Tomita', 'Satoshi Murata'], freq=22),
#  FreqItemset(items=['Haruhisa Kurokawa', 'Satoshi Murata'], freq=25),
#  FreqItemset(items=['Jyrki Lötjönen'], freq=41),
#  FreqItemset(items=['Hanghang Tong'], freq=59),
#  FreqItemset(items=['Hanghang Tong', 'Christos Faloutsos'], freq=27),
#  FreqItemset(items=['Jonathan P. How'], freq=46),
#  FreqItemset(items=['Alessandro Rizzo'], freq=23),
#  FreqItemset(items=['Xiang Bai'], freq=41),
#  FreqItemset(items=['Xiang Bai', 'Wenyu Liu'], freq=25),
#  FreqItemset(items=['Xiang Bai', 'Longin Jan Latecki'], freq=25),
#  FreqItemset(items=['Andreas Stein'], freq=22),
#  FreqItemset(items=['Zhenjiang Miao'], freq=53),
#  FreqItemset(items=['Fei Xia'], freq=91),
#  FreqItemset(items=['Fei Xia', 'Alexandre Yakovlev'], freq=29),
#  FreqItemset(items=['Bo Huang'], freq=75),
#  FreqItemset(items=['Bruce Hendrickson'], freq=62),
#  FreqItemset(items=['George Weiss'], freq=25),
#  FreqItemset(items=['Xiaochun Cao'], freq=47),
#  FreqItemset(items=['Shih-Lien Lu'], freq=54),
#  FreqItemset(items=['Laurent Amanton'], freq=23),
#  FreqItemset(items=['Chung-Nan Lee'], freq=22),
#  FreqItemset(items=['Christine Strauss'], freq=57),
#  FreqItemset(items=['Driss Aboutajdine'], freq=106),
#  FreqItemset(items=['Esteban Feuerstein'], freq=29),
#  FreqItemset(items=['Marcos Faúndez-Zanuy'], freq=79),
#  FreqItemset(items=['Henry C. M. Leung'], freq=28),
#  FreqItemset(items=['Henry C. M. Leung', 'Francis Y. L. Chin'], freq=26),
#  FreqItemset(items=['Thomas Stockhammer'], freq=56),
#  FreqItemset(items=['Andrei Sherstyuk'], freq=26),
#  FreqItemset(items=['Gonzalo López-Nicolás'], freq=24),
#  FreqItemset(items=['Gonzalo López-Nicolás', 'Carlos Sagüés'], freq=22),
#  FreqItemset(items=['Volker Warnke'], freq=23),
#  FreqItemset(items=['Panayotis Tsanakas'], freq=50),
#  FreqItemset(items=['Panayotis Tsanakas', 'George K. Papakonstantinou'], freq=35),
#  FreqItemset(items=['Romit Roy Choudhury'], freq=77),
#  FreqItemset(items=['Wen-Jiin Tsai'], freq=27),
#  FreqItemset(items=['Tetsuya Higuchi'], freq=81),
#  FreqItemset(items=['Emanuele Salerno'], freq=24),
#  FreqItemset(items=['Henryk Wozniakowski'], freq=88),
#  FreqItemset(items=['Steve Mann'], freq=70),
#  FreqItemset(items=['Kil To Chong'], freq=28),
#  FreqItemset(items=['Hao Zhang'], freq=315),
#  FreqItemset(items=['Wenzhong Shi'], freq=35),
#  FreqItemset(items=['Hugo Miranda'], freq=25),
#  FreqItemset(items=['Chandrika Kamath'], freq=33),
#  FreqItemset(items=['Takayuki Nakamura'], freq=28),
#  FreqItemset(items=['Robert C. Bolles'], freq=30),
#  FreqItemset(items=['Worthy N. Martin'], freq=28),
#  FreqItemset(items=['Clémence Magnien'], freq=34),
#  FreqItemset(items=['Clémence Magnien', 'Matthieu Latapy'], freq=26),
#  FreqItemset(items=['Cédric Richard'], freq=45),
#  FreqItemset(items=['Oliver Stein'], freq=29),
#  FreqItemset(items=['Ihsin T. Phillips'], freq=33),
#  FreqItemset(items=['Ihsin T. Phillips', 'Robert M. Haralick'], freq=26),
#  FreqItemset(items=['Luis Gómez-Chova'], freq=37),
#  FreqItemset(items=['Luis Gómez-Chova', 'Gustavo Camps-Valls'], freq=29),
#  FreqItemset(items=['Wojciech Kabacinski'], freq=31),
#  FreqItemset(items=['Lirong Xia'], freq=46),
#  FreqItemset(items=['Lirong Xia', 'Vincent Conitzer'], freq=22),
#  FreqItemset(items=['Jang-Won Lee'], freq=42),
#  FreqItemset(items=['Daniele Falavigna'], freq=38),
#  FreqItemset(items=['Nadia Ranaldo'], freq=22),
#  FreqItemset(items=['Juan A. Montiel-Nelson'], freq=32),
#  FreqItemset(items=['Juan A. Montiel-Nelson', 'Saeid Nooshabadi'], freq=23),
#  FreqItemset(items=['Juan R. Rabuñal'], freq=41),
#  FreqItemset(items=['Juan R. Rabuñal', 'Julian Dorado'], freq=32),
#  FreqItemset(items=['Bernard Manderick'], freq=54),
#  FreqItemset(items=['Gilles Venturini'], freq=56),
#  FreqItemset(items=['Pavol Duris'], freq=43),
#  FreqItemset(items=['Sheng Ma'], freq=77),
#  FreqItemset(items=['James Ohene-Djan'], freq=22),
#  FreqItemset(items=['Garrison W. Greenwood'], freq=39),
#  FreqItemset(items=['Jesper Kjeldskov'], freq=53),
#  FreqItemset(items=['Sergio Antoy'], freq=55),
#  FreqItemset(items=['Josef Widder'], freq=25),
#  FreqItemset(items=['Dimitris Bertsimas'], freq=83),
#  FreqItemset(items=['David Jensen'], freq=58),
#  FreqItemset(items=['Gérald Oster'], freq=24),
#  FreqItemset(items=['David J. Kasik'], freq=30),
#  FreqItemset(items=['Naehyuck Chang'], freq=110),
#  FreqItemset(items=['Naehyuck Chang', 'Massoud Pedram'], freq=22),
#  FreqItemset(items=['Fabrizio Sebastiani'], freq=81),
#  FreqItemset(items=['Seiichi Sampei'], freq=28),
#  FreqItemset(items=['Erich Barke'], freq=68),
#  FreqItemset(items=['Lisa Hellerstein'], freq=57),
#  FreqItemset(items=['Grégoire Sutre'], freq=26),
#  FreqItemset(items=['Jeong-A. Lee'], freq=25),
#  FreqItemset(items=['Yacov Y. Haimes'], freq=23),
#  FreqItemset(items=['Ettore Merlo'], freq=87),
#  FreqItemset(items=['Ettore Merlo', 'Giuliano Antoniol'], freq=42),
#  FreqItemset(items=['Xin Liu'], freq=290),
#  FreqItemset(items=['Philip H. S. Torr'], freq=123),
#  FreqItemset(items=['Philip H. S. Torr', 'Andrew Zisserman'], freq=27),
#  FreqItemset(items=['Yangqiu Song'], freq=36),
#  FreqItemset(items=['Yangqiu Song', 'Changshui Zhang'], freq=22),
#  FreqItemset(items=['Girija J. Narlikar'], freq=25),
#  FreqItemset(items=['Behrouz Farhang-Boroujeny'], freq=71),
#  FreqItemset(items=['Mikael Rönnqvist'], freq=28),
#  FreqItemset(items=['Ovidiu Ghita'], freq=31),
#  FreqItemset(items=['Ovidiu Ghita', 'Paul F. Whelan'], freq=31),
#  FreqItemset(items=['Alex Yakovlev'], freq=27),
#  FreqItemset(items=['Auroop R. Ganguly'], freq=25),
#  FreqItemset(items=['Aomar Osmani'], freq=24),
#  FreqItemset(items=['Serge Gratton'], freq=29),
#  FreqItemset(items=['Hu Yang'], freq=34),
#  FreqItemset(items=['Yannis E. Ioannidis'], freq=163),
#  FreqItemset(items=['Agostino Forestiero'], freq=31),
#  FreqItemset(items=['Agostino Forestiero', 'Giandomenico Spezzano'], freq=23),
#  FreqItemset(items=['Charles R. McLean'], freq=27),
#  FreqItemset(items=['Ankur Jain'], freq=34),
#  FreqItemset(items=['Hong Man'], freq=54),
#  FreqItemset(items=['Michael Kipp'], freq=42),
#  FreqItemset(items=['Klaus-Peter Löhr'], freq=43),
#  FreqItemset(items=['Ann E. Kelley Sobel'], freq=35),
#  FreqItemset(items=['Feng Zhao'], freq=205),
#  FreqItemset(items=['Feng Zhao', 'Jie Liu'], freq=32),
#  FreqItemset(items=['Gerhard Krieger'], freq=53),
#  FreqItemset(items=['Fabio Valente'], freq=41),
#  FreqItemset(items=['Franck Davoine'], freq=38),
#  FreqItemset(items=['Carlos Delgado-Mata'], freq=22),
#  FreqItemset(items=['Andreas Schaad'], freq=42),
#  FreqItemset(items=['John Snyder'], freq=32),
#  FreqItemset(items=['Fahiem Bacchus'], freq=101),
#  FreqItemset(items=['Nicolas Villar'], freq=44),
#  FreqItemset(items=['Chiori Hori'], freq=55),
#  FreqItemset(items=['Chiori Hori', 'Satoshi Nakamura'], freq=22),
#  FreqItemset(items=['Chiori Hori', 'Hideki Kashioka'], freq=29),
#  FreqItemset(items=['S. Trent Rosenbloom'], freq=25),
#  FreqItemset(items=['Dongmei Zhao'], freq=65),
#  FreqItemset(items=['Carlo Novara'], freq=24),
#  FreqItemset(items=['Masanori Hariyama'], freq=49),
#  FreqItemset(items=['Masanori Hariyama', 'Michitaka Kameyama'], freq=48),
#  FreqItemset(items=['Pei-Yu Chen'], freq=23),
#  FreqItemset(items=['E. Burton Swanson'], freq=43),
#  FreqItemset(items=['Meliha Handzic'], freq=22),
#  FreqItemset(items=['Hubert Cardot'], freq=40),
#  FreqItemset(items=['Zhigang Luo'], freq=24),
#  FreqItemset(items=['Yuqing Sun'], freq=22),
#  FreqItemset(items=['José Antonio Lozano'], freq=85),
#  FreqItemset(items=['José Antonio Lozano', 'Pedro Larrañaga'], freq=46),
#  FreqItemset(items=['Esther Ezra'], freq=25),
#  FreqItemset(items=['Bernard Tourancheau'], freq=59),
#  FreqItemset(items=['Gerardo Schneider'], freq=51),
#  FreqItemset(items=['Adel Ben Mnaouer'], freq=23),
#  FreqItemset(items=['Bruno Dutertre'], freq=25),
#  FreqItemset(items=['Matt Jones'], freq=83),
#  FreqItemset(items=['Yongchang Ji'], freq=22),
#  FreqItemset(items=['Bram Kruseman'], freq=28),
#  FreqItemset(items=['Mario Zagar'], freq=25),
#  FreqItemset(items=['Thomas Sikora'], freq=138),
#  FreqItemset(items=['Enhong Chen'], freq=90),
#  FreqItemset(items=['Theodoros Salonidis'], freq=29),
#  FreqItemset(items=['Erwin P. Rathgeb'], freq=74),
#  FreqItemset(items=['Harvey J. Wasserman'], freq=25),
#  FreqItemset(items=['Moon Ho Lee'], freq=130),
#  FreqItemset(items=['Pu Liu'], freq=31),
#  FreqItemset(items=['Ronald Peikert'], freq=28),
#  FreqItemset(items=['John Kubiatowicz'], freq=73),
#  FreqItemset(items=['Robert J. Webster III'], freq=27),
#  FreqItemset(items=['Sanjay Kumar Madria'], freq=159),
#  FreqItemset(items=['Sanjay Kumar Madria', 'Wee Keong Ng'], freq=22),
#  FreqItemset(items=['Chantal Ykman-Couvreur'], freq=34),
#  FreqItemset(items=['Sangyoon Lee'], freq=34),
#  FreqItemset(items=['Gérard G. Medioni'], freq=180),
#  FreqItemset(items=['J. Xu'], freq=32),
#  FreqItemset(items=['R. S. Ramakrishna'], freq=27),
#  FreqItemset(items=['Alberto L. Morán'], freq=42),
#  FreqItemset(items=['Shuang Li'], freq=39),
#  FreqItemset(items=['Bart Kosko'], freq=35),
#  FreqItemset(items=['Tobias Koch'], freq=33),
#  FreqItemset(items=['Vojtech Svátek'], freq=57),
#  FreqItemset(items=['Teresa A. Dahlberg'], freq=24),
#  FreqItemset(items=['Adonios Thanailakis'], freq=44),
#  FreqItemset(items=['Adonios Thanailakis', 'Dimitrios Soudris'], freq=23),
#  FreqItemset(items=['Koji Yatani'], freq=22),
#  FreqItemset(items=['Ala I. Al-Fuqaha'], freq=40),
#  FreqItemset(items=['Hyeon Soo Kim'], freq=22),
#  FreqItemset(items=['Michael Schwind'], freq=56),
#  FreqItemset(items=['Hua Dai'], freq=24),
#  FreqItemset(items=['Dilip Kumar Pratihar'], freq=50),
#  FreqItemset(items=['S. M. Lee'], freq=39),
#  FreqItemset(items=['S. M. Lee', 'Ju H. Park'], freq=28),
#  FreqItemset(items=['Ki-Ryong Kwon'], freq=44),
#  FreqItemset(items=['Jaume Llibre'], freq=40),
#  FreqItemset(items=['C. M. Sperberg-McQueen'], freq=22),
#  FreqItemset(items=['Tao Cui'], freq=71),
#  FreqItemset(items=['Tao Cui', 'Chintha Tellambura'], freq=32),
#  FreqItemset(items=['Carsten Trinitis'], freq=52),
#  FreqItemset(items=['Srikanth Srinivasan'], freq=30),
#  FreqItemset(items=['Jon Whittle'], freq=87),
#  FreqItemset(items=['D. Scott McCrickard'], freq=69),
#  FreqItemset(items=["Donato D'Ambrosio"], freq=22),
#  FreqItemset(items=["Donato D'Ambrosio", 'William Spataro'], freq=22),
#  FreqItemset(items=['Zaili Dong'], freq=25),
#  FreqItemset(items=['Giorgos Flouris'], freq=26),
#  FreqItemset(items=['David Y. Y. Yun'], freq=51),
#  FreqItemset(items=['Akio Fujiyoshi'], freq=23),
#  FreqItemset(items=['Santi Phithakkitnukoon'], freq=22),
#  FreqItemset(items=['Thambipillai Srikanthan'], freq=147),
#  FreqItemset(items=['Geoffrey M. Voelker'], freq=92),
#  FreqItemset(items=['Akhilesh Kumar'], freq=27),
#  FreqItemset(items=['Robert Lagerström'], freq=29),
#  FreqItemset(items=['Hans-Dieter Ehrich'], freq=76),
#  FreqItemset(items=['Ana-Maria Popescu'], freq=27),
#  FreqItemset(items=['Christian R. Huyck'], freq=24),
#  FreqItemset(items=['Zsolt Tuza'], freq=197),
#  FreqItemset(items=['Sherman S. M. Chow'], freq=82),
#  FreqItemset(items=['Sherman S. M. Chow', 'Lucas Chi Kwong Hui'], freq=23),
#  FreqItemset(items=['Sherman S. M. Chow', 'Lucas Chi Kwong Hui', 'Siu-Ming Yiu'], freq=22),
#  FreqItemset(items=['Sherman S. M. Chow', 'Siu-Ming Yiu'], freq=25),
#  FreqItemset(items=['Jay Sethuraman'], freq=34),
#  FreqItemset(items=['Damien Chablat'], freq=176),
#  FreqItemset(items=['Diane Crawford'], freq=250),
#  FreqItemset(items=['Mandava Rajeswari'], freq=32),
#  FreqItemset(items=['June M. Verner'], freq=80),
#  FreqItemset(items=['Maurizio Pizzonia'], freq=29),
#  FreqItemset(items=['Chun-Wei Lin'], freq=28),
#  FreqItemset(items=['Chun-Wei Lin', 'Tzung-Pei Hong'], freq=26),
#  FreqItemset(items=['Anthony G. Pipe'], freq=67),
#  FreqItemset(items=['Susanto Rahardja'], freq=160),
#  FreqItemset(items=['Thomas Richter'], freq=35),
#  FreqItemset(items=['Nikil D. Dutt'], freq=203),
#  FreqItemset(items=['Nikil D. Dutt', 'Alexandru Nicolau'], freq=71),
#  FreqItemset(items=['Douglas Stebila'], freq=32),
#  FreqItemset(items=['Yingwei Yao'], freq=28),
#  FreqItemset(items=['Yacov Hel-Or'], freq=33),
#  FreqItemset(items=['Christine L. Lisetti'], freq=43),
#  FreqItemset(items=['Guy Pierra'], freq=39),
#  FreqItemset(items=['Philippe Marquet'], freq=35),
#  FreqItemset(items=['Philippe Marquet', 'Jean-Luc Dekeyser'], freq=31),
#  FreqItemset(items=['Cécile Belleudy'], freq=33),
#  FreqItemset(items=['Cécile Belleudy', 'Michel Auguin'], freq=27),
#  FreqItemset(items=['Ranko Lazic'], freq=40),
#  FreqItemset(items=['Davide Ancona'], freq=58),
#  FreqItemset(items=['Davide Ancona', 'Elena Zucca'], freq=33),
#  FreqItemset(items=['Nelma Moreira'], freq=40),
#  FreqItemset(items=['M. R. Garey'], freq=45),
#  FreqItemset(items=['M. R. Garey', 'David S. Johnson'], freq=31),
#  FreqItemset(items=['Jens Clausen'], freq=22),
#  FreqItemset(items=['Faouzi Kossentini'], freq=87),
#  FreqItemset(items=['Oege de Moor'], freq=72),
#  FreqItemset(items=['Matthias Hollick'], freq=60),
#  FreqItemset(items=['Matthias Hollick', 'Ralf Steinmetz'], freq=36),
#  FreqItemset(items=['Moustafa A. Hammad'], freq=25),
#  FreqItemset(items=['Fabian Abel'], freq=53),
#  FreqItemset(items=['Fabian Abel', 'Nicola Henze'], freq=28),
#  FreqItemset(items=['Bang Ye Wu'], freq=46),
#  FreqItemset(items=['Sozo Inoue'], freq=24),
#  FreqItemset(items=['Uwe Brinkschulte'], freq=71),
#  FreqItemset(items=['Asim Roy'], freq=22),
#  FreqItemset(items=['Sangarapillai Lambotharan'], freq=38),
#  FreqItemset(items=['Chein-Wei Jen'], freq=52),
#  FreqItemset(items=['Masahiro Ohka'], freq=24),
#  FreqItemset(items=['Simon L. Peyton Jones'], freq=173),
#  FreqItemset(items=['Peter D. Mosses'], freq=75),
#  FreqItemset(items=['Michael T. Orchard'], freq=79),
#  FreqItemset(items=['Ponnurangam Kumaraguru'], freq=27),
#  FreqItemset(items=['Jaime Teevan'], freq=55),
#  FreqItemset(items=['Hervé Bourlard'], freq=159),
#  FreqItemset(items=['Steffen van Bakel'], freq=49),
#  FreqItemset(items=['Hans Lamecker'], freq=24),
#  FreqItemset(items=['Lu Yu'], freq=74),
#  FreqItemset(items=['Odile Favaron'], freq=77),
#  FreqItemset(items=['Christian Hahn'], freq=29),
#  FreqItemset(items=['Tengku M. T. Sembok'], freq=27),
#  FreqItemset(items=['Nayantara Bhatnagar'], freq=24),
#  FreqItemset(items=['Oscar C. Au'], freq=236),
#  FreqItemset(items=['Jun Heo'], freq=35),
#  FreqItemset(items=['Toru Ishida'], freq=198),
#  FreqItemset(items=['Kewu Peng'], freq=32),
#  FreqItemset(items=['Kewu Peng', 'Zhixing Yang'], freq=22),
#  FreqItemset(items=['Marco Attene'], freq=30),
#  FreqItemset(items=['Jinxi Xu'], freq=28),
#  FreqItemset(items=['Xianbin Cao'], freq=33),
#  FreqItemset(items=['Michel Léonard'], freq=44),
#  FreqItemset(items=['Kwabena Boahen'], freq=36),
#  FreqItemset(items=['Jaap Kamps'], freq=126),
#  FreqItemset(items=['Jaap Kamps', 'Maarten de Rijke'], freq=29),
#  FreqItemset(items=['Eryk Laskowski'], freq=33),
#  FreqItemset(items=['Eryk Laskowski', 'Marek Tudruj'], freq=27),
#  FreqItemset(items=['Angelo Furfaro'], freq=34),
#  FreqItemset(items=['Angelo Furfaro', 'Libero Nigro'], freq=34),
#  FreqItemset(items=['Abram Hindle'], freq=31),
#  FreqItemset(items=['Wim Michiels'], freq=40),
#  FreqItemset(items=['Robert D. Tennent'], freq=33),
#  FreqItemset(items=["Dianne P. O'Leary"], freq=51),
#  FreqItemset(items=['Zhou Xu'], freq=37),
#  FreqItemset(items=['Zhou Xu', 'Andrew Lim'], freq=22),
#  FreqItemset(items=['Hideya Iwasaki'], freq=41),
#  FreqItemset(items=['Xinzhi Liu'], freq=50),
#  FreqItemset(items=['Miquel Sànchez-Marrè'], freq=41),
#  FreqItemset(items=['Miquel Sànchez-Marrè', 'Ulises Cortés'], freq=27),
#  FreqItemset(items=['E. K. Park'], freq=75),
#  FreqItemset(items=['Philippe Baptiste'], freq=53),
#  FreqItemset(items=['Resit Sendag'], freq=24),
#  FreqItemset(items=['Haitham S. Hamza'], freq=54),
#  FreqItemset(items=['Björn Hartmann'], freq=42),
#  FreqItemset(items=['Jop F. Sibeyn'], freq=74),
#  FreqItemset(items=['Saharon Rosset'], freq=52),
#  FreqItemset(items=['Thomas F. Keefe'], freq=25),
#  FreqItemset(items=['Malika Smaïl-Tabbone'], freq=24),
#  FreqItemset(items=['Malika Smaïl-Tabbone', 'Marie-Dominique Devignes'], freq=24),
#  FreqItemset(items=['Jinyuan You'], freq=54),
#  FreqItemset(items=['Hareton Leung'], freq=22),
#  FreqItemset(items=['Tomoki Toda'], freq=79),
#  FreqItemset(items=['Tomoki Toda', 'Hiroshi Saruwatari'], freq=39),
#  FreqItemset(items=['Tomoki Toda', 'Hiroshi Saruwatari', 'Kiyohiro Shikano'], freq=38),
#  FreqItemset(items=['Tomoki Toda', 'Kiyohiro Shikano'], freq=51),
#  FreqItemset(items=['Sandro Ridella'], freq=56),
#  FreqItemset(items=['Christoph Grimm'], freq=77),
#  FreqItemset(items=['Kee Chaing Chua'], freq=102),
#  FreqItemset(items=['Theresa Beaubouef'], freq=29),
#  FreqItemset(items=['Sjaak Smetsers'], freq=27),
#  FreqItemset(items=['Ljiljana Stojanovic'], freq=66),
#  FreqItemset(items=['Ljiljana Stojanovic', 'Nenad Stojanovic'], freq=37),
#  FreqItemset(items=['Xin Xin'], freq=25),
#  FreqItemset(items=['Wojciech Plandowski'], freq=55),
#  FreqItemset(items=['Wojciech Plandowski', 'Wojciech Rytter'], freq=25),
#  FreqItemset(items=['William A. Massey'], freq=24),
#  FreqItemset(items=['Shaula Yemini'], freq=23),
#  FreqItemset(items=['Jacob Chakareski'], freq=50),
#  FreqItemset(items=['Yong Lu'], freq=27),
#  FreqItemset(items=['Qian Yang'], freq=24),
#  FreqItemset(items=['Yue Wang'], freq=327),
#  FreqItemset(items=['Csaba Szepesvári'], freq=112),
#  FreqItemset(items=['Levent Tunçel'], freq=33),
#  FreqItemset(items=['André Kündgen'], freq=28),
#  FreqItemset(items=['Hyun Seung Yang'], freq=69),
#  FreqItemset(items=['François G. Meyer'], freq=28),
#  FreqItemset(items=['Jianping Chen'], freq=26),
#  FreqItemset(items=['Herbert Edelsbrunner'], freq=239),
#  FreqItemset(items=['Herbert Edelsbrunner', 'Leonidas J. Guibas'], freq=39),
#  FreqItemset(items=['Herbert Edelsbrunner', 'Leonidas J. Guibas', 'Micha Sharir'], freq=31),
#  FreqItemset(items=['Herbert Edelsbrunner', 'Micha Sharir'], freq=36),
#  FreqItemset(items=['Jittat Fakcharoenphol'], freq=25),
#  FreqItemset(items=['Masahiro Watanabe'], freq=33),
#  FreqItemset(items=['Sing-Ling Lee'], freq=23),
#  FreqItemset(items=['Mircea Marin'], freq=28),
#  FreqItemset(items=['Sunder Lal'], freq=33),
#  FreqItemset(items=['Victor Mitrana'], freq=141),
#  FreqItemset(items=['John A. Barnden'], freq=44),
#  FreqItemset(items=['Christoph Schommer'], freq=36),
#  FreqItemset(items=['Hideyoshi Tominaga'], freq=33),
#  FreqItemset(items=['Volker Nissen'], freq=41),
#  FreqItemset(items=['Pierre Siohan'], freq=42),
#  FreqItemset(items=['Lunjin Lu'], freq=52),
#  FreqItemset(items=['Barry Norton'], freq=22),
#  FreqItemset(items=['Janusz R. Getta'], freq=41),
#  FreqItemset(items=['Julie A. Adams'], freq=37),
#  FreqItemset(items=['Jing Yu'], freq=38),
#  FreqItemset(items=['Vicente Grau'], freq=32),
#  FreqItemset(items=['Wen Li'], freq=54),
#  FreqItemset(items=['Bora Uçar'], freq=24),
#  FreqItemset(items=['Andreas Polze'], freq=48),
#  FreqItemset(items=['Xabiel G. Pañeda'], freq=42),
#  FreqItemset(items=['Xabiel G. Pañeda', 'Roberto García'], freq=35),
#  FreqItemset(items=['Mickaël Raulet'], freq=39),
#  FreqItemset(items=['Gaochao Xu'], freq=24),
#  FreqItemset(items=['Alex Pang'], freq=54),
#  FreqItemset(items=['Dongfeng Yuan'], freq=66),
#  FreqItemset(items=['Peter Bruza'], freq=81),
#  FreqItemset(items=['Peter Bruza', 'Dawei Song'], freq=24),
#  FreqItemset(items=['Radu Calinescu'], freq=28),
#  FreqItemset(items=['Yan Qiao'], freq=24),
#  FreqItemset(items=['Ralf Herbrich'], freq=49),
#  FreqItemset(items=['Ralf Herbrich', 'Thore Graepel'], freq=35),
#  FreqItemset(items=['Giovanni Ponti'], freq=25),
#  FreqItemset(items=['Daeyoung Park'], freq=23),
#  FreqItemset(items=['Milind R. Naphade'], freq=79),
#  FreqItemset(items=['Milind R. Naphade', 'John R. Smith'], freq=34),
#  FreqItemset(items=['Lionel Seinturier'], freq=65),
#  FreqItemset(items=['Werner R. W. Scheinhardt'], freq=22),
#  FreqItemset(items=['César Andrés'], freq=28),
#  FreqItemset(items=['Amrit L. Goel'], freq=24),
#  FreqItemset(items=['Gaurav Pandey'], freq=23),
#  FreqItemset(items=['Santosh K. Shrivastava'], freq=124),
#  FreqItemset(items=['Richard M. Schwartz'], freq=85),
#  FreqItemset(items=['Steven M. German'], freq=28),
#  FreqItemset(items=['Ladislav Stacho'], freq=71),
#  FreqItemset(items=['Ladislav Stacho', 'Evangelos Kranakis'], freq=22),
#  FreqItemset(items=['B. David Saunders'], freq=36),
#  FreqItemset(items=['Oussama Khatib'], freq=118),
#  FreqItemset(items=['Florian Skopik'], freq=28),
#  FreqItemset(items=['Florian Skopik', 'Daniel Schall'], freq=22),
#  FreqItemset(items=['Florian Skopik', 'Schahram Dustdar'], freq=22),
#  FreqItemset(items=['Kuansan Wang'], freq=30),
#  FreqItemset(items=['Jean-Eric Pin'], freq=70),
#  FreqItemset(items=['Paulo Barthelmess'], freq=27),
#  FreqItemset(items=['Vigyan Singhal'], freq=40),
#  FreqItemset(items=['Vigyan Singhal', 'Adnan Aziz'], freq=22),
#  FreqItemset(items=['Xiaohua Wang'], freq=37),
#  FreqItemset(items=['Judith Gal-Ezer'], freq=34),
#  FreqItemset(items=['Gerard J. Foschini'], freq=31),
#  FreqItemset(items=['Kinshuk'], freq=151),
#  FreqItemset(items=['Gaoxi Xiao'], freq=32),
#  FreqItemset(items=['Francesca Scozzari'], freq=27),
#  FreqItemset(items=['Paul McNamee'], freq=41),
#  FreqItemset(items=['Paul McNamee', 'James Mayfield'], freq=32),
#  FreqItemset(items=['Mattia Monga'], freq=42),
#  FreqItemset(items=['Johan Schubert'], freq=38),
#  FreqItemset(items=['Solomon Marcus'], freq=34),
#  FreqItemset(items=['Daqing He'], freq=53),
#  FreqItemset(items=['Yong Tan'], freq=32),
#  FreqItemset(items=['Kyu-Han Kim'], freq=22),
#  FreqItemset(items=['Janusz Sobecki'], freq=38),
#  FreqItemset(items=['Stephen Robertson'], freq=42),
#  FreqItemset(items=['Caiming Zhang'], freq=55),
#  FreqItemset(items=['Guojun Dai'], freq=43),
#  FreqItemset(items=['Desheng Wang'], freq=22),
#  FreqItemset(items=['Panagiotis G. Ipeirotis'], freq=54),
#  FreqItemset(items=['Panagiotis G. Ipeirotis', 'Luis Gravano'], freq=25),
#  FreqItemset(items=['Lihong Xu'], freq=24),
#  FreqItemset(items=['Christian Bizer'], freq=49),
#  FreqItemset(items=['David L. Olson'], freq=43),
#  FreqItemset(items=['Michael R. Macedonia'], freq=39),
#  FreqItemset(items=['Sabrina Sicari'], freq=22),
#  FreqItemset(items=['Simon Harper'], freq=68),
#  FreqItemset(items=['Michael Hatzopoulos'], freq=51),
#  FreqItemset(items=['Raimund Seidel'], freq=83),
#  FreqItemset(items=['Noriko Kando'], freq=67),
#  FreqItemset(items=['Qian Zhu'], freq=50),
#  FreqItemset(items=['Wolf-Fritz Riekert'], freq=24),
#  FreqItemset(items=['Mingchu Li'], freq=23),
#  FreqItemset(items=['Zhangyan Xu'], freq=22),
#  FreqItemset(items=['Toru Yamamoto'], freq=25),
#  FreqItemset(items=['Margaret Martonosi'], freq=131),
#  FreqItemset(items=['Shmuel Katz'], freq=87),
#  FreqItemset(items=['Michele Bugliesi'], freq=73),
#  FreqItemset(items=['Paolo Puliti'], freq=28),
#  FreqItemset(items=['Norihide Kitaoka'], freq=60),
#  FreqItemset(items=['Norihide Kitaoka', 'Seiichi Nakagawa'], freq=31),
#  FreqItemset(items=['Norihide Kitaoka', 'Kazuya Takeda'], freq=26),
#  FreqItemset(items=['Shiva Chaudhuri'], freq=26),
#  FreqItemset(items=['Chris H. Messom'], freq=27),
#  FreqItemset(items=['Chris Blondia'], freq=124),
#  FreqItemset(items=['Suzanne Little'], freq=23),
#  FreqItemset(items=['Leyla Zhuhadar'], freq=26),
#  FreqItemset(items=['Robert C. Glen'], freq=27),
#  FreqItemset(items=['Walid G. Aref'], freq=148),
#  FreqItemset(items=['Walid G. Aref', 'Ahmed K. Elmagarmid'], freq=42),
#  FreqItemset(items=['Alistair P. Barros'], freq=34),
#  FreqItemset(items=['Judea Pearl'], freq=181),
#  FreqItemset(items=['Kirsten Winter'], freq=32),
#  FreqItemset(items=['Nan Niu'], freq=29),
#  FreqItemset(items=['Jaiyong Lee'], freq=41),
#  FreqItemset(items=['Alistair A. Young'], freq=27),
#  FreqItemset(items=['Roberto Scopigno'], freq=140),
#  FreqItemset(items=['Régine André-Obrecht'], freq=34),
#  FreqItemset(items=['Chandrajit L. Bajaj'], freq=164),
#  FreqItemset(items=['Guillaume Bonfante'], freq=31),
#  FreqItemset(items=['Masoud Sharif'], freq=27),
#  FreqItemset(items=['Simeon C. Ntafos'], freq=42),
#  FreqItemset(items=['Zongming Guo'], freq=38),
#  ...]

# %%
model3 = FPGrowth.train(rdd_res, 0.5e-5, 2)
res = model3.freqItemsets().collect()

# %%
res
# Out:
# [FreqItemset(items=['Eva Hudlicka'], freq=26),
#  FreqItemset(items=['Philip Levis'], freq=58),
#  FreqItemset(items=['Philip Levis', 'David E. Culler'], freq=18),
#  FreqItemset(items=['Yin Zhao'], freq=16),
#  FreqItemset(items=['Pierre Vandergheynst'], freq=109),
#  FreqItemset(items=['Pierre Vandergheynst', 'Pascal Frossard'], freq=23),
#  FreqItemset(items=['Pierre Vandergheynst', 'Jean-Philippe Thiran'], freq=16),
#  FreqItemset(items=['Mark Minas'], freq=81),
#  FreqItemset(items=['Martti Penttonen'], freq=32),
#  FreqItemset(items=['Martti Penttonen', 'Ville Leppänen'], freq=11),
#  FreqItemset(items=['Yen-Hsien Lee'], freq=23),
#  FreqItemset(items=['Yen-Hsien Lee', 'Chih-Ping Wei'], freq=14),
#  FreqItemset(items=['Terrence S. T. Mak'], freq=30),
#  FreqItemset(items=['Andrew W. Appel'], freq=85),
#  FreqItemset(items=['Even-André Karlsson'], freq=15),
#  FreqItemset(items=['John MacIntyre'], freq=28),
#  FreqItemset(items=['Pierre Soille'], freq=57),
#  FreqItemset(items=['Ana Cristina Vieira de Melo'], freq=26),
#  FreqItemset(items=['Hantao Song'], freq=16),
#  FreqItemset(items=['Jan Stallaert'], freq=25),
#  FreqItemset(items=['Jan Stallaert', 'Andrew B. Whinston'], freq=11),
#  FreqItemset(items=['Tomonari Masada'], freq=26),
#  FreqItemset(items=['Tomonari Masada', 'Yuichiro Shibata'], freq=12),
#  FreqItemset(items=['Tomonari Masada', 'Kiyoshi Oguri'], freq=12),
#  FreqItemset(items=['Tomonari Masada', 'Kiyoshi Oguri', 'Yuichiro Shibata'], freq=12),
#  FreqItemset(items=['Tomonari Masada', 'Atsuhiro Takasu'], freq=14),
#  FreqItemset(items=['Harry Bratt'], freq=17),
#  FreqItemset(items=['Roberto Sabella'], freq=23),
#  FreqItemset(items=['Ricardo C. Farias'], freq=30),
#  FreqItemset(items=['Christian G. Huber'], freq=11),
#  FreqItemset(items=['Arnoud Visser'], freq=22),
#  FreqItemset(items=['Linzhong Liu'], freq=15),
#  FreqItemset(items=['Daniel W. Halpin'], freq=11),
#  FreqItemset(items=['Young Ae Kim'], freq=11),
#  FreqItemset(items=['Yang Shao'], freq=14),
#  FreqItemset(items=['Ling Zhao'], freq=26),
#  FreqItemset(items=['K. W. Chan'], freq=16),
#  FreqItemset(items=['Darrell D. E. Long'], freq=120),
#  FreqItemset(items=['Giulio Caravagna'], freq=11),
#  FreqItemset(items=['Peer-Timo Bremer'], freq=31),
#  FreqItemset(items=['Peer-Timo Bremer', 'Valerio Pascucci'], freq=28),
#  FreqItemset(items=['Georg Carle'], freq=90),
#  FreqItemset(items=['Hans van der Heijden'], freq=29),
#  FreqItemset(items=['Juan M. López-Soler'], freq=18),
#  FreqItemset(items=['Sebastian Schmidt'], freq=16),
#  FreqItemset(items=['Nathan Dwyer'], freq=12),
#  FreqItemset(items=['Nathan Dwyer', 'Daniel D. Suthers'], freq=11),
#  FreqItemset(items=['Thomas Wedi'], freq=16),
#  FreqItemset(items=['Sushant Sachdeva'], freq=13),
#  FreqItemset(items=['Karsten Einwich'], freq=18),
#  FreqItemset(items=['Anne Penfold Street'], freq=15),
#  FreqItemset(items=['Guilherme Travassos'], freq=11),
#  FreqItemset(items=['Gary Higgs'], freq=13),
#  FreqItemset(items=['Martti Hallikainen'], freq=46),
#  FreqItemset(items=['Martti Hallikainen', 'Jouni Pulliainen'], freq=15),
#  FreqItemset(items=['Gary Warner'], freq=12),
#  FreqItemset(items=['Hans M. Jacobson'], freq=16),
#  FreqItemset(items=['Rhys S. Francis'], freq=12),
#  FreqItemset(items=['Yirng-An Chen'], freq=12),
#  FreqItemset(items=['Wieslaw L. Nowinski'], freq=37),
#  FreqItemset(items=['Ed Zaluska'], freq=34),
#  FreqItemset(items=['Ed Zaluska', 'David De Roure'], freq=15),
#  FreqItemset(items=['Emad Aboelela'], freq=11),
#  FreqItemset(items=['Wenjing Jia'], freq=45),
#  FreqItemset(items=['Wenjing Jia', 'Qiang Wu'], freq=34),
#  FreqItemset(items=['Wenjing Jia', 'Xiangjian He'], freq=44),
#  FreqItemset(items=['Wenjing Jia', 'Xiangjian He', 'Qiang Wu'], freq=34),
#  FreqItemset(items=['Wenjing Jia', 'Tom Hintz'], freq=11),
#  FreqItemset(items=['Wenjing Jia', 'Tom Hintz', 'Qiang Wu'], freq=11),
#  FreqItemset(items=['Wenjing Jia', 'Tom Hintz', 'Xiangjian He'], freq=11),
#  FreqItemset(items=['Wenjing Jia', 'Tom Hintz', 'Xiangjian He', 'Qiang Wu'], freq=11),
#  FreqItemset(items=['Cornelis W. Oosterlee'], freq=18),
#  FreqItemset(items=['Junji Furusho'], freq=29),
#  FreqItemset(items=['Peter A. Gloor'], freq=41),
#  FreqItemset(items=['Samir Roy'], freq=18),
#  FreqItemset(items=['Jukka Nenonen'], freq=13),
#  FreqItemset(items=['Alex A. T. Bui'], freq=21),
#  FreqItemset(items=['Kunio Doi'], freq=37),
#  FreqItemset(items=['Marc Teboulle'], freq=34),
#  FreqItemset(items=['Séamus McLoone'], freq=20),
#  FreqItemset(items=['Séamus McLoone', 'Tomás Ward'], freq=19),
#  FreqItemset(items=['Igor Boglaev'], freq=12),
#  FreqItemset(items=['Zhuowei Hu'], freq=18),
#  FreqItemset(items=['Zhuowei Hu', 'Wenji Zhao'], freq=12),
#  FreqItemset(items=['Yuanyuan Zeng'], freq=13),
#  FreqItemset(items=['Alexandre Gramfort'], freq=18),
#  FreqItemset(items=['Alexandre Gramfort', 'Bertrand Thirion'], freq=12),
#  FreqItemset(items=['Yen-Hsiang Chen'], freq=13),
#  FreqItemset(items=['Radha Krishna Ganti'], freq=47),
#  FreqItemset(items=['Radha Krishna Ganti', 'Martin Haenggi'], freq=23),
#  FreqItemset(items=['Radha Krishna Ganti', 'Jeffrey G. Andrews'], freq=27),
#  FreqItemset(items=['Alberto Silva'], freq=12),
#  FreqItemset(items=['Fernando H. Gregorio'], freq=12),
#  FreqItemset(items=['Wen-Chih Chang'], freq=38),
#  FreqItemset(items=['Wen-Chih Chang', 'Timothy K. Shih'], freq=18),
#  FreqItemset(items=['Gonzalo Cuevas Agustín'], freq=19),
#  FreqItemset(items=['Gonzalo Cuevas Agustín', 'Tomás San Feliu Gilabert'], freq=16),
#  FreqItemset(items=['Fouad B. Chedid'], freq=20),
#  FreqItemset(items=['Richard J. La'], freq=46),
#  FreqItemset(items=['H. Edwin Romeijn'], freq=48),
#  FreqItemset(items=['Jaakko Kangasharju'], freq=22),
#  FreqItemset(items=['Jaakko Kangasharju', 'Sasu Tarkoma'], freq=16),
#  FreqItemset(items=['Anthony J. H. Simons'], freq=42),
#  FreqItemset(items=['David Meisner'], freq=13),
#  FreqItemset(items=['David Meisner', 'Thomas F. Wenisch'], freq=12),
#  FreqItemset(items=['Izzat Darwazeh'], freq=21),
#  FreqItemset(items=['Tao Hu'], freq=38),
#  FreqItemset(items=['Daniel L. Schacter'], freq=14),
#  FreqItemset(items=['Henri Pierreval'], freq=20),
#  FreqItemset(items=['Guido Schryen'], freq=35),
#  FreqItemset(items=['Swarup Mandal'], freq=14),
#  FreqItemset(items=['Swarup Mandal', 'Debashis Saha'], freq=12),
#  FreqItemset(items=['Hitoshi Yanami'], freq=11),
#  FreqItemset(items=['Collin Jackson'], freq=19),
#  FreqItemset(items=['Lianfang Zhang'], freq=13),
#  FreqItemset(items=['Lianfang Zhang', 'Yantai Shu'], freq=11),
#  FreqItemset(items=['Kio Kim'], freq=12),
#  FreqItemset(items=['Kio Kim', 'Colin Studholme'], freq=11),
#  FreqItemset(items=['Chu-Ti Lin'], freq=13),
#  FreqItemset(items=['Chu-Ti Lin', 'Chin-Yu Huang'], freq=11),
#  FreqItemset(items=['J. Gregory Trafton'], freq=44),
#  FreqItemset(items=['J. Gregory Trafton', 'Alan C. Schultz'], freq=11),
#  FreqItemset(items=['Suryaprakash Kompalli'], freq=14),
#  FreqItemset(items=['Changyin Sun'], freq=65),
#  FreqItemset(items=['Denis R. Hirschfeldt'], freq=26),
#  FreqItemset(items=["Tiziana D'Orazio"], freq=57),
#  FreqItemset(items=["Tiziana D'Orazio", 'Arcangelo Distante'], freq=27),
#  FreqItemset(items=['Tse-Hsin Liu'], freq=13),
#  FreqItemset(items=['Tse-Hsin Liu', 'K. Suzanne Barber'], freq=13),
#  FreqItemset(items=['Vassil Roussev'], freq=23),
#  FreqItemset(items=['Vassil Roussev', 'Golden G. Richard III'], freq=13),
#  FreqItemset(items=['Björn Waske'], freq=22),
#  FreqItemset(items=['Björn Waske', 'Jon Atli Benediktsson'], freq=14),
#  FreqItemset(items=['Aaron Read'], freq=15),
#  FreqItemset(items=['Aaron Read', 'Robert O. Briggs'], freq=11),
#  FreqItemset(items=['Marco Ragni'], freq=23),
#  FreqItemset(items=['Bernard Lidický'], freq=26),
#  FreqItemset(items=['Mahesh Sooriyabandara'], freq=14),
#  FreqItemset(items=['David W. Wall'], freq=20),
#  FreqItemset(items=['Weimin Chen'], freq=23),
#  FreqItemset(items=['Mehran Mohsenzadeh'], freq=15),
#  FreqItemset(items=['Tim Weitzel'], freq=108),
#  FreqItemset(items=['Tim Weitzel', 'Wolfgang König'], freq=17),
#  FreqItemset(items=['Masahiko Yachida'], freq=119),
#  FreqItemset(items=['Masahiko Yachida', 'Yasushi Yagi'], freq=36),
#  FreqItemset(items=['Jari Nurmi'], freq=85),
#  FreqItemset(items=['Rana Ejaz Ahmed'], freq=14),
#  FreqItemset(items=['Fabio Salice'], freq=67),
#  FreqItemset(items=['Fabio Salice', 'Donatella Sciuto'], freq=41),
#  FreqItemset(items=['Fabio Salice', 'William Fornaciari'], freq=26),
#  FreqItemset(items=['Fabio Salice', 'William Fornaciari', 'Donatella Sciuto'], freq=18),
#  FreqItemset(items=['Fabio Salice', 'Cristiana Bolchini'], freq=33),
#  FreqItemset(items=['Fabio Salice', 'Cristiana Bolchini', 'Donatella Sciuto'], freq=22),
#  FreqItemset(items=['Seung Joon Lee'], freq=26),
#  FreqItemset(items=['Fei He'], freq=59),
#  FreqItemset(items=['Fei He', 'Ming Gu'], freq=20),
#  FreqItemset(items=['Fei He', 'Ming Gu', 'Xiaoyu Song'], freq=18),
#  FreqItemset(items=['Fei He', 'Xiaoyu Song'], freq=20),
#  FreqItemset(items=['Minghua Xia'], freq=25),
#  FreqItemset(items=['Minghua Xia', 'Yik-Chung Wu'], freq=11),
#  FreqItemset(items=['Wanyi Gu'], freq=16),
#  FreqItemset(items=['Jae-Woo Chang'], freq=114),
#  FreqItemset(items=['Yue Wu'], freq=83),
#  FreqItemset(items=['Albert Alderson'], freq=14),
#  FreqItemset(items=['Richard H. Thayer'], freq=11),
#  FreqItemset(items=['Luiz Angelo Steffenel'], freq=15),
#  FreqItemset(items=['Ferdinando Nunziata'], freq=16),
#  FreqItemset(items=['Ferdinando Nunziata', 'Maurizio Migliaccio'], freq=16),
#  FreqItemset(items=['Kevin A. Schneider'], freq=25),
#  FreqItemset(items=['Conrad C. Huang'], freq=14),
#  FreqItemset(items=['Conrad C. Huang', 'Thomas E. Ferrin'], freq=13),
#  FreqItemset(items=['Julio H. Braslavsky'], freq=16),
#  FreqItemset(items=['Adi R. Bulsara'], freq=15),
#  FreqItemset(items=['Chian Wang'], freq=11),
#  FreqItemset(items=['Alberto Rodriguez'], freq=14),
#  FreqItemset(items=['Harald Baier'], freq=11),
#  FreqItemset(items=['Xiaoyang Sean Wang'], freq=133),
#  FreqItemset(items=['Xiaoyang Sean Wang', 'Sushil Jajodia'], freq=56),
#  FreqItemset(items=['Nenad Dedic'], freq=11),
#  FreqItemset(items=['Nicolas Van Wambeke'], freq=11),
#  FreqItemset(items=['Bernard Ries'], freq=29),
#  FreqItemset(items=['Bernard Ries', 'Marie-Christine Costa'], freq=11),
#  FreqItemset(items=['Bernard Ries', 'Marie-Christine Costa', 'Dominique de Werra'], freq=11),
#  FreqItemset(items=['Bernard Ries', 'Marie-Christine Costa', 'Christophe Picouleau'], freq=11),
#  FreqItemset(items=['Bernard Ries', 'Marie-Christine Costa', 'Christophe Picouleau', 'Dominique de Werra'], freq=11),
#  FreqItemset(items=['Bernard Ries', 'Dominique de Werra'], freq=15),
#  FreqItemset(items=['Bernard Ries', 'Christophe Picouleau'], freq=13),
#  FreqItemset(items=['Bernard Ries', 'Christophe Picouleau', 'Dominique de Werra'], freq=12),
#  FreqItemset(items=['Tom Vercauteren'], freq=31),
#  FreqItemset(items=['Tom Vercauteren', 'Nicholas Ayache'], freq=20),
#  FreqItemset(items=['Sem C. Borst'], freq=95),
#  FreqItemset(items=['Samir Tohmé'], freq=54),
#  FreqItemset(items=['Sameer Tilak'], freq=25),
#  FreqItemset(items=['Sameer Tilak', 'Nael B. Abu-Ghazaleh'], freq=15),
#  FreqItemset(items=['Y. Xiang'], freq=16),
#  FreqItemset(items=['Jitendra Ajmera'], freq=17),
#  FreqItemset(items=['Canhui Cai'], freq=19),
#  FreqItemset(items=['Canhui Cai', 'Kai-Kuang Ma'], freq=11),
#  FreqItemset(items=['Liang Zhou'], freq=93),
#  FreqItemset(items=['Liang Zhou', 'Eduard H. Hovy'], freq=11),
#  FreqItemset(items=['Shaochun Xu'], freq=28),
#  FreqItemset(items=['Serge Weber'], freq=31),
#  FreqItemset(items=['Serge Weber', 'Camel Tanougast'], freq=22),
#  FreqItemset(items=['Katharina Kaiser'], freq=18),
#  FreqItemset(items=['Katharina Kaiser', 'Silvia Miksch'], freq=17),
#  FreqItemset(items=['Masafumi Okada'], freq=29),
#  FreqItemset(items=['Masafumi Okada', 'Yoshihiko Nakamura'], freq=14),
#  FreqItemset(items=['Upendra Sharma'], freq=13),
#  FreqItemset(items=['Hui Xia'], freq=11),
#  FreqItemset(items=['Guillermo de Jesús Hoyos-Rivera'], freq=16),
#  FreqItemset(items=['Jin S. Lee'], freq=25),
#  FreqItemset(items=['Tien-Chi Huang'], freq=12),
#  FreqItemset(items=['Mun-Kew Leong'], freq=16),
#  FreqItemset(items=['Zhe Shan'], freq=17),
#  FreqItemset(items=['Barry Boots'], freq=12),
#  FreqItemset(items=['Johnny Henderson'], freq=11),
#  FreqItemset(items=['Rahul M. Rao'], freq=18),
#  FreqItemset(items=['Rahul M. Rao', 'Richard B. Brown'], freq=13),
#  FreqItemset(items=['Hee Lin Wang'], freq=11),
#  FreqItemset(items=['Tom Croonenborghs'], freq=11),
#  FreqItemset(items=['Alexandre David'], freq=46),
#  FreqItemset(items=['Alexandre David', 'Kim Guldstrand Larsen'], freq=26),
#  FreqItemset(items=['Alexandre David', 'Axel Legay'], freq=17),
#  FreqItemset(items=['Alexandre David', 'Kim G. Larsen'], freq=13),
#  FreqItemset(items=['Tohru Nitta'], freq=16),
#  FreqItemset(items=['Bruno Feijó'], freq=37),
#  FreqItemset(items=['Chaouki T. Abdallah'], freq=38),
#  FreqItemset(items=['Andreas Frommer'], freq=34),
#  FreqItemset(items=['Alexander De Luca'], freq=31),
#  FreqItemset(items=['Manolis Maragoudakis'], freq=46),
#  FreqItemset(items=['Manolis Maragoudakis', 'Nikos Fakotakis'], freq=23),
#  FreqItemset(items=['Sara Tonelli'], freq=18),
#  FreqItemset(items=['Adam Przepiórkowski'], freq=29),
#  FreqItemset(items=['Ueli Meier'], freq=13),
#  FreqItemset(items=['Ueli Meier', 'Jürgen Schmidhuber'], freq=13),
#  FreqItemset(items=['Jing Kong'], freq=18),
#  FreqItemset(items=['Ricardo Oscar Rodríguez'], freq=12),
#  FreqItemset(items=['Robert Piloty'], freq=12),
#  FreqItemset(items=['Ruby Krishnaswamy'], freq=13),
#  FreqItemset(items=['Thomas Ehrhard'], freq=47),
#  FreqItemset(items=['Yvonne Dittrich'], freq=43),
#  FreqItemset(items=['Fredrik Heintz'], freq=23),
#  FreqItemset(items=['Fredrik Heintz', 'Patrick Doherty'], freq=16),
#  FreqItemset(items=['Germán Mato'], freq=12),
#  FreqItemset(items=['Long Bao Le'], freq=39),
#  FreqItemset(items=['Long Bao Le', 'Ekram Hossain'], freq=16),
#  FreqItemset(items=['Amara Amara'], freq=20),
#  FreqItemset(items=['Josef Spillner'], freq=19),
#  FreqItemset(items=['Josef Spillner', 'Alexander Schill'], freq=16),
#  FreqItemset(items=['Olivier Simonin'], freq=33),
#  FreqItemset(items=['Olivier Simonin', 'François Charpillet'], freq=13),
#  FreqItemset(items=['Richard J. Fateman'], freq=36),
#  FreqItemset(items=['Michael Eineder'], freq=43),
#  FreqItemset(items=['Michael Eineder', 'Richard Bamler'], freq=12),
#  FreqItemset(items=['Mitsunori Ogiwara'], freq=22),
#  FreqItemset(items=['Xiao Feng'], freq=13),
#  FreqItemset(items=['Tomas Eklund'], freq=18),
#  FreqItemset(items=['Tomas Eklund', 'Barbro Back'], freq=12),
#  FreqItemset(items=['Yoshinori Tamada'], freq=21),
#  FreqItemset(items=['Yoshinori Tamada', 'Hideo Bannai'], freq=11),
#  FreqItemset(items=['Yoshinori Tamada', 'Hideo Bannai', 'Satoru Miyano'], freq=11),
#  FreqItemset(items=['Yoshinori Tamada', 'Satoru Miyano'], freq=20),
#  FreqItemset(items=['Yoshinori Tamada', 'Seiya Imoto'], freq=13),
#  FreqItemset(items=['Yoshinori Tamada', 'Seiya Imoto', 'Satoru Miyano'], freq=12),
#  FreqItemset(items=['Madeline Weiss'], freq=20),
#  FreqItemset(items=['Yu You'], freq=14),
#  FreqItemset(items=['Frank G. Goethals'], freq=19),
#  FreqItemset(items=['Frank G. Goethals', 'Jacques Vandenbulcke'], freq=12),
#  FreqItemset(items=['Frank G. Goethals', 'Jacques Vandenbulcke', 'Monique Snoeck'], freq=11),
#  FreqItemset(items=['Frank G. Goethals', 'Jacques Vandenbulcke', 'Wilfried Lemahieu'], freq=12),
#  FreqItemset(items=['Frank G. Goethals', 'Jacques Vandenbulcke', 'Wilfried Lemahieu', 'Monique Snoeck'], freq=11),
#  FreqItemset(items=['Frank G. Goethals', 'Monique Snoeck'], freq=13),
#  FreqItemset(items=['Frank G. Goethals', 'Wilfried Lemahieu'], freq=14),
#  FreqItemset(items=['Frank G. Goethals', 'Wilfried Lemahieu', 'Monique Snoeck'], freq=13),
#  FreqItemset(items=['José Villalón'], freq=13),
#  FreqItemset(items=['José Villalón', 'Luis Orozco-Barbosa'], freq=11),
#  FreqItemset(items=['Yihua Zhu'], freq=14),
#  FreqItemset(items=['Rémy Prost'], freq=57),
#  FreqItemset(items=['Hamid R. Sadjadpour'], freq=67),
#  FreqItemset(items=['Hamid R. Sadjadpour', 'Zheng Wang'], freq=20),
#  FreqItemset(items=['Hamid R. Sadjadpour', 'Zheng Wang', 'J. J. Garcia-Luna-Aceves'], freq=13),
#  FreqItemset(items=['Hamid R. Sadjadpour', 'J. J. Garcia-Luna-Aceves'], freq=40),
#  FreqItemset(items=['Jiho Yoo'], freq=13),
#  FreqItemset(items=['Jiho Yoo', 'Seungjin Choi'], freq=13),
#  FreqItemset(items=['José Machado'], freq=44),
#  FreqItemset(items=['José Machado', 'Paulo Novais'], freq=15),
#  FreqItemset(items=['José Machado', 'Paulo Novais', 'José Neves'], freq=15),
#  FreqItemset(items=['José Machado', 'José Neves'], freq=31),
#  FreqItemset(items=['Andreas Czylwik'], freq=22),
#  FreqItemset(items=['Marc Toussaint'], freq=66),
#  FreqItemset(items=['Bernard Mulgrew'], freq=56),
#  FreqItemset(items=['Patti Price'], freq=21),
#  FreqItemset(items=['Er-Wei Bai'], freq=58),
#  FreqItemset(items=['Hongkai Zhao'], freq=14),
#  FreqItemset(items=['Edward Chu Yeow Peh'], freq=13),
#  FreqItemset(items=['Edward Chu Yeow Peh', 'Ying-Chang Liang'], freq=13),
#  FreqItemset(items=['Junping Sun'], freq=20),
#  FreqItemset(items=['Hristo Djidjev'], freq=44),
#  FreqItemset(items=['Sven-Arne Reinemo'], freq=23),
#  FreqItemset(items=['Sven-Arne Reinemo', 'Tor Skeie'], freq=19),
#  FreqItemset(items=['Sven-Arne Reinemo', 'Tor Skeie', 'Olav Lysne'], freq=11),
#  FreqItemset(items=['Sven-Arne Reinemo', 'Olav Lysne'], freq=11),
#  FreqItemset(items=['Yong-Sheng Chen'], freq=22),
#  FreqItemset(items=['Yong-Sheng Chen', 'Yi-Ping Hung'], freq=11),
#  FreqItemset(items=['Shuqian Luo'], freq=15),
#  FreqItemset(items=['Fritz Albregtsen'], freq=14),
#  FreqItemset(items=['Bernhard Walke'], freq=89),
#  FreqItemset(items=["John O'Brien"], freq=14),
#  FreqItemset(items=['Damian Grzechca'], freq=11),
#  FreqItemset(items=['Hiroyuki Toh'], freq=20),
#  FreqItemset(items=['Richard Hawkins'], freq=13),
#  FreqItemset(items=['Nelly Litvak'], freq=25),
#  FreqItemset(items=['David Horn'], freq=61),
#  FreqItemset(items=['David Horn', 'Eytan Ruppin'], freq=15),
#  FreqItemset(items=['Juan J. Merelo Guervós'], freq=87),
#  FreqItemset(items=['Juan J. Merelo Guervós', 'Alberto Prieto'], freq=19),
#  FreqItemset(items=['John Matthews'], freq=22),
#  FreqItemset(items=['Zhizheng Zhang'], freq=25),
#  FreqItemset(items=['Yukitoshi Sanada'], freq=60),
#  FreqItemset(items=['Roksana Boreli'], freq=26),
#  FreqItemset(items=['Loïc Denis'], freq=16),
#  FreqItemset(items=['Loïc Denis', 'Florence Tupin'], freq=14),
#  FreqItemset(items=['Ji-Huan He'], freq=25),
#  FreqItemset(items=['Byung-Seo Kim'], freq=15),
#  FreqItemset(items=['Byung-Seo Kim', 'Sung Won Kim'], freq=11),
#  FreqItemset(items=['Karen Tanenbaum'], freq=11),
#  FreqItemset(items=['Volker Dicken'], freq=15),
#  FreqItemset(items=['Charlie D. Frowd'], freq=15),
#  FreqItemset(items=['Opher Etzion'], freq=95),
#  FreqItemset(items=['Opher Etzion', 'Avigdor Gal'], freq=20),
#  FreqItemset(items=['Mei-Chen Hsueh'], freq=11),
#  FreqItemset(items=['Sarma Sastry'], freq=16),
#  FreqItemset(items=['Peter Gorniak'], freq=14),
#  FreqItemset(items=['Atílio Gameiro'], freq=63),
#  FreqItemset(items=['Dave A. Thomas'], freq=37),
#  FreqItemset(items=['David Cuesta-Frau'], freq=15),
#  FreqItemset(items=['Samuel Madden'], freq=141),
#  FreqItemset(items=['Samuel Madden', 'Michael J. Franklin'], freq=16),
#  FreqItemset(items=['Samuel Madden', 'Michael Stonebraker'], freq=13),
#  FreqItemset(items=['Samuel Madden', 'Hari Balakrishnan'], freq=23),
#  FreqItemset(items=['Samuel Madden', 'Joseph M. Hellerstein'], freq=19),
#  FreqItemset(items=['Samuel Madden', 'Joseph M. Hellerstein', 'Michael J. Franklin'], freq=11),
#  FreqItemset(items=['Rangasami L. Kashyap'], freq=92),
#  FreqItemset(items=['Rangasami L. Kashyap', 'Shu-Ching Chen'], freq=11),
#  FreqItemset(items=['Emanouil I. Atanassov'], freq=31),
#  FreqItemset(items=['Andrea Acquaviva'], freq=75),
#  FreqItemset(items=['Andrea Acquaviva', 'Enrico Macii'], freq=19),
#  FreqItemset(items=['Andrea Acquaviva', 'Luca Benini'], freq=26),
#  FreqItemset(items=['Cunsheng Ding'], freq=99),
#  FreqItemset(items=['Cunsheng Ding', 'Tor Helleseth'], freq=12),
#  FreqItemset(items=['Raman Kazhamiakin'], freq=29),
#  FreqItemset(items=['Raman Kazhamiakin', 'Marco Pistore'], freq=25),
#  FreqItemset(items=['Patrick Lam'], freq=31),
#  FreqItemset(items=['Patrick Lam', 'Martin C. Rinard'], freq=12),
#  FreqItemset(items=['Khalid Daoudi'], freq=27),
#  FreqItemset(items=['Maria J. Martín-Bautista'], freq=37),
#  FreqItemset(items=['Maria J. Martín-Bautista', 'Daniel Sánchez'], freq=17),
#  FreqItemset(items=['Maria J. Martín-Bautista', 'Daniel Sánchez', 'María Amparo Vila Miranda'], freq=14),
#  FreqItemset(items=['Maria J. Martín-Bautista', 'María Amparo Vila Miranda'], freq=25),
#  FreqItemset(items=['Pablo Figueroa'], freq=25),
#  FreqItemset(items=['Paulo Santos'], freq=17),
#  FreqItemset(items=['Ohm Sornil'], freq=12),
#  FreqItemset(items=['Tsuyoshi Moriyama'], freq=16),
#  FreqItemset(items=['Cynthia LeRouge'], freq=29),
#  FreqItemset(items=['Mingchuan Zhang'], freq=11),
#  FreqItemset(items=['Amjed Shareef'], freq=11),
#  FreqItemset(items=['Yuan-Chieh Chow'], freq=14),
#  FreqItemset(items=['Osei Poku'], freq=12),
#  FreqItemset(items=["Vijay D'Silva"], freq=16),
#  FreqItemset(items=['Daniel P. Jenkins'], freq=12),
#  FreqItemset(items=['Daniel P. Jenkins', 'Paul M. Salmon'], freq=11),
#  FreqItemset(items=['Daniel P. Jenkins', 'Paul M. Salmon', 'Neville A. Stanton'], freq=11),
#  FreqItemset(items=['Daniel P. Jenkins', 'Paul M. Salmon', 'Guy H. Walker'], freq=11),
#  FreqItemset(items=['Daniel P. Jenkins', 'Paul M. Salmon', 'Guy H. Walker', 'Neville A. Stanton'], freq=11),
#  FreqItemset(items=['Daniel P. Jenkins', 'Neville A. Stanton'], freq=12),
#  FreqItemset(items=['Daniel P. Jenkins', 'Guy H. Walker'], freq=12),
#  FreqItemset(items=['Daniel P. Jenkins', 'Guy H. Walker', 'Neville A. Stanton'], freq=12),
#  FreqItemset(items=['Klaus Radermacher'], freq=35),
#  FreqItemset(items=['Fabrício Martins Lopes'], freq=11),
#  FreqItemset(items=['Michel R. Klein'], freq=11),
#  FreqItemset(items=['Yosuke Sato'], freq=32),
#  FreqItemset(items=['Yosuke Sato', 'Yoshitaka Shibata'], freq=16),
#  FreqItemset(items=['Lorcan Coyle'], freq=30),
#  FreqItemset(items=['Lorcan Coyle', 'Paddy Nixon'], freq=11),
#  FreqItemset(items=['Magnus Andersson'], freq=17),
#  FreqItemset(items=['Daxin Jiang'], freq=28),
#  FreqItemset(items=['Daxin Jiang', 'Aidong Zhang'], freq=12),
#  FreqItemset(items=['Daxin Jiang', 'Jian Pei'], freq=22),
#  FreqItemset(items=['Arcangelo Bruna'], freq=18),
#  FreqItemset(items=['Chan-Soo Hwang'], freq=35),
#  FreqItemset(items=['Chan-Soo Hwang', 'John M. Cioffi'], freq=16),
#  FreqItemset(items=['Salim Chitroub'], freq=20),
#  FreqItemset(items=['Alexandra Shlapentokh'], freq=12),
#  FreqItemset(items=['Ehsan Atoofian'], freq=16),
#  FreqItemset(items=['Nitin Sharma'], freq=19),
#  FreqItemset(items=['Christian Leibold'], freq=12),
#  FreqItemset(items=['Carlos Alós-Ferrer'], freq=18),
#  FreqItemset(items=['Dae Young Kim'], freq=30),
#  FreqItemset(items=['Raymond S. Smith'], freq=17),
#  FreqItemset(items=['Zhi-Hui Wang'], freq=18),
#  FreqItemset(items=['Zhi-Hui Wang', 'Chin-Chen Chang'], freq=16),
#  FreqItemset(items=['Sergiu Gordea'], freq=13),
#  FreqItemset(items=['Mihir R. Choudhury'], freq=16),
#  FreqItemset(items=['Mihir R. Choudhury', 'Kartik Mohanram'], freq=15),
#  FreqItemset(items=['Valerie L. Shalin'], freq=12),
#  FreqItemset(items=['Nick R. Jennings'], freq=12),
#  FreqItemset(items=['Jihyung Kim'], freq=12),
#  FreqItemset(items=['Marco Callieri'], freq=36),
#  FreqItemset(items=['Marco Callieri', 'Roberto Scopigno'], freq=30),
#  FreqItemset(items=['Marco Callieri', 'Paolo Cignoni'], freq=21),
#  FreqItemset(items=['Marco Callieri', 'Paolo Cignoni', 'Roberto Scopigno'], freq=19),
#  FreqItemset(items=['Pierre Savéant'], freq=20),
#  FreqItemset(items=['Pierre Savéant', 'Marc Schoenauer'], freq=11),
#  FreqItemset(items=['Wen-Liang Hung'], freq=48),
#  FreqItemset(items=['Wen-Liang Hung', 'Miin-Shen Yang'], freq=25),
#  FreqItemset(items=['Huadong Guo'], freq=44),
#  FreqItemset(items=['Toshinori Munakata'], freq=23),
#  FreqItemset(items=['Tz-Heng Hsu'], freq=18),
#  FreqItemset(items=['Tz-Heng Hsu', 'Chung-Ming Huang'], freq=12),
#  FreqItemset(items=['Mohamed H. Ahmed'], freq=35),
#  FreqItemset(items=['Michel Joubert'], freq=21),
#  FreqItemset(items=['Juan Miguel Campanario'], freq=19),
#  FreqItemset(items=['Luis E. Mendoza Morales'], freq=14),
#  FreqItemset(items=['Chao Ren'], freq=13),
#  FreqItemset(items=['Dietrich Albert'], freq=58),
#  FreqItemset(items=['Xianxian Li'], freq=13),
#  FreqItemset(items=['Jeroen Wigard'], freq=18),
#  FreqItemset(items=['Kang-Soo You'], freq=12),
#  FreqItemset(items=['Mercedes G. Merayo'], freq=45),
#  FreqItemset(items=['Mercedes G. Merayo', 'Manuel Núñez'], freq=38),
#  FreqItemset(items=['Mercedes G. Merayo', 'Manuel Núñez', 'Robert M. Hierons'], freq=12),
#  FreqItemset(items=['Mercedes G. Merayo', 'Robert M. Hierons'], freq=14),
#  FreqItemset(items=['Mercedes G. Merayo', 'Ismael Rodríguez'], freq=12),
#  FreqItemset(items=['Mercedes G. Merayo', 'Ismael Rodríguez', 'Manuel Núñez'], freq=12),
#  FreqItemset(items=['Gary Singh'], freq=68),
#  FreqItemset(items=['J. Leo van Hemmen'], freq=58),
#  FreqItemset(items=['J. Leo van Hemmen', 'Wulfram Gerstner'], freq=13),
#  FreqItemset(items=['Paul G. Sorenson'], freq=51),
#  FreqItemset(items=['Adam Liwo'], freq=23),
#  FreqItemset(items=['Adam Liwo', 'Harold A. Scheraga'], freq=13),
#  FreqItemset(items=['Shaahin Hessabi'], freq=45),
#  FreqItemset(items=['Yuval Emek'], freq=41),
#  FreqItemset(items=['Yuval Emek', 'David Peleg'], freq=14),
#  FreqItemset(items=['Yuval Emek', 'Amos Korman'], freq=11),
#  FreqItemset(items=['Yael Moses'], freq=22),
#  FreqItemset(items=['William Stallings'], freq=15),
#  FreqItemset(items=['Wil Michiels'], freq=13),
#  FreqItemset(items=['Volker Braun'], freq=19),
#  FreqItemset(items=['Volker Braun', 'Tiziana Margaria'], freq=13),
#  FreqItemset(items=['Kentaro Onizuka'], freq=14),
#  FreqItemset(items=['Manfred Gehrke'], freq=15),
#  FreqItemset(items=['Helman Stern'], freq=22),
#  FreqItemset(items=['Jacob Illum Rasmussen'], freq=13),
#  FreqItemset(items=['Jacob Illum Rasmussen', 'Kim Guldstrand Larsen'], freq=13),
#  FreqItemset(items=['Dragos Vingarzan'], freq=14),
#  FreqItemset(items=['Dragos Vingarzan', 'Thomas Magedanz'], freq=13),
#  FreqItemset(items=['Mike Burmester'], freq=92),
#  FreqItemset(items=['Mike Burmester', 'Yvo Desmedt'], freq=32),
#  FreqItemset(items=['Ian Williamson'], freq=14),
#  FreqItemset(items=['Hiroaki Kurokawa'], freq=13),
#  FreqItemset(items=['Karl J. Lieberherr'], freq=71),
#  FreqItemset(items=['Yves Lecourtier'], freq=53),
#  FreqItemset(items=['Yves Lecourtier', 'Laurent Heutte'], freq=15),
#  FreqItemset(items=['Luca Roversi'], freq=25),
#  FreqItemset(items=['Jeffrey H. Reed'], freq=62),
#  FreqItemset(items=['Amaury Lendasse'], freq=89),
#  FreqItemset(items=['Amaury Lendasse', 'Michel Verleysen'], freq=28),
#  FreqItemset(items=['Richard Cooper'], freq=42),
#  FreqItemset(items=['Carlos D. Martínez-Hinarejos'], freq=22),
#  FreqItemset(items=['George Philokyprou'], freq=15),
#  FreqItemset(items=['Mikael Lindvall'], freq=61),
#  FreqItemset(items=['Mikael Lindvall', 'Victor R. Basili'], freq=11),
#  FreqItemset(items=['Jinsuk Baek'], freq=25),
#  FreqItemset(items=['Jinsuk Baek', 'Paul S. Fisher'], freq=14),
#  FreqItemset(items=['Carlo Gaibisso'], freq=25),
#  FreqItemset(items=['Carlo Gaibisso', 'Giorgio Gambosi'], freq=12),
#  FreqItemset(items=['Wentao Zhao'], freq=22),
#  FreqItemset(items=['Jonathan Slocum'], freq=15),
#  FreqItemset(items=['A. Mukherjee'], freq=15),
#  FreqItemset(items=['Chang An'], freq=11),
#  FreqItemset(items=['Yiu-ming Cheung'], freq=98),
#  FreqItemset(items=['Cheng-Li Liu'], freq=11),
#  FreqItemset(items=['Manabu Hagiwara'], freq=29),
#  FreqItemset(items=['Manabu Hagiwara', 'Hideki Imai'], freq=20),
#  FreqItemset(items=['Yong Bai'], freq=26),
#  FreqItemset(items=['Yong Bai', 'Lan Chen'], freq=16),
#  FreqItemset(items=['Todor Cooklev'], freq=16),
#  FreqItemset(items=['Riccardo Scandariato'], freq=24),
#  FreqItemset(items=['Riccardo Scandariato', 'Wouter Joosen'], freq=16),
#  FreqItemset(items=['Andreas Nürnberger'], freq=95),
#  FreqItemset(items=['Srinivas Aluru'], freq=102),
#  FreqItemset(items=['Leszek Pacholski'], freq=29),
#  FreqItemset(items=['Christian Winkler'], freq=15),
#  FreqItemset(items=['Stephen D. Bay'], freq=17),
#  FreqItemset(items=['A. Ant Ozok'], freq=26),
#  FreqItemset(items=['Hua-Gang Li'], freq=16),
#  FreqItemset(items=['Hua-Gang Li', 'Divyakant Agrawal'], freq=11),
#  FreqItemset(items=['Abu Bakar Md Sultan'], freq=12),
#  FreqItemset(items=['Toan Huynh'], freq=16),
#  FreqItemset(items=['David Maier'], freq=227),
#  FreqItemset(items=['David Maier', 'Jeffrey D. Ullman'], freq=19),
#  FreqItemset(items=['Ramana M. Idury'], freq=11),
#  FreqItemset(items=['Takahiro Matsumoto'], freq=11),
#  FreqItemset(items=['James R. Evans'], freq=11),
#  FreqItemset(items=['Xiaohui Yu'], freq=30),
#  FreqItemset(items=['Xiaohui Yu', 'Yang Liu'], freq=13),
#  FreqItemset(items=['Jack W. Davidson'], freq=83),
#  FreqItemset(items=['Jack W. Davidson', 'David B. Whalley'], freq=15),
#  FreqItemset(items=['Gavin M. Bierman'], freq=38),
#  FreqItemset(items=['Andrea Omicini'], freq=194),
#  FreqItemset(items=['Andrea Omicini', 'Franco Zambonelli'], freq=23),
#  FreqItemset(items=['Lingmei Jiang'], freq=35),
#  FreqItemset(items=['Lingmei Jiang', 'Jiancheng Shi'], freq=19),
#  FreqItemset(items=['Lingmei Jiang', 'Lixin Zhang'], freq=22),
#  FreqItemset(items=['Vijay Kumar'], freq=349),
#  FreqItemset(items=['Yubao Liu'], freq=20),
#  FreqItemset(items=['Yubao Liu', 'Jian Yin'], freq=11),
#  FreqItemset(items=['Sebastian Wagner'], freq=16),
#  FreqItemset(items=['Nicholas Carriero'], freq=32),
#  FreqItemset(items=['Nicholas Carriero', 'David Gelernter'], freq=23),
#  FreqItemset(items=['Ki Hwan Yum'], freq=30),
#  FreqItemset(items=['Ki Hwan Yum', 'Eun Jung Kim'], freq=28),
#  FreqItemset(items=['Ki Hwan Yum', 'Eun Jung Kim', 'Chita R. Das'], freq=11),
#  FreqItemset(items=['Ki Hwan Yum', 'Chita R. Das'], freq=12),
#  FreqItemset(items=['Benoît Naegel'], freq=18),
#  FreqItemset(items=['Po-Han Wu'], freq=28),
#  FreqItemset(items=['Konstantinos Konstantinides'], freq=18),
#  FreqItemset(items=['Christian M. Reidys'], freq=30),
#  FreqItemset(items=['Jingyue Li'], freq=35),
#  FreqItemset(items=['Jingyue Li', 'Reidar Conradi'], freq=31),
#  FreqItemset(items=['Mónica Marrero'], freq=12),
#  FreqItemset(items=['Tang Enya Kong'], freq=16),
#  FreqItemset(items=['Yongxian Liu'], freq=12),
#  FreqItemset(items=['Amnon Shabo'], freq=11),
#  FreqItemset(items=['Vanathi Gopalakrishnan'], freq=18),
#  FreqItemset(items=['Adam J. Tenenbaum'], freq=12),
#  FreqItemset(items=['Adam J. Tenenbaum', 'Raviraj S. Adve'], freq=12),
#  FreqItemset(items=['Béla Lantos'], freq=11),
#  FreqItemset(items=['Claudio Turchetti'], freq=44),
#  FreqItemset(items=['Spiros Skiadopoulos'], freq=40),
#  FreqItemset(items=['Spiros Skiadopoulos', 'Manolis Koubarakis'], freq=13),
#  FreqItemset(items=['Spiros Skiadopoulos', 'Panos Vassiliadis'], freq=18),
#  FreqItemset(items=['Eija Airio'], freq=12),
#  FreqItemset(items=['Joseph M. Kahn'], freq=36),
#  FreqItemset(items=['Utz Westermann'], freq=20),
#  FreqItemset(items=['Liang Gu'], freq=34),
#  FreqItemset(items=['Liang Gu', 'Yuqing Gao'], freq=12),
#  FreqItemset(items=['Julio Berrocal'], freq=19),
#  FreqItemset(items=['Julio Berrocal', 'Víctor A. Villagrá'], freq=14),
#  FreqItemset(items=['Takashi Hikihara'], freq=17),
#  FreqItemset(items=['Chi-Hsiang Lo'], freq=12),
#  FreqItemset(items=['Walid S. Saba'], freq=18),
#  FreqItemset(items=['Neelam Soundararajan'], freq=13),
#  FreqItemset(items=['Ashraf Wadaa'], freq=14),
#  FreqItemset(items=['Ashraf Wadaa', 'Mohamed Eltoweissy'], freq=12),
#  FreqItemset(items=['Henry Larkin'], freq=20),
#  FreqItemset(items=['Andriy Mnih'], freq=12),
#  FreqItemset(items=['Hans-Gerhard Gross'], freq=13),
#  FreqItemset(items=['Hui Lei'], freq=59),
#  FreqItemset(items=['Jonathan Cook'], freq=18),
#  FreqItemset(items=['Xiuguo Zhang'], freq=13),
#  FreqItemset(items=['Amali Weerasinghe'], freq=12),
#  FreqItemset(items=['Billy G. Claybrook'], freq=13),
#  FreqItemset(items=['Misha Tsodyks'], freq=22),
#  FreqItemset(items=['Paul Dalsgaard'], freq=41),
#  FreqItemset(items=['Matthew Ming-Fai Yuen'], freq=46),
#  FreqItemset(items=['Matthew Ming-Fai Yuen', 'Charlie C. L. Wang'], freq=14),
#  FreqItemset(items=['Dietmar Hildenbrand'], freq=12),
#  FreqItemset(items=['Steven Schockaert'], freq=58),
#  FreqItemset(items=['Steven Schockaert', 'Dirk Vermeir'], freq=14),
#  FreqItemset(items=['Steven Schockaert', 'Etienne E. Kerre'], freq=17),
#  FreqItemset(items=['Steven Schockaert', 'Martine De Cock'], freq=38),
#  FreqItemset(items=['Steven Schockaert', 'Martine De Cock', 'Dirk Vermeir'], freq=14),
#  FreqItemset(items=['Steven Schockaert', 'Martine De Cock', 'Etienne E. Kerre'], freq=17),
#  FreqItemset(items=['Martin Sauerhoff'], freq=34),
#  FreqItemset(items=['Guangyan Huang'], freq=20),
#  FreqItemset(items=['Guangyan Huang', 'Jing He'], freq=18),
#  FreqItemset(items=['Arthur M. Hobbs'], freq=14),
#  FreqItemset(items=['Zhihui Wang'], freq=23),
#  FreqItemset(items=['Zhihui Wang', 'Wei Wang'], freq=11),
#  FreqItemset(items=['Henrik Boström'], freq=45),
#  FreqItemset(items=['Ralf Mikut'], freq=22),
#  FreqItemset(items=['Tai-Ming Parng'], freq=15),
#  FreqItemset(items=['George Chryssolouris'], freq=22),
#  FreqItemset(items=['Inger Ekman'], freq=13),
#  FreqItemset(items=['Xiaojun Yang'], freq=20),
#  FreqItemset(items=['Myong K. Jeong'], freq=14),
#  FreqItemset(items=['Atsushi Shimizu'], freq=13),
#  FreqItemset(items=['Yoichi Muraoka'], freq=62),
#  FreqItemset(items=['Shin-ichi Tanigawa'], freq=25),
#  FreqItemset(items=['Shin-ichi Tanigawa', 'Naoki Katoh'], freq=16),
#  FreqItemset(items=['Leonidas Georgiadis'], freq=64),
#  FreqItemset(items=['Leonidas Georgiadis', 'Roch Guérin'], freq=11),
#  FreqItemset(items=['Leonidas Georgiadis', 'Leandros Tassiulas'], freq=15),
#  FreqItemset(items=['Dirk Thorleuchter'], freq=13),
#  FreqItemset(items=['Dirk Thorleuchter', 'Dirk Van den Poel'], freq=11),
#  FreqItemset(items=['Debargha Mukherjee'], freq=47),
#  FreqItemset(items=['Debargha Mukherjee', 'Ricardo L. de Queiroz'], freq=14),
#  FreqItemset(items=['Stanley Osher'], freq=95),
#  FreqItemset(items=['Jorge Vallejos'], freq=15),
#  FreqItemset(items=['Changle Li'], freq=23),
#  FreqItemset(items=['Changle Li', 'Jiandong Li'], freq=18),
#  FreqItemset(items=['Hiroshi Shigeno'], freq=61),
#  FreqItemset(items=['Hiroshi Shigeno', 'Ken-ichi Okada'], freq=36),
#  FreqItemset(items=['Hiroshi Shigeno', 'Yutaka Matsushita'], freq=11),
#  FreqItemset(items=['Rajat Subhra Chakraborty'], freq=27),
#  FreqItemset(items=['Rajat Subhra Chakraborty', 'Swarup Bhunia'], freq=22),
#  FreqItemset(items=['Frank Vetere'], freq=63),
#  FreqItemset(items=['Frank Vetere', 'Steve Howard'], freq=27),
#  FreqItemset(items=['Shen-Fu Hsiao'], freq=25),
#  FreqItemset(items=['Walfredo Cirne'], freq=54),
#  FreqItemset(items=['Walfredo Cirne', 'Francisco Vilar Brasileiro'], freq=23),
#  FreqItemset(items=['Robin Sommer'], freq=24),
#  FreqItemset(items=['Robin Sommer', 'Vern Paxson'], freq=16),
#  FreqItemset(items=['Filippo Molinari'], freq=15),
#  FreqItemset(items=['David T. Barnard'], freq=22),
#  FreqItemset(items=['Tobias Renk'], freq=14),
#  FreqItemset(items=['Tobias Renk', 'Friedrich Jondral'], freq=14),
#  FreqItemset(items=['Qiwei Jin'], freq=11),
#  FreqItemset(items=['Zhiwei Mao'], freq=15),
#  FreqItemset(items=['Manas Saksena'], freq=21),
#  FreqItemset(items=['Paul Davidsson'], freq=79),
#  FreqItemset(items=['J. C. C. McKinsey'], freq=11),
#  FreqItemset(items=["Rahul De'"], freq=13),
#  FreqItemset(items=['Gideon Frieder'], freq=15),
#  FreqItemset(items=['Chai Quek'], freq=102),
#  FreqItemset(items=['Stilian Stoev'], freq=11),
#  FreqItemset(items=['Bertil Svensson'], freq=30),
#  FreqItemset(items=['Dieter Merkl'], freq=81),
#  FreqItemset(items=['Dieter Merkl', 'Andreas Rauber'], freq=31),
#  FreqItemset(items=['Rainer Keller'], freq=27),
#  FreqItemset(items=['Rainer Keller', 'Michael M. Resch'], freq=11),
#  FreqItemset(items=['Gabor Gombás'], freq=16),
#  FreqItemset(items=['Gabor Gombás', 'Zoltán Balaton'], freq=14),
#  FreqItemset(items=['Frédéric Valette'], freq=26),
#  FreqItemset(items=['Burak Kantarci'], freq=24),
#  FreqItemset(items=['Burak Kantarci', 'Hussein T. Mouftah'], freq=15),
#  FreqItemset(items=['Xiaodong Huang'], freq=29),
#  FreqItemset(items=['Xiaodong Huang', 'Jason P. Jue'], freq=13),
#  FreqItemset(items=['Johannes Zeppenfeld'], freq=15),
#  FreqItemset(items=['Johannes Zeppenfeld', 'Andreas Herkersdorf'], freq=11),
#  FreqItemset(items=['Bülent Tavli'], freq=11),
#  FreqItemset(items=['Lionel Lapierre'], freq=11),
#  FreqItemset(items=['Mauro Castelli'], freq=16),
#  FreqItemset(items=['Mauro Castelli', 'Luca Manzoni'], freq=12),
#  FreqItemset(items=['Mauro Castelli', 'Luca Manzoni', 'Leonardo Vanneschi'], freq=11),
#  FreqItemset(items=['Mauro Castelli', 'Leonardo Vanneschi'], freq=15),
#  FreqItemset(items=['Zhenmin Tang'], freq=26),
#  FreqItemset(items=['Heang-Ping Chan'], freq=16),
#  FreqItemset(items=['Ning Zhong'], freq=303),
#  FreqItemset(items=['Marco Dalai'], freq=15),
#  FreqItemset(items=['Demetrios Sarantis'], freq=11),
#  FreqItemset(items=['Demetrios Sarantis', 'Dimitris Askounis'], freq=11),
#  FreqItemset(items=['Jérôme Simonin'], freq=11),
#  FreqItemset(items=['Kyung-Yong Chwa'], freq=86),
#  FreqItemset(items=['Xiaofeng He'], freq=30),
#  FreqItemset(items=['Xiaofeng He', 'Horst D. Simon'], freq=11),
#  FreqItemset(items=['Xiaofeng He', 'Horst D. Simon', 'Chris H. Q. Ding'], freq=11),
#  FreqItemset(items=['Xiaofeng He', 'Chris H. Q. Ding'], freq=25),
#  FreqItemset(items=['Xiaofeng He', 'Hongyuan Zha'], freq=12),
#  FreqItemset(items=['Xiaofeng He', 'Hongyuan Zha', 'Chris H. Q. Ding'], freq=12),
#  FreqItemset(items=['Johan F. Hoorn'], freq=28),
#  FreqItemset(items=['Zuochang Ye'], freq=18),
#  FreqItemset(items=['Shyam S. Pattnaik'], freq=16),
#  FreqItemset(items=['Idris Dag'], freq=12),
#  FreqItemset(items=['Chun-Hsiang Huang'], freq=16),
#  FreqItemset(items=['Chun-Hsiang Huang', 'Ja-Ling Wu'], freq=13),
#  FreqItemset(items=['Miklos Maroti'], freq=13),
#  FreqItemset(items=['Miklos Maroti', 'Ákos Lédeczi'], freq=12),
#  FreqItemset(items=['Ming Yao Xu'], freq=18),
#  FreqItemset(items=['Oliver Holschke'], freq=11),
#  FreqItemset(items=['Nils Papenberg'], freq=12),
#  FreqItemset(items=['Rida A. Bazzi'], freq=45),
#  FreqItemset(items=['Xiaoji Ye'], freq=16),
#  FreqItemset(items=['Xiaoji Ye', 'Peng Li'], freq=16),
#  FreqItemset(items=['Ho Joon Kim'], freq=12),
#  FreqItemset(items=['Christine Kühnel'], freq=12),
#  FreqItemset(items=['Christine Kühnel', 'Sebastian Möller'], freq=11),
#  FreqItemset(items=['J. M. van de Mortel-Fronczak'], freq=12),
#  FreqItemset(items=['J. M. van de Mortel-Fronczak', 'J. E. Rooda'], freq=11),
#  FreqItemset(items=['Chuan Lin'], freq=33),
#  FreqItemset(items=['Chuan Lin', 'Hai Zhou'], freq=15),
#  FreqItemset(items=['Ricardo Silva'], freq=37),
#  FreqItemset(items=["Eamonn O'Neill"], freq=44),
#  FreqItemset(items=["Eamonn O'Neill", 'Vassilis Kostakos'], freq=12),
#  FreqItemset(items=['Wen-Hsiao Peng'], freq=29),
#  FreqItemset(items=['Periklis A. Papakonstantinou'], freq=18),
#  FreqItemset(items=['Chieko Asakawa'], freq=40),
#  FreqItemset(items=['S. N. Sivanandam'], freq=13),
#  FreqItemset(items=['Brian P. Gerkey'], freq=21),
#  FreqItemset(items=['Guy Kindler'], freq=36),
#  FreqItemset(items=['Yiping Ke'], freq=33),
#  FreqItemset(items=['Yiping Ke', 'James Cheng'], freq=25),
#  FreqItemset(items=['Yiping Ke', 'James Cheng', 'Wilfred Ng'], freq=16),
#  FreqItemset(items=['Yiping Ke', 'Jeffrey Xu Yu'], freq=13),
#  FreqItemset(items=['Yiping Ke', 'Wilfred Ng'], freq=18),
#  FreqItemset(items=['Faisal Ahmad'], freq=14),
#  FreqItemset(items=['Faisal Ahmad', 'Tamara Sumner'], freq=14),
#  FreqItemset(items=['Paz Morillo'], freq=34),
#  FreqItemset(items=['Marco Vannucci'], freq=20),
#  FreqItemset(items=['Marco Vannucci', 'Valentina Colla'], freq=20),
#  FreqItemset(items=['Sorin Moga'], freq=12),
#  FreqItemset(items=['Sudhir R. Ghorpade'], freq=18),
#  FreqItemset(items=['Ariadna Quattoni'], freq=13),
#  FreqItemset(items=['Jean-Philippe Dubernard'], freq=13),
#  FreqItemset(items=['Ana Bove'], freq=17),
#  FreqItemset(items=['Malik Muhammad Saad Missen'], freq=12),
#  FreqItemset(items=['Stefan M. Dodunekov'], freq=20),
#  FreqItemset(items=['Hanna Mazzawi'], freq=12),
#  FreqItemset(items=['Hanna Mazzawi', 'Nader H. Bshouty'], freq=11),
#  FreqItemset(items=['Cishen Zhang'], freq=60),
#  FreqItemset(items=['Cishen Zhang', 'Lihua Xie'], freq=25),
#  FreqItemset(items=['Marilynn P. Wylie-Green'], freq=11),
#  FreqItemset(items=['Mohammed Belkhatir'], freq=45),
#  FreqItemset(items=['Sven Schuierer'], freq=46),
#  FreqItemset(items=['Sven Schuierer', 'Alejandro López-Ortiz'], freq=12),
#  FreqItemset(items=['Michel Buffa'], freq=22),
#  FreqItemset(items=['Michel Buffa', 'Fabien Gandon'], freq=11),
#  FreqItemset(items=['Emmanuel C. Ifeachor'], freq=41),
#  FreqItemset(items=['Robert M. MacGregor'], freq=21),
#  FreqItemset(items=['Jianjun Hu'], freq=37),
#  FreqItemset(items=['Jianjun Hu', 'Erik D. Goodman'], freq=13),
#  FreqItemset(items=['Antti Valmari'], freq=59),
#  FreqItemset(items=['Edgar E. Vallejo'], freq=20),
#  FreqItemset(items=['Young-Chon Kim'], freq=34),
#  FreqItemset(items=['Chris Gunn'], freq=14),
#  FreqItemset(items=['Shuguang Feng'], freq=19),
#  FreqItemset(items=['Shuguang Feng', 'Amin Ansari'], freq=17),
#  FreqItemset(items=['Shuguang Feng', 'Amin Ansari', 'Shantanu Gupta'], freq=17),
#  FreqItemset(items=['Shuguang Feng', 'Amin Ansari', 'Shantanu Gupta', 'Scott A. Mahlke'], freq=17),
#  FreqItemset(items=['Shuguang Feng', 'Amin Ansari', 'Scott A. Mahlke'], freq=17),
#  FreqItemset(items=['Shuguang Feng', 'Shantanu Gupta'], freq=19),
#  FreqItemset(items=['Shuguang Feng', 'Shantanu Gupta', 'Scott A. Mahlke'], freq=19),
#  FreqItemset(items=['Shuguang Feng', 'Scott A. Mahlke'], freq=19),
#  FreqItemset(items=['Kaoru Tone'], freq=12),
#  FreqItemset(items=['Raymond Hoare'], freq=14),
#  FreqItemset(items=['Huafei Zhu'], freq=63),
#  FreqItemset(items=['Huafei Zhu', 'Feng Bao'], freq=26),
#  FreqItemset(items=['Joaquín J. Torres'], freq=25),
#  FreqItemset(items=['Herman Schmit'], freq=48),
#  FreqItemset(items=['Victor L. Selivanov'], freq=55),
#  FreqItemset(items=['Claudia Löbbecke'], freq=23),
#  FreqItemset(items=['Stanimire Tomov'], freq=39),
#  FreqItemset(items=['Stanimire Tomov', 'Jack Dongarra'], freq=28),
#  FreqItemset(items=['Veikko Seppänen'], freq=21),
#  FreqItemset(items=['Juan A. Sánchez'], freq=15),
#  FreqItemset(items=['Juan A. Sánchez', 'Pedro M. Ruiz'], freq=14),
#  FreqItemset(items=['Jan Reimann'], freq=15),
#  FreqItemset(items=['Tamás Szonyi'], freq=25),
#  FreqItemset(items=['Hermann Brunner'], freq=14),
#  FreqItemset(items=['Patrick Meyer'], freq=19),
#  FreqItemset(items=['Gary L. Wise'], freq=16),
#  FreqItemset(items=['Philip Langer'], freq=15),
#  FreqItemset(items=['Philip Langer', 'Manuel Wimmer'], freq=15),
#  FreqItemset(items=['Stephen Winters-Hilt'], freq=23),
#  FreqItemset(items=['Rosa Laura Zavala Gutierrez'], freq=11),
#  FreqItemset(items=['Laura Monceaux'], freq=15),
#  FreqItemset(items=['Patrice Godefroid'], freq=81),
#  FreqItemset(items=['Marcel J. T. Reinders'], freq=109),
#  FreqItemset(items=['Marcel J. T. Reinders', 'Arjen P. de Vries'], freq=13),
#  FreqItemset(items=['Marcel J. T. Reinders', 'Jun Wang'], freq=11),
#  FreqItemset(items=['Dorothy E. Setliff'], freq=14),
#  FreqItemset(items=['Zicai Wang'], freq=11),
#  FreqItemset(items=['Diana Göhringer'], freq=26),
#  FreqItemset(items=['Diana Göhringer', 'Jürgen Becker'], freq=23),
#  FreqItemset(items=['Diana Göhringer', 'Michael Hübner'], freq=21),
#  FreqItemset(items=['Diana Göhringer', 'Michael Hübner', 'Jürgen Becker'], freq=21),
#  FreqItemset(items=['Bruno Buchberger'], freq=57),
#  FreqItemset(items=['Umeshwar Dayal'], freq=225),
#  FreqItemset(items=['Umeshwar Dayal', 'Daniel A. Keim'], freq=26),
#  FreqItemset(items=['George O. Wesolowsky'], freq=25),
#  FreqItemset(items=['George O. Wesolowsky', 'Zvi Drezner'], freq=15),
#  FreqItemset(items=['Andreas Lang'], freq=16),
#  FreqItemset(items=['Andreas Lang', 'Jana Dittmann'], freq=15),
#  FreqItemset(items=['Ojas Parekh'], freq=26),
#  FreqItemset(items=['Pedro López'], freq=105),
#  FreqItemset(items=['Pedro López', 'José Duato'], freq=87),
#  FreqItemset(items=['Stefanie N. Lindstaedt'], freq=79),
#  FreqItemset(items=['Zheng Yuan'], freq=30),
#  FreqItemset(items=['Bernhard Westfechtel'], freq=83),
#  FreqItemset(items=['Zhixiang Li'], freq=11),
#  FreqItemset(items=['David Baker'], freq=15),
#  FreqItemset(items=['Stephen J. McKenna'], freq=56),
#  FreqItemset(items=['Stephen J. McKenna', 'Shaogang Gong'], freq=18),
#  FreqItemset(items=['Yogesh Simmhan'], freq=26),
#  FreqItemset(items=['Brad Mehlenbacher'], freq=17),
#  FreqItemset(items=['Alex J. Ruiz-Torres'], freq=16),
#  FreqItemset(items=['Yeong-Dae Kim'], freq=24),
#  FreqItemset(items=['Lawrence Peter Belluce'], freq=16),
#  FreqItemset(items=['Lawrence Peter Belluce', 'Antonio di Nola'], freq=11),
#  FreqItemset(items=['Wenming Lin'], freq=11),
#  FreqItemset(items=['Aistis Raudys'], freq=15),
#  FreqItemset(items=['Deepaknath Tandur'], freq=11),
#  FreqItemset(items=['Andreas Albers'], freq=11),
#  FreqItemset(items=['Nobuo Suematsu'], freq=14),
#  FreqItemset(items=['Nobuo Suematsu', 'Akira Hayashi'], freq=13),
#  FreqItemset(items=['Krishna R. Pattipati'], freq=90),
#  FreqItemset(items=['Krishna R. Pattipati', 'Peter Willett'], freq=14),
#  FreqItemset(items=['Tun-Wen Pai'], freq=28),
#  FreqItemset(items=['Michio Ozeki'], freq=12),
#  FreqItemset(items=['André Schulz'], freq=36),
#  FreqItemset(items=['Elizabeth A. Kemp'], freq=33),
#  FreqItemset(items=['Chiara Epifanio'], freq=11),
#  FreqItemset(items=['Chiara Epifanio', 'Filippo Mignosi'], freq=11),
#  FreqItemset(items=['Immanuel M. Bomze'], freq=30),
#  FreqItemset(items=['Ibrahim Matta'], freq=88),
#  FreqItemset(items=['Ibrahim Matta', 'Azer Bestavros'], freq=32),
#  FreqItemset(items=['Trevor Barker'], freq=18),
#  FreqItemset(items=['Steven D. Johnson'], freq=28),
#  FreqItemset(items=['Frederick P. Roth'], freq=16),
#  FreqItemset(items=['Byung-Woo Hong'], freq=16),
#  FreqItemset(items=['Norihide Shinagawa'], freq=12),
#  FreqItemset(items=['Nikos Anastopoulos'], freq=11),
#  FreqItemset(items=['Nikos Anastopoulos', 'Nectarios Koziris'], freq=11),
#  FreqItemset(items=['Magnus Strengert'], freq=18),
#  FreqItemset(items=['Magnus Strengert', 'Thomas Ertl'], freq=14),
#  FreqItemset(items=['David Saff'], freq=11),
#  FreqItemset(items=['Neil I. Weisenfeld'], freq=11),
#  FreqItemset(items=['Boting Yang'], freq=45),
#  FreqItemset(items=['Peng Yan'], freq=16),
#  FreqItemset(items=['Eugenio Roanes-Lozano'], freq=36),
#  FreqItemset(items=['Haixia Li'], freq=12),
#  FreqItemset(items=['Karl-Friedrich Kraiss'], freq=37),
#  FreqItemset(items=['Tatsuya Kawahara'], freq=149),
#  FreqItemset(items=['Tatsuya Kawahara', 'Hiroshi G. Okuno'], freq=11),
#  FreqItemset(items=['Christopher A. Higgins'], freq=20),
#  FreqItemset(items=['Hamid Mahmoodi'], freq=34),
#  FreqItemset(items=['Hamid Mahmoodi', 'Kaushik Roy'], freq=12),
#  FreqItemset(items=['Chunyang Ye'], freq=19),
#  FreqItemset(items=['Robert Marti'], freq=45),
#  FreqItemset(items=['Robert Marti', 'Xavier Lladó'], freq=20),
#  FreqItemset(items=['Robert Marti', 'Arnau Oliver'], freq=28),
#  FreqItemset(items=['Robert Marti', 'Arnau Oliver', 'Xavier Lladó'], freq=20),
#  FreqItemset(items=['Robert Marti', 'Arnau Oliver', 'Jordi Freixenet'], freq=18),
#  FreqItemset(items=['Robert Marti', 'Arnau Oliver', 'Jordi Freixenet', 'Xavier Lladó'], freq=13),
#  FreqItemset(items=['Robert Marti', 'Jordi Freixenet'], freq=20),
#  FreqItemset(items=['Robert Marti', 'Jordi Freixenet', 'Xavier Lladó'], freq=13),
#  FreqItemset(items=['Oliver Vogel'], freq=18),
#  FreqItemset(items=['Oliver Vogel', 'Michael Breuß'], freq=11),
#  FreqItemset(items=['Igor Melatti'], freq=29),
#  FreqItemset(items=['Igor Melatti', 'Giuseppe Della Penna'], freq=13),
#  FreqItemset(items=['Igor Melatti', 'Giuseppe Della Penna', 'Enrico Tronci'], freq=11),
#  FreqItemset(items=['Igor Melatti', 'Giuseppe Della Penna', 'Benedetto Intrigila'], freq=12),
#  FreqItemset(items=['Igor Melatti', 'Enrico Tronci'], freq=24),
#  FreqItemset(items=['Igor Melatti', 'Enrico Tronci', 'Benedetto Intrigila'], freq=11),
#  FreqItemset(items=['Igor Melatti', 'Benedetto Intrigila'], freq=14),
#  FreqItemset(items=['Stanley Kok'], freq=13),
#  FreqItemset(items=['Manuel Gómez'], freq=17),
#  FreqItemset(items=['Timothy Clark'], freq=19),
#  FreqItemset(items=['Jacques Simonin'], freq=12),
#  FreqItemset(items=['Shabsi Walfish'], freq=11),
#  FreqItemset(items=['Philipp Muigg'], freq=13),
#  FreqItemset(items=['Philipp Muigg', 'Helmut Doleisch'], freq=11),
#  FreqItemset(items=['Bart Mesman'], freq=46),
#  FreqItemset(items=['Bart Mesman', 'Henk Corporaal'], freq=30),
#  FreqItemset(items=['Konstantinos Votis'], freq=22),
#  FreqItemset(items=['Konstantinos Votis', 'Dimitrios Tzovaras'], freq=13),
#  FreqItemset(items=['Adolfy Hoisie'], freq=42),
#  FreqItemset(items=['Adolfy Hoisie', 'Darren J. Kerbyson'], freq=21),
#  FreqItemset(items=['Adolfy Hoisie', 'Fabrizio Petrini'], freq=11),
#  FreqItemset(items=['Vibha Singhal Sinha'], freq=12),
#  FreqItemset(items=['Minghui Wu'], freq=38),
#  FreqItemset(items=['Masoumeh Safkhani'], freq=20),
#  FreqItemset(items=['Masoumeh Safkhani', 'Majid Naderi'], freq=18),
#  FreqItemset(items=['Masoumeh Safkhani', 'Majid Naderi', 'Nasour Bagheri'], freq=17),
#  FreqItemset(items=['Masoumeh Safkhani', 'Nasour Bagheri'], freq=19),
#  FreqItemset(items=['Rosanna E. Guadagno'], freq=14),
#  FreqItemset(items=['John D. Kececioglu'], freq=32),
#  FreqItemset(items=['Myung-Joon Kim'], freq=19),
#  FreqItemset(items=['Ana Petric'], freq=14),
#  FreqItemset(items=['Negar Kiyavash'], freq=42),
#  FreqItemset(items=['Negar Kiyavash', 'Todd P. Coleman'], freq=14),
#  FreqItemset(items=['G. Tanner Jackson'], freq=22),
#  FreqItemset(items=['G. Tanner Jackson', 'Danielle S. McNamara'], freq=12),
#  FreqItemset(items=['Ashok U. Mallya'], freq=18),
#  FreqItemset(items=['Ashok U. Mallya', 'Munindar P. Singh'], freq=16),
#  FreqItemset(items=['David Gerhard'], freq=13),
#  FreqItemset(items=['Jui-Feng Weng'], freq=21),
#  FreqItemset(items=['Jui-Feng Weng', 'Shian-Shyong Tseng'], freq=21),
#  FreqItemset(items=['Harish Srinivasan'], freq=14),
#  FreqItemset(items=['Harish Srinivasan', 'Sargur N. Srihari'], freq=14),
#  FreqItemset(items=['Pierpaolo Baglietto'], freq=20),
#  FreqItemset(items=['Pierpaolo Baglietto', 'Massimo Maresca'], freq=16),
#  FreqItemset(items=['Andrzej Tarczynski'], freq=19),
#  FreqItemset(items=['J. R. Sharma'], freq=13),
#  FreqItemset(items=['Amanda G. Chetwynd'], freq=14),
#  FreqItemset(items=['Takeshi Masuda'], freq=19),
#  FreqItemset(items=['A. Jefferson Offutt'], freq=55),
#  FreqItemset(items=['Xiabi Liu'], freq=13),
#  FreqItemset(items=['Xiabi Liu', 'Yunde Jia'], freq=13),
#  FreqItemset(items=['Michael Schulz'], freq=12),
#  FreqItemset(items=['Chung-Min Chen'], freq=43),
#  FreqItemset(items=['C. Paul Bonnington'], freq=22),
#  FreqItemset(items=['Stéphan Thomassé'], freq=64),
#  FreqItemset(items=['Hiroshi Saito'], freq=54),
#  FreqItemset(items=['Hiroshi Saito', 'Takashi Nanya'], freq=12),
#  FreqItemset(items=['Hong Ji'], freq=56),
#  FreqItemset(items=['Hong Ji', 'Victor C. M. Leung'], freq=16),
#  FreqItemset(items=['Hong Ji', 'F. Richard Yu'], freq=21),
#  FreqItemset(items=['Hong Ji', 'Xi Li'], freq=12),
#  FreqItemset(items=['Ted Bapty'], freq=26),
#  FreqItemset(items=['Ted Bapty', 'Sandeep Neema'], freq=15),
#  FreqItemset(items=['Piotr Gawkowski'], freq=20),
#  FreqItemset(items=['Piotr Gawkowski', 'Janusz Sosnowski'], freq=19),
#  FreqItemset(items=['Gary M. Olson'], freq=43),
#  FreqItemset(items=['Gary M. Olson', 'Judith S. Olson'], freq=24),
#  FreqItemset(items=['Yevgeniy Bodyanskiy'], freq=23),
#  FreqItemset(items=['Fuhui Long'], freq=22),
#  FreqItemset(items=['Fuhui Long', 'Hanchuan Peng'], freq=22),
#  FreqItemset(items=['William J. Godinez'], freq=15),
#  FreqItemset(items=['William J. Godinez', 'Karl Rohr'], freq=15),
#  FreqItemset(items=['William J. Godinez', 'Roland Eils'], freq=14),
#  FreqItemset(items=['William J. Godinez', 'Roland Eils', 'Karl Rohr'], freq=14),
#  FreqItemset(items=['D. V. Lande'], freq=14),
#  FreqItemset(items=['Paulo Ferreira'], freq=85),
#  FreqItemset(items=['Makoto Okada'], freq=14),
#  FreqItemset(items=['Michael Colón'], freq=13),
#  FreqItemset(items=['Beno Benhabib'], freq=59),
#  FreqItemset(items=['Franco Turini'], freq=114),
#  FreqItemset(items=['Franco Turini', 'Antonio Brogi'], freq=18),
#  FreqItemset(items=['Franco Turini', 'Fosca Giannotti'], freq=14),
#  FreqItemset(items=['Franco Turini', 'Dino Pedreschi'], freq=25),
#  FreqItemset(items=['Lian Li'], freq=83),
#  FreqItemset(items=['Lian Li', 'Jingling Xue'], freq=11),
#  FreqItemset(items=['Lian Li', 'Li Liu'], freq=15),
#  FreqItemset(items=['Lian Li', 'Yi Yang'], freq=12),
#  FreqItemset(items=['Görschwin Fey'], freq=70),
#  FreqItemset(items=['Görschwin Fey', 'Rolf Drechsler'], freq=59),
#  FreqItemset(items=['Y. Thomas Hou'], freq=58),
#  FreqItemset(items=['Y. Thomas Hou', 'Yi Shi'], freq=37),
#  FreqItemset(items=['Y. Thomas Hou', 'Yi Shi', 'Hanif D. Sherali'], freq=15),
#  FreqItemset(items=['Y. Thomas Hou', 'Jia Liu'], freq=15),
#  FreqItemset(items=['Y. Thomas Hou', 'Hanif D. Sherali'], freq=19),
#  FreqItemset(items=['Jean-Pierre Jessel'], freq=26),
#  FreqItemset(items=['Richard A. Brualdi'], freq=52),
#  FreqItemset(items=['Federico Alvarez'], freq=16),
#  FreqItemset(items=['Javier González'], freq=25),
#  FreqItemset(items=['Tineke M. Egyedi'], freq=23),
#  FreqItemset(items=['Shi Wang'], freq=28),
#  FreqItemset(items=['Christian Krause'], freq=15),
#  FreqItemset(items=['Henrik Lundqvist'], freq=11),
#  FreqItemset(items=['Fernando Perdigão'], freq=14),
#  FreqItemset(items=['Erkan Zergeroglu'], freq=21),
#  FreqItemset(items=['Vasileios D. Papoutsis'], freq=11),
#  FreqItemset(items=['Hiroshi Someya'], freq=11),
#  FreqItemset(items=['Yueping Li'], freq=16),
#  FreqItemset(items=['Alexandros Paramythis'], freq=12),
#  FreqItemset(items=['Sagi Snir'], freq=36),
#  FreqItemset(items=['Ashley T. McNeile'], freq=15),
#  FreqItemset(items=['Dan Zhang'], freq=127),
#  FreqItemset(items=['Changhua Hu'], freq=11),
#  FreqItemset(items=['Johannes Uhlmann'], freq=31),
#  FreqItemset(items=['Johannes Uhlmann', 'Rolf Niedermeier'], freq=21),
#  FreqItemset(items=['Johannes Uhlmann', 'Christian Komusiewicz'], freq=15),
#  FreqItemset(items=['Johannes Uhlmann', 'Jiong Guo'], freq=13),
#  FreqItemset(items=['Eric W. Brown'], freq=28),
#  FreqItemset(items=['P. John Clarkson'], freq=72),
#  FreqItemset(items=['P. John Clarkson', 'Peter Robinson'], freq=14),
#  FreqItemset(items=['Nobuko Yoshida'], freq=93),
#  FreqItemset(items=['Davide Adami'], freq=36),
#  FreqItemset(items=['Davide Adami', 'Stefano Giordano'], freq=33),
#  FreqItemset(items=['Davide Adami', 'Michele Pagano'], freq=24),
#  FreqItemset(items=['Davide Adami', 'Michele Pagano', 'Stefano Giordano'], freq=24),
#  FreqItemset(items=['Ramón Gallardo Caballero'], freq=16),
#  FreqItemset(items=['Ramón Gallardo Caballero', 'Miguel Macías Macías'], freq=14),
#  FreqItemset(items=['Ramón Gallardo Caballero', 'Miguel Macías Macías', 'Carlos J. García Orellana'], freq=14),
#  FreqItemset(items=['Ramón Gallardo Caballero', 'Carlos J. García Orellana'], freq=16),
#  FreqItemset(items=['Ramón Gallardo Caballero', 'Horacio M. González Velasco'], freq=15),
#  FreqItemset(items=['Ramón Gallardo Caballero', 'Horacio M. González Velasco', 'Miguel Macías Macías'], freq=14),
#  FreqItemset(items=['Ramón Gallardo Caballero', 'Horacio M. González Velasco', 'Miguel Macías Macías', 'Carlos J. García Orellana'], freq=14),
#  FreqItemset(items=['Ramón Gallardo Caballero', 'Horacio M. González Velasco', 'Carlos J. García Orellana'], freq=15),
#  FreqItemset(items=['James F. Geelen'], freq=25),
#  FreqItemset(items=['Jean-Paul Jamont'], freq=33),
#  FreqItemset(items=['Jean-Paul Jamont', 'Michel Occello'], freq=29),
#  FreqItemset(items=['Jeff Lichtman'], freq=12),
#  FreqItemset(items=['Sei Ikeda'], freq=16),
#  FreqItemset(items=['Sei Ikeda', 'Tomokazu Sato'], freq=12),
#  FreqItemset(items=['Sei Ikeda', 'Tomokazu Sato', 'Naokazu Yokoya'], freq=12),
#  FreqItemset(items=['Sei Ikeda', 'Naokazu Yokoya'], freq=12),
#  FreqItemset(items=['Nikhil Jayakumar'], freq=28),
#  FreqItemset(items=['Nikhil Jayakumar', 'Sunil P. Khatri'], freq=27),
#  FreqItemset(items=['K. S. Fu'], freq=31),
#  FreqItemset(items=['Loren G. Terveen'], freq=90),
#  FreqItemset(items=['Loren G. Terveen', 'John Riedl'], freq=12),
#  FreqItemset(items=['Jim Schroeder'], freq=18),
#  FreqItemset(items=['Eric Pacuit'], freq=29),
#  FreqItemset(items=['Matthieu Molinier'], freq=11),
#  FreqItemset(items=['Roberto Musmanno'], freq=25),
#  FreqItemset(items=['Roberto Musmanno', 'Gianpaolo Ghiani'], freq=12),
#  FreqItemset(items=['Chun Nie'], freq=12),
#  FreqItemset(items=['Lien-Wu Chen'], freq=12),
#  FreqItemset(items=['Lien-Wu Chen', 'Yu-Chee Tseng'], freq=12),
#  FreqItemset(items=['Michael Klemm'], freq=16),
#  FreqItemset(items=['Stuart J. Norcross'], freq=11),
#  FreqItemset(items=['Stuart J. Norcross', 'Alan Dearle'], freq=11),
#  FreqItemset(items=['Stuart J. Norcross', 'Graham N. C. Kirby'], freq=11),
#  FreqItemset(items=['Stuart J. Norcross', 'Graham N. C. Kirby', 'Alan Dearle'], freq=11),
#  FreqItemset(items=['Francisco J. Pino'], freq=34),
#  FreqItemset(items=['Francisco J. Pino', 'Félix García'], freq=24),
#  FreqItemset(items=['Francisco J. Pino', 'Félix García', 'Mario Piattini'], freq=24),
#  ...]

# %% [markdown]
# When I tried to train model with support threshold of 1e-6, the program just crashed with a 'out of memory error'. As the pattern shown in the three thresholds above, the number of frequent itemsets is increasing and the upper bound of frequency decresed. So I think it is because when the threshold is really low and there would be a great number of frequent itemsets generated whhich costs a lot memory and system resources.

# %% [markdown]
# ### Part b

# %% [markdown]
# To find co-author relationship, I save the freqent itemset result in a list called 'res'. And use function 'findCoAuthor' to filter targeted author and sort the result.

# %%
def takeSecond(tup):
    return tup[1]
def findCoAuthor(fis, name):
    l = []
    for fi in fis:
        if name in fi[0]:
            l.append(fi)
    l.sort(key=takeSecond, reverse=True)
    return l[:5]
ra = findCoAuthor(res, 'Rakesh Agrawal')
jh = findCoAuthor(res, 'Jiawei Han')
zg = findCoAuthor(res, 'Zoubin Ghahramani')
cf = findCoAuthor(res, 'Christos Faloutsos')

# %%
ra
# Out:
# [FreqItemset(items=['Rakesh Agrawal'], freq=199),
#  FreqItemset(items=['Ramakrishnan Srikant', 'Rakesh Agrawal'], freq=33),
#  FreqItemset(items=['Jerry Kiernan', 'Rakesh Agrawal'], freq=16),
#  FreqItemset(items=['Rakesh Agrawal', 'H. V. Jagadish'], freq=15),
#  FreqItemset(items=['Yirong Xu', 'Rakesh Agrawal'], freq=11)]

# %% [markdown]
# The top-5 co-authors for Rakesh Agrawal are Ramakrishnan Srikant, Jerry Kiernan, H. V. Jagadish, Roberto J. Bayardo Jr. and Yirong Xu.

# %%
jh
# Out:
# [FreqItemset(items=['Jiawei Han'], freq=581),
#  FreqItemset(items=['Xifeng Yan', 'Jiawei Han'], freq=55),
#  FreqItemset(items=['Jiawei Han', 'Philip S. Yu'], freq=51),
#  FreqItemset(items=['Jian Pei', 'Jiawei Han'], freq=37),
#  FreqItemset(items=['Yizhou Sun', 'Jiawei Han'], freq=32)]

# %% [markdown]
# The top-5 co-authors of Jiawei Han are Xifeng Yan, Philip S. Yu, Jian Pei, Yizhou Sun, Xin Jin.

# %%
zg
# Out:
# [FreqItemset(items=['Zoubin Ghahramani'], freq=157),
#  FreqItemset(items=['David L. Wild', 'Zoubin Ghahramani'], freq=15),
#  FreqItemset(items=['Katherine A. Heller', 'Zoubin Ghahramani'], freq=13),
#  FreqItemset(items=['Zoubin Ghahramani', 'Michael I. Jordan'], freq=11)]

# %% [markdown]
# The top-5 co-authors of Zoubin Ghahramani are David L. Wild, Katherine A. Heller, Michael I. Jordan.

# %%
cf
# Out:
# [FreqItemset(items=['Christos Faloutsos'], freq=374),
#  FreqItemset(items=['Hanghang Tong', 'Christos Faloutsos'], freq=27),
#  FreqItemset(items=['Spiros Papadimitriou', 'Christos Faloutsos'], freq=26),
#  FreqItemset(items=['Jimeng Sun', 'Christos Faloutsos'], freq=24),
#  FreqItemset(items=['Agma J. M. Traina', 'Christos Faloutsos'], freq=24)]

# %% [markdown]
# The top-5 co-authors of Christos Faloutsos are Hanghang Tong, Spiros Papadimitriou, Jimeng Sun, Agma J. M. Traina, Caetano Traina Jr..

# %% [markdown]
# ## Problem 3

# %% [markdown]
# ### Part a

# %% [markdown]
# For Problem 3, we have to first construct a list of venues for each author. So use the same method as in Excercise 2, I import `pandas` and do some wrangling with regex and `pandas` functions. And then call `FPGrowth.train()` to find frequent itemsets according to target support threshold and `collect()` to bring in the results.

# %%
import pandas as pd
df = pd.read_csv('q4_dataset.txt', delimiter='\t')
df.columns = ['col']
authors=df[df['col'].str.contains(r'^#@(.*)')]
authors=authors['col'].str.replace('#@', '')
venues=df[df['col'].str.contains(r'^#c(.*)')]
venues=venues['col'].str.replace('#c', '')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
authors=authors.reset_index(drop=True)
venues=venues.reset_index(drop=True)

# %%
df_new = pd.concat([authors, venues], axis=1)

# %%
df_new.columns = ['authors', 'venue']

# %%
df_new = df_new.drop('authors', axis=1).join(df_new['authors'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('author'))

# %%
author_agg=df_new.groupby('author').agg(','.join).reset_index()

# %%
author_agg
# Out:
#                           author  \
# 0
# 1                 Abhay Harpale
# 2                         Ai Wen
# 3                      Aihua Bao
# 4                        Bin Han
# 5                   Bo Andersson
# 6                        Bo Wang
# 7                 Chen Ting Zhao
# 8            Christos Faloutsos
# 9                      Chun E Ma
# 10                     Cong Wang
# 11        Evangelos Papalexakis
# 12              Geoffrey I. Webb
# 13                     Guilin Qi
# 14                   Haifeng Liu
# 15                  Haitao Zheng
# 16                Hajime Kishida
# 17                   Haofen Wang
# 18                   Hongyan YUN
# 19                        Hua Li
# 20                        Hua Xu
# 21                   Huajun Chen
# 22                      Jeff Pan
# 23                   Jiajia Miao
# 24                  Jianliang XU
# 25                           Jun
# 26                     Jun Zhang
# 27                       Ke Ding
# 28                       Lei Hou
# 29                         Li Yi
# ...                          ...
# 1232511            étienne Mémin
# 1232512             éva Czabarka
# 1232513              éva Simonin
# 1232514              éva Székely
# 1232515              ítalo Cunha
# 1232516              òscar Celma
# 1232517          ólafur Hlynsson
# 1232518            óscar Ciaurri
# 1232519             óscar Corcho
# 1232520          óscar Ferrández
# 1232521             óscar García
# 1232522       óscar García-López
# 1232523           óscar González
# 1232524             óscar Ibá?ez
# 1232525  óscar Jesús Rubio Martí
# 1232526            óscar Jiménez
# 1232527              óscar Lopez
# 1232528             óscar Martín
# 1232529       óscar Mu?oz-García
# 1232530            óscar Reinoso
# 1232531       ü. Erkan Mumcuoglu
# 1232532               ülle Kotta
# 1232533             ümit ?zgüner
# 1232534              ümit Ayg?lü
# 1232535               ümit Güler
# 1232536            ümit Mersinli
# 1232537       ümit V. ?atalyürek
# 1232538            ümit Y. Ogras
# 1232539               ürün Dogan
# 1232540          陶金灿 Huajun Chen
#
#                                                      venue
# 0        The INGRES Papers,The INGRES Papers,The TSQL2 ...
# 1                                                      KDD
# 2                                                     CSWS
# 3                                                     CSWS
# 4                                                     CSWS
# 5                                                     CSWS
# 6                                                     CSWS
# 7                                                     CSWS
# 8                                                      KDD
# 9                                                     CSWS
# 10                                                    CSWS
# 11                                                     KDD
# 12                                                    PKAW
# 13                                               CSWS,CSWS
# 14                                                    CSWS
# 15                                                    CSWS
# 16                                                    CSWS
# 17                                                    CSWS
# 18                                                    CSWS
# 19                                                    CSWS
# 20                                                    CSWS
# 21                                                    CSWS
# 22                                               CSWS,CSWS
# 23                                                    CSWS
# 24                                                    CSWS
# 25                                                    CSWS
# 26                                                    CSWS
# 27                                               CSWS,CSWS
# 28                                                    CSWS
# 29                                                    CSWS
# ...                                                    ...
# 1232511                                           ICIP (1)
# 1232512                                               CoRR
# 1232513                                                SMC
# 1232514                                      SLT,LREC,LREC
# 1232515                                               PAM
# 1232516                                              IJMIR
# 1232517                                               FACS
# 1232518  Journal of Approximation Theory,ICPCA/SWS,ICPC...
# 1232519  AGILE Conf.,Multimedia Tools Appl.,eScience,J....
# 1232520  JAMIA,Procesamiento del Lenguaje Natural,Proce...
# 1232521  Journal of Circuits, Systems, and Computers,IE...
# 1232522                      The Journal of Supercomputing
# 1232523                                               CoRR
# 1232524                               IEEE Comp. Int. Mag.
# 1232525                  Journal of Biomedical Informatics
# 1232526        IEEE Transactions on Industrial Electronics
# 1232527  IEEE Transactions on Industrial Electronics,IE...
# 1232528                                          ICPCA/SWS
# 1232529                                               IJEB
# 1232530                      IEEE Transactions on Robotics
# 1232531                                 J. Digital Imaging
# 1232532              CDC,CDC,CCA,Systems & Control Letters
# 1232533        IEEE Transactions on Industrial Electronics
# 1232534                                                ICC
# 1232535                                                CIG
# 1232536                                               LREC
# 1232537                 Scientific Programming,ASONAM,CoRR
# 1232538            Lecture Notes In Electrical Engineering
# 1232539                                               CoRR
# 1232540                                               CSWS
#
# [1232541 rows x 2 columns]

# %%
author_agg=author_agg.drop(df.head(1).index)

# %%
author_agg['venue'].to_csv('author_agg.csv', sep='\n', index=False)

# %%
author_venues=sc.textFile('author_agg.csv')

# %%
venue_train = author_venues.map(lambda line: line.strip().split(',')).map(lambda x: list(set(x)))

# %%
venue1 = FPGrowth.train(venue_train, 1e-3, 2)
venue_res1 = venue1.freqItemsets().collect()

# %%
venue_res1
# Out:
# [FreqItemset(items=['IEEE Transactions on Information Technology in Biomedicine'], freq=3930),
#  FreqItemset(items=['RoboCup'], freq=1651),
#  FreqItemset(items=['Knowl.-Based Syst.'], freq=3027),
#  FreqItemset(items=['PaCT'], freq=1588),
#  FreqItemset(items=['ISSCC'], freq=4950),
#  FreqItemset(items=['KES (3)'], freq=1913),
#  FreqItemset(items=['Multimedia Tools Appl.'], freq=3174),
#  FreqItemset(items=['EUROMICRO'], freq=1734),
#  FreqItemset(items=['Biological Cybernetics'], freq=3453),
#  FreqItemset(items=['ACL'], freq=2800),
#  FreqItemset(items=['SOFSEM'], freq=1331),
#  FreqItemset(items=['IEEE SCC'], freq=1970),
#  FreqItemset(items=['J. Comb. Optim.'], freq=1303),
#  FreqItemset(items=['Int. J. Math. Mathematical Sciences'], freq=1775),
#  FreqItemset(items=['OTM Workshops'], freq=1814),
#  FreqItemset(items=['SEKE'], freq=3650),
#  FreqItemset(items=['GECCO'], freq=4545),
#  FreqItemset(items=['International Conference on Internet Computing'], freq=1857),
#  FreqItemset(items=['VTS'], freq=1702),
#  FreqItemset(items=['IACR Cryptology ePrint Archive'], freq=4290),
#  FreqItemset(items=['CCA'], freq=2021),
#  FreqItemset(items=['EvoWorkshops'], freq=1261),
#  FreqItemset(items=['JASIST'], freq=2907),
#  FreqItemset(items=['ASPLOS'], freq=1404),
#  FreqItemset(items=['ICS'], freq=1926),
#  FreqItemset(items=[' Pract. Exper.'], freq=4636),
#  FreqItemset(items=['CloudCom'], freq=1305),
#  FreqItemset(items=['Journal of Chemical Information and Modeling'], freq=1826),
#  FreqItemset(items=['Euro-Par'], freq=4342),
#  FreqItemset(items=['BMEI'], freq=3220),
#  FreqItemset(items=['IEEE Micro'], freq=1744),
#  FreqItemset(items=['Computers & Geosciences'], freq=3515),
#  FreqItemset(items=['MUE'], freq=1278),
#  FreqItemset(items=['AAAI/IAAI'], freq=1985),
#  FreqItemset(items=['Pacific Symposium on Biocomputing'], freq=1783),
#  FreqItemset(items=['Computer Physics Communications'], freq=5119),
#  FreqItemset(items=['Computers & Education'], freq=3694),
#  FreqItemset(items=['Computer Networks'], freq=7289),
#  FreqItemset(items=['Computer Networks', 'GLOBECOM'], freq=1730),
#  FreqItemset(items=['Computer Networks', 'Computer Communications'], freq=1664),
#  FreqItemset(items=['Computer Networks', 'ICC'], freq=1713),
#  FreqItemset(items=['Computer Networks', 'INFOCOM'], freq=1651),
#  FreqItemset(items=['Computer Networks', 'CoRR'], freq=1308),
#  FreqItemset(items=['Operating Systems Review'], freq=2189),
#  FreqItemset(items=['MOBICOM'], freq=1339),
#  FreqItemset(items=['ICPCA/SWS'], freq=2040),
#  FreqItemset(items=['IEEE T. Instrumentation and Measurement'], freq=8581),
#  FreqItemset(items=['GrC'], freq=2125),
#  FreqItemset(items=['Signal Processing'], freq=6372),
#  FreqItemset(items=['Signal Processing', 'IEEE Transactions on Signal Processing'], freq=1729),
#  FreqItemset(items=['Signal Processing', 'ICASSP'], freq=1326),
#  FreqItemset(items=['J. Comput. Physics'], freq=4071),
#  FreqItemset(items=['SIGCOMM'], freq=1875),
#  FreqItemset(items=['ICEIS'], freq=1431),
#  FreqItemset(items=['Networks'], freq=2263),
#  FreqItemset(items=['ISVC (1)'], freq=1374),
#  FreqItemset(items=['PKDD'], freq=1237),
#  FreqItemset(items=['ISMIR'], freq=1348),
#  FreqItemset(items=['IRI'], freq=2092),
#  FreqItemset(items=['IJCNN'], freq=6628),
#  FreqItemset(items=['IEEE Trans. Knowl. Data Eng.'], freq=4176),
#  FreqItemset(items=['Computer Communication Review'], freq=1547),
#  FreqItemset(items=['PPSN'], freq=1379),
#  FreqItemset(items=['ICCSA (1)'], freq=2151),
#  FreqItemset(items=['GLOBECOM'], freq=14374),
#  FreqItemset(items=['GLOBECOM', 'ICC'], freq=5962),
#  FreqItemset(items=['GLOBECOM', 'ICC', 'CoRR'], freq=1791),
#  FreqItemset(items=['GLOBECOM', 'IEICE Transactions'], freq=1893),
#  FreqItemset(items=['GLOBECOM', 'CoRR'], freq=2941),
#  FreqItemset(items=['IDEAS'], freq=1257),
#  FreqItemset(items=['PLoS Computational Biology'], freq=7643),
#  FreqItemset(items=['PLoS Computational Biology', 'Bioinformatics'], freq=1593),
#  FreqItemset(items=['PLoS Computational Biology', 'BMC Bioinformatics'], freq=1288),
#  FreqItemset(items=['International Journal of Geographical Information Science'], freq=2207),
#  FreqItemset(items=['PPSC'], freq=1942),
#  FreqItemset(items=['Theor. Comput. Sci.'], freq=9026),
#  FreqItemset(items=['Theor. Comput. Sci.', 'CoRR'], freq=3550),
#  FreqItemset(items=['Comp. Opt. and Appl.'], freq=1413),
#  FreqItemset(items=['Data Knowl. Eng.'], freq=2458),
#  FreqItemset(items=['OOPSLA Companion'], freq=1438),
#  FreqItemset(items=['Eur. J. Comb.'], freq=2275),
#  FreqItemset(items=['Eur. J. Comb.', 'Discrete Mathematics'], freq=1284),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications'], freq=5746),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'GLOBECOM'], freq=2931),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'GLOBECOM', 'ICC'], freq=2111),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'VTC Fall'], freq=1379),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'ICC'], freq=2909),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'PIMRC'], freq=1442),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'IEEE Transactions on Signal Processing'], freq=1270),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'IEEE Transactions on Communications'], freq=1880),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'IEEE Transactions on Communications', 'GLOBECOM'], freq=1380),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'IEEE Transactions on Communications', 'ICC'], freq=1396),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'IEEE Journal on Selected Areas in Communications'], freq=1369),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'WCNC'], freq=1813),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'WCNC', 'GLOBECOM'], freq=1394),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'WCNC', 'ICC'], freq=1363),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'VTC Spring'], freq=1526),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'IEEE Communications Letters'], freq=1654),
#  FreqItemset(items=['IEEE Transactions on Wireless Communications', 'CoRR'], freq=1679),
#  FreqItemset(items=['Ars Comb.'], freq=2570),
#  FreqItemset(items=['Ars Comb.', 'Discrete Mathematics'], freq=1289),
#  FreqItemset(items=['CW'], freq=1477),
#  FreqItemset(items=['ISM'], freq=1901),
#  FreqItemset(items=['JAMIA'], freq=4418),
#  FreqItemset(items=['IEEE ICCI'], freq=1289),
#  FreqItemset(items=['CIT'], freq=4717),
#  FreqItemset(items=['Integrated Network Management'], freq=2005),
#  FreqItemset(items=['Security and Management'], freq=1509),
#  FreqItemset(items=['PVM/MPI'], freq=1323),
#  FreqItemset(items=['ICIC (1)'], freq=2362),
#  FreqItemset(items=['IJMTM'], freq=1450),
#  FreqItemset(items=['IEEE Trans. on CAD of Integrated Circuits and Systems'], freq=5986),
#  FreqItemset(items=['IEEE Trans. on CAD of Integrated Circuits and Systems', 'DAC'], freq=2233),
#  FreqItemset(items=['IEEE Trans. on CAD of Integrated Circuits and Systems', 'DATE'], freq=1546),
#  FreqItemset(items=['WETICE'], freq=2118),
#  FreqItemset(items=['VTC Fall'], freq=6902),
#  FreqItemset(items=['VTC Fall', 'GLOBECOM'], freq=2175),
#  FreqItemset(items=['VTC Fall', 'GLOBECOM', 'ICC'], freq=1452),
#  FreqItemset(items=['VTC Fall', 'ICC'], freq=2139),
#  FreqItemset(items=['VTC Fall', 'IEICE Transactions'], freq=1255),
#  FreqItemset(items=['VTC Fall', 'WCNC'], freq=1808),
#  FreqItemset(items=['VTC Fall', 'VTC Spring'], freq=2410),
#  FreqItemset(items=['CIS'], freq=2707),
#  FreqItemset(items=['ACM Trans. Design Autom. Electr. Syst.'], freq=1358),
#  FreqItemset(items=['DSD'], freq=2488),
#  FreqItemset(items=['STOC'], freq=2164),
#  FreqItemset(items=['STOC', 'CoRR'], freq=1262),
#  FreqItemset(items=['EACL'], freq=1389),
#  FreqItemset(items=['Computer Communications'], freq=7949),
#  FreqItemset(items=['Computer Communications', 'GLOBECOM'], freq=1903),
#  FreqItemset(items=['Computer Communications', 'GLOBECOM', 'ICC'], freq=1238),
#  FreqItemset(items=['Computer Communications', 'ICC'], freq=1906),
#  FreqItemset(items=['ESANN'], freq=2223),
#  FreqItemset(items=['ACSAC'], freq=1572),
#  FreqItemset(items=['ICANN'], freq=1634),
#  FreqItemset(items=['ISCAS (5)'], freq=2843),
#  FreqItemset(items=['PLDI'], freq=1553),
#  FreqItemset(items=['Web Intelligence'], freq=2963),
#  FreqItemset(items=['TIIS'], freq=1424),
#  FreqItemset(items=['ESA'], freq=2305),
#  FreqItemset(items=['SMC'], freq=9894),
#  FreqItemset(items=['Bioinformatics'], freq=18669),
#  FreqItemset(items=['Bioinformatics', 'CoRR'], freq=1333),
#  FreqItemset(items=['Comp. Med. Imag. and Graph.'], freq=1679),
#  FreqItemset(items=['KES'], freq=2384),
#  FreqItemset(items=['ICYCS'], freq=1487),
#  FreqItemset(items=['Interactions'], freq=1527),
#  FreqItemset(items=['Journal of Biomedical Informatics'], freq=2612),
#  FreqItemset(items=['J. Electronic Testing'], freq=1726),
#  FreqItemset(items=['SIGMETRICS Performance Evaluation Review'], freq=1648),
#  FreqItemset(items=['ICDM'], freq=3431),
#  FreqItemset(items=['Acta Inf.'], freq=1699),
#  FreqItemset(items=['Int. J. Hum. Comput. Interaction'], freq=1537),
#  FreqItemset(items=['BIOCOMP'], freq=1813),
#  FreqItemset(items=['The Smart Internet'], freq=2764),
#  FreqItemset(items=['GECCO (Companion)'], freq=1501),
#  FreqItemset(items=['ICEC'], freq=2517),
#  FreqItemset(items=['Simulation'], freq=1772),
#  FreqItemset(items=['FPL'], freq=3640),
#  FreqItemset(items=['IEEE Data Eng. Bull.'], freq=1561),
#  FreqItemset(items=['IV'], freq=2637),
#  FreqItemset(items=['HICSS'], freq=11225),
#  FreqItemset(items=['MFCS'], freq=2321),
#  FreqItemset(items=['MFCS', 'Theor. Comput. Sci.'], freq=1475),
#  FreqItemset(items=['COMPSAC'], freq=3013),
#  FreqItemset(items=['FSTTCS'], freq=1586),
#  FreqItemset(items=['BIBE'], freq=3147),
#  FreqItemset(items=['FG'], freq=1459),
#  FreqItemset(items=['ISDA'], freq=2896),
#  FreqItemset(items=['Wireless Networks'], freq=2408),
#  FreqItemset(items=['ICIAP'], freq=1824),
#  FreqItemset(items=['ICSLP'], freq=4022),
#  FreqItemset(items=['ICSLP', 'EUROSPEECH'], freq=1660),
#  FreqItemset(items=['ICSLP', 'INTERSPEECH'], freq=1366),
#  FreqItemset(items=['Knowl. Inf. Syst.'], freq=1780),
#  FreqItemset(items=['CDC-ECE'], freq=2822),
#  FreqItemset(items=['CDC-ECE', 'CDC'], freq=1669),
#  FreqItemset(items=['Operations Research'], freq=1610),
#  FreqItemset(items=['ITNG'], freq=2925),
#  FreqItemset(items=['J. Log. Comput.'], freq=1233),
#  FreqItemset(items=['CBMS'], freq=4325),
#  FreqItemset(items=['Sci. Comput. Program.'], freq=1924),
#  FreqItemset(items=['ASP-DAC'], freq=4604),
#  FreqItemset(items=['ASP-DAC', 'DAC'], freq=1354),
#  FreqItemset(items=['ASP-DAC', 'DATE'], freq=1278),
#  FreqItemset(items=['Systems & Control Letters'], freq=1663),
#  FreqItemset(items=['DEXA'], freq=3043),
#  FreqItemset(items=['PRICAI'], freq=1704),
#  FreqItemset(items=['IPMI'], freq=1273),
#  FreqItemset(items=['ICEIS (2)'], freq=1977),
#  FreqItemset(items=['Med. Biol. Engineering and Computing'], freq=3691),
#  FreqItemset(items=['ICCE'], freq=1741),
#  FreqItemset(items=['SAINT'], freq=1565),
#  FreqItemset(items=['I. J. Medical Informatics'], freq=3491),
#  FreqItemset(items=['Int. J. Neural Syst.'], freq=1868),
#  FreqItemset(items=['ISQED'], freq=3186),
#  FreqItemset(items=['ISCA'], freq=2669),
#  FreqItemset(items=['Procedia CS'], freq=3547),
#  FreqItemset(items=['IEEE Transactions on Information Theory'], freq=7516),
#  FreqItemset(items=['IEEE Transactions on Information Theory', 'GLOBECOM'], freq=1310),
#  FreqItemset(items=['IEEE Transactions on Information Theory', 'ICC'], freq=1325),
#  FreqItemset(items=['IEEE Transactions on Information Theory', 'IEEE Transactions on Signal Processing'], freq=1284),
#  FreqItemset(items=['IEEE Transactions on Information Theory', 'CoRR'], freq=2998),
#  FreqItemset(items=['ICIP (2)'], freq=4384),
#  FreqItemset(items=['ICIP (2)', 'ICIP (3)'], freq=1336),
#  FreqItemset(items=['ICIP (2)', 'IEEE Transactions on Image Processing'], freq=1306),
#  FreqItemset(items=['ICIP (2)', 'ICIP'], freq=1828),
#  FreqItemset(items=['Software Engineering Research and Practice'], freq=1932),
#  FreqItemset(items=['Int. J. Communication Systems'], freq=1834),
#  FreqItemset(items=['ICCAD'], freq=4158),
#  FreqItemset(items=['ICCAD', 'DAC'], freq=1961),
#  FreqItemset(items=['ICCAD', 'IEEE Trans. on CAD of Integrated Circuits and Systems'], freq=1894),
#  FreqItemset(items=['ICCAD', 'IEEE Trans. on CAD of Integrated Circuits and Systems', 'DAC'], freq=1300),
#  FreqItemset(items=['ICCAD', 'DATE'], freq=1342),
#  FreqItemset(items=['KDD'], freq=3093),
#  FreqItemset(items=['IJTM'], freq=2004),
#  FreqItemset(items=['ICEIS (4)'], freq=1314),
#  FreqItemset(items=['IEEE Trans. Circuits Syst. Video Techn.'], freq=4675),
#  FreqItemset(items=['IEEE Trans. Circuits Syst. Video Techn.', 'ICIP'], freq=1742),
#  FreqItemset(items=['IEEE Trans. Circuits Syst. Video Techn.', 'ICME'], freq=1343),
#  FreqItemset(items=['Information Systems Frontiers'], freq=1256),
#  FreqItemset(items=['International Journal of Parallel Programming'], freq=1892),
#  FreqItemset(items=['ITC'], freq=5621),
#  FreqItemset(items=['HMD - Praxis Wirtschaftsinform.'], freq=1713),
#  FreqItemset(items=['WiMob'], freq=1753),
#  FreqItemset(items=['Annals OR'], freq=3294),
#  FreqItemset(items=['Annals OR', 'European Journal of Operational Research'], freq=1281),
#  FreqItemset(items=['Oper. Res. Lett.'], freq=2078),
#  FreqItemset(items=['Theory Comput. Syst.'], freq=1345),
#  FreqItemset(items=['UKSIM'], freq=1289),
#  FreqItemset(items=['PIMRC'], freq=6591),
#  FreqItemset(items=['PIMRC', 'GLOBECOM'], freq=2201),
#  FreqItemset(items=['PIMRC', 'GLOBECOM', 'ICC'], freq=1496),
#  FreqItemset(items=['PIMRC', 'VTC Fall'], freq=1869),
#  FreqItemset(items=['PIMRC', 'ICC'], freq=2285),
#  FreqItemset(items=['PIMRC', 'WCNC'], freq=1917),
#  FreqItemset(items=['PIMRC', 'VTC Spring'], freq=2142),
#  FreqItemset(items=['Int. CMG Conference'], freq=2138),
#  FreqItemset(items=['EDBT'], freq=1803),
#  FreqItemset(items=['IEEE Transactions on Neural Networks'], freq=3830),
#  FreqItemset(items=['IMECS'], freq=1377),
#  FreqItemset(items=['Scientometrics'], freq=2201),
#  FreqItemset(items=['Human Factors'], freq=1955),
#  FreqItemset(items=['RIAO'], freq=1300),
#  FreqItemset(items=['IJCAI'], freq=6814),
#  FreqItemset(items=['IJCAI', 'CoRR'], freq=1877),
#  FreqItemset(items=['ICIP (3)'], freq=4828),
#  FreqItemset(items=['ICIP (3)', 'IEEE Transactions on Image Processing'], freq=1341),
#  FreqItemset(items=['ICIP (3)', 'ICIP'], freq=1911),
#  FreqItemset(items=['ICSM'], freq=2019),
#  FreqItemset(items=['Inf. Comput.'], freq=2483),
#  FreqItemset(items=['Inf. Comput.', 'Theor. Comput. Sci.'], freq=1556),
#  FreqItemset(items=['Inf. Comput.', 'CoRR'], freq=1310),
#  FreqItemset(items=['IEEE Transactions on Information Forensics and Security'], freq=1388),
#  FreqItemset(items=['DG.O'], freq=1328),
#  FreqItemset(items=['Neurocomputing'], freq=7888),
#  FreqItemset(items=['Perform. Eval.'], freq=2217),
#  FreqItemset(items=['IUI'], freq=2116),
#  FreqItemset(items=['Electronic Colloquium on Computational Complexity (ECCC)'], freq=1357),
#  FreqItemset(items=['FUZZ-IEEE'], freq=4267),
#  FreqItemset(items=['SIAM J. Discrete Math.'], freq=2293),
#  FreqItemset(items=['Nucleic Acids Research'], freq=17378),
#  FreqItemset(items=['Nucleic Acids Research', 'Bioinformatics'], freq=3556),
#  FreqItemset(items=['JCIS'], freq=1484),
#  FreqItemset(items=['Journal of Circuits'], freq=2155),
#  FreqItemset(items=['Comput. Graph. Forum'], freq=3917),
#  FreqItemset(items=['ACM Comput. Surv.'], freq=1854),
#  FreqItemset(items=['FSKD (1)'], freq=1421),
#  FreqItemset(items=['IEEE Transactions on Signal Processing'], freq=9330),
#  FreqItemset(items=['IEEE Transactions on Signal Processing', 'GLOBECOM'], freq=1583),
#  FreqItemset(items=['IEEE Transactions on Signal Processing', 'ICC'], freq=1602),
#  FreqItemset(items=['IEEE Transactions on Signal Processing', 'ICASSP'], freq=2459),
#  FreqItemset(items=['IEEE Transactions on Signal Processing', 'CoRR'], freq=1936),
#  FreqItemset(items=['VCIP'], freq=1910),
#  FreqItemset(items=['SpringSim'], freq=1258),
#  FreqItemset(items=['PDPTA'], freq=5788),
#  FreqItemset(items=['ECIS'], freq=4466),
#  FreqItemset(items=['ECIR'], freq=1449),
#  FreqItemset(items=['FOCS'], freq=2365),
#  FreqItemset(items=['FOCS', 'CoRR'], freq=1263),
#  FreqItemset(items=['MMM'], freq=1368),
#  FreqItemset(items=['IGARSS'], freq=11017),
#  FreqItemset(items=['Math. Comput.'], freq=2398),
#  FreqItemset(items=['SIAM J. Scientific Computing'], freq=2253),
#  FreqItemset(items=['CASCON'], freq=1305),
#  FreqItemset(items=['EGC'], freq=2037),
#  FreqItemset(items=['IEEE Trans. on Circuits and Systems'], freq=4988),
#  FreqItemset(items=['IEEE Trans. on Circuits and Systems', 'ISCAS'], freq=1924),
#  FreqItemset(items=['Int. J. Applied Earth Observation and Geoinformation'], freq=1496),
#  FreqItemset(items=['Web Intelligence/IAT Workshops'], freq=1532),
#  FreqItemset(items=['IEEE Transactions on Audio'], freq=2496),
#  FreqItemset(items=['JORS'], freq=1457),
#  FreqItemset(items=['Geoinformatics'], freq=1338),
#  FreqItemset(items=['IEEE Trans. Med. Imaging'], freq=6154),
#  FreqItemset(items=['IEEE Trans. Med. Imaging', 'ISBI'], freq=1750),
#  FreqItemset(items=['VLSI Signal Processing'], freq=2124),
#  FreqItemset(items=['Journal of Computational Chemistry'], freq=7111),
#  FreqItemset(items=['I. J. Robotic Res.'], freq=2634),
#  FreqItemset(items=['I. J. Robotic Res.', 'ICRA'], freq=1735),
#  FreqItemset(items=['Des. Codes Cryptography'], freq=1559),
#  FreqItemset(items=['IEEE Transactions on Multimedia'], freq=2744),
#  FreqItemset(items=['ICIC (2)'], freq=2316),
#  FreqItemset(items=['DCC'], freq=1402),
#  FreqItemset(items=['J. Field Robotics'], freq=2174),
#  FreqItemset(items=['Winter Simulation Conference'], freq=8462),
#  FreqItemset(items=['IPPS'], freq=1582),
#  FreqItemset(items=['J. ACM'], freq=2885),
#  FreqItemset(items=['ICNP'], freq=1430),
#  FreqItemset(items=['IROS'], freq=13344),
#  FreqItemset(items=['IROS', 'ICRA'], freq=5662),
#  FreqItemset(items=['IICAI'], freq=1703),
#  FreqItemset(items=['IEEE Intelligent Systems'], freq=2449),
#  FreqItemset(items=['BIBM'], freq=1735),
#  FreqItemset(items=['Computers in Human Behavior'], freq=3487),
#  FreqItemset(items=['SIAM J. Math. Analysis'], freq=1412),
#  FreqItemset(items=['IEEE Internet Computing'], freq=2270),
#  FreqItemset(items=['Informatik Spektrum'], freq=1654),
#  FreqItemset(items=['ICML'], freq=3035),
#  FreqItemset(items=['ICML', 'NIPS'], freq=1256),
#  FreqItemset(items=['ICML', 'CoRR'], freq=1465),
#  FreqItemset(items=['ISCAS (3)'], freq=2553),
#  FreqItemset(items=['Annales des Télécommunications'], freq=2357),
#  FreqItemset(items=['Computational Biology and Chemistry'], freq=1466),
#  FreqItemset(items=['AAMAS'], freq=3181),
#  FreqItemset(items=['ACM Trans. Graph.'], freq=2661),
#  FreqItemset(items=['Informatica (Slovenia)'], freq=1565),
#  FreqItemset(items=['Journal of Computational Neuroscience'], freq=1506),
#  FreqItemset(items=['FLAIRS Conference'], freq=2811),
#  FreqItemset(items=['IEEE T. Geoscience and Remote Sensing'], freq=8785),
#  FreqItemset(items=['IEEE T. Geoscience and Remote Sensing', 'IGARSS'], freq=2700),
#  FreqItemset(items=['Journal of Machine Learning Research - Proceedings Track'], freq=1603),
#  FreqItemset(items=['J. Economic Theory'], freq=1540),
#  FreqItemset(items=['IIH-MSP'], freq=2921),
#  FreqItemset(items=['J. Visual Communication and Image Representation'], freq=1436),
#  FreqItemset(items=['ICWS'], freq=2602),
#  FreqItemset(items=['IWCMC'], freq=3521),
#  FreqItemset(items=['SoCC'], freq=1788),
#  FreqItemset(items=[' Part B'], freq=3763),
#  FreqItemset(items=[' Part B', ' Man'], freq=3763),
#  FreqItemset(items=[' Part B', 'IEEE Transactions on Systems'], freq=3763),
#  FreqItemset(items=[' Part B', 'IEEE Transactions on Systems', ' Man'], freq=3763),
#  FreqItemset(items=[' Part B', 'IEEE Transactions on Systems', ' and Cybernetics'], freq=3763),
#  FreqItemset(items=[' Part B', 'IEEE Transactions on Systems', ' and Cybernetics', ' Man'], freq=3763),
#  FreqItemset(items=[' Part B', ' and Cybernetics'], freq=3763),
#  FreqItemset(items=[' Part B', ' and Cybernetics', ' Man'], freq=3763),
#  FreqItemset(items=['FSKD (2)'], freq=1550),
#  FreqItemset(items=['Neural Computation'], freq=2948),
#  FreqItemset(items=['INFORMS Journal on Computing'], freq=1569),
#  FreqItemset(items=['Soft Comput.'], freq=2691),
#  FreqItemset(items=['Sig. Proc.: Image Comm.'], freq=1832),
#  FreqItemset(items=['Advances in Computer Entertainment Technology'], freq=1676),
#  FreqItemset(items=['ICSE'], freq=4146),
#  FreqItemset(items=['IEEE Transactions on Intelligent Transportation Systems'], freq=1888),
#  FreqItemset(items=['Fundam. Inform.'], freq=3060),
#  FreqItemset(items=['COCOON'], freq=1627),
#  FreqItemset(items=['AVI'], freq=1249),
#  FreqItemset(items=['Neural Networks'], freq=4347),
#  FreqItemset(items=['SSDBM'], freq=1747),
#  FreqItemset(items=['J. Comput. Syst. Sci.'], freq=2836),
#  FreqItemset(items=['J. Comput. Syst. Sci.', 'Theor. Comput. Sci.'], freq=1299),
#  FreqItemset(items=['International Conference on Computational Science (3)'], freq=1711),
#  FreqItemset(items=['ICDAR'], freq=3267),
#  FreqItemset(items=['Computers in Industry'], freq=1519),
#  FreqItemset(items=['Automatica'], freq=6756),
#  FreqItemset(items=['Automatica', 'CDC'], freq=1902),
#  FreqItemset(items=['IEEE Trans. Automat. Contr.'], freq=3374),
#  FreqItemset(items=['IEEE Trans. Automat. Contr.', 'Automatica'], freq=1622),
#  FreqItemset(items=['IEEE Trans. Automat. Contr.', 'CDC'], freq=1734),
#  FreqItemset(items=['CARS'], freq=3002),
#  FreqItemset(items=['IEEE Trans. VLSI Syst.'], freq=4752),
#  FreqItemset(items=['IEEE Trans. VLSI Syst.', 'DAC'], freq=1305),
#  FreqItemset(items=['IEEE Trans. VLSI Syst.', 'DATE'], freq=1318),
#  FreqItemset(items=['Journal of Computational Biology'], freq=1808),
#  FreqItemset(items=['VLDB'], freq=3607),
#  FreqItemset(items=['VLDB', 'SIGMOD Conference'], freq=1431),
#  FreqItemset(items=['VLDB', 'ICDE'], freq=1451),
#  FreqItemset(items=['CICC'], freq=1725),
#  FreqItemset(items=['PATMOS'], freq=1326),
#  FreqItemset(items=['SIAM Journal of Applied Mathematics'], freq=2106),
#  FreqItemset(items=['WWW'], freq=3874),
#  FreqItemset(items=['European Transactions on Telecommunications'], freq=1849),
#  FreqItemset(items=['Biosystems'], freq=1762),
#  FreqItemset(items=['Parallel Computing'], freq=4205),
#  FreqItemset(items=['Bell Labs Technical Journal'], freq=1648),
#  FreqItemset(items=['Math. Program.'], freq=1904),
#  FreqItemset(items=['ICWI'], freq=1258),
#  FreqItemset(items=['Image Vision Comput.'], freq=4449),
#  FreqItemset(items=['CAIP'], freq=1946),
#  FreqItemset(items=['IEEE Trans. Neural Netw. Learning Syst.'], freq=1696),
#  FreqItemset(items=['Information & Software Technology'], freq=3132),
#  FreqItemset(items=['J. Intell. Inf. Syst.'], freq=1296),
#  FreqItemset(items=['IFIP Congress'], freq=2011),
#  FreqItemset(items=['AAAI'], freq=5768),
#  FreqItemset(items=['AAAI', 'IJCAI'], freq=2004),
#  FreqItemset(items=['AAAI', 'CoRR'], freq=1559),
#  FreqItemset(items=['IEEE T. Fuzzy Systems'], freq=1355),
#  FreqItemset(items=['MASCOTS'], freq=2310),
#  FreqItemset(items=['Mathematical and Computer Modelling'], freq=4977),
#  FreqItemset(items=['SIGMOD Record'], freq=2031),
#  FreqItemset(items=['IPSN'], freq=1454),
#  FreqItemset(items=['MICCAI'], freq=2121),
#  FreqItemset(items=['IEEE Journal on Selected Areas in Communications'], freq=7049),
#  FreqItemset(items=['IEEE Journal on Selected Areas in Communications', 'GLOBECOM'], freq=2396),
#  FreqItemset(items=['IEEE Journal on Selected Areas in Communications', 'GLOBECOM', 'ICC'], freq=1776),
#  FreqItemset(items=['IEEE Journal on Selected Areas in Communications', 'ICC'], freq=2447),
#  FreqItemset(items=['IEEE Journal on Selected Areas in Communications', 'INFOCOM'], freq=1778),
#  FreqItemset(items=['IEEE Journal on Selected Areas in Communications', 'CoRR'], freq=1534),
#  FreqItemset(items=['Intelligent Tutoring Systems'], freq=1398),
#  FreqItemset(items=['ICNSC'], freq=1973),
#  FreqItemset(items=['PPOPP'], freq=1337),
#  FreqItemset(items=['Microelectronics Journal'], freq=6019),
#  FreqItemset(items=['ECAI'], freq=4002),
#  FreqItemset(items=['ECAI', 'IJCAI'], freq=1261),
#  FreqItemset(items=['ICMCS'], freq=1778),
#  FreqItemset(items=['Computer Methods and Programs in Biomedicine'], freq=4299),
#  FreqItemset(items=['J. UCS'], freq=3661),
#  FreqItemset(items=['DFT'], freq=1362),
#  FreqItemset(items=['ROBIO'], freq=2168),
#  FreqItemset(items=['Discrete Mathematics'], freq=8159),
#  FreqItemset(items=['Discrete Mathematics', 'CoRR'], freq=1374),
#  FreqItemset(items=['AIME'], freq=1268),
#  FreqItemset(items=['ICPR (3)'], freq=1917),
#  FreqItemset(items=['Computers & Security'], freq=1818),
#  FreqItemset(items=['Comput. J.'], freq=4560),
#  FreqItemset(items=['ER'], freq=1859),
#  FreqItemset(items=['Inf. Syst.'], freq=2233),
#  FreqItemset(items=['ISI'], freq=1427),
#  FreqItemset(items=['ICASSP'], freq=10647),
#  FreqItemset(items=['ICASSP', 'GLOBECOM'], freq=1242),
#  FreqItemset(items=['ICASSP', 'ICIP'], freq=2045),
#  FreqItemset(items=['ICASSP', 'CoRR'], freq=1868),
#  FreqItemset(items=[' Fuzziness and Knowledge-Based Systems'], freq=1304),
#  FreqItemset(items=[' Fuzziness and Knowledge-Based Systems', 'International Journal of Uncertainty'], freq=1304),
#  FreqItemset(items=['VTC Spring'], freq=7314),
#  FreqItemset(items=['VTC Spring', 'GLOBECOM'], freq=2233),
#  FreqItemset(items=['VTC Spring', 'GLOBECOM', 'ICC'], freq=1532),
#  FreqItemset(items=['VTC Spring', 'ICC'], freq=2361),
#  FreqItemset(items=['VTC Spring', 'IEICE Transactions'], freq=1268),
#  FreqItemset(items=['VTC Spring', 'WCNC'], freq=2000),
#  FreqItemset(items=['VTC Spring', 'WCNC', 'ICC'], freq=1233),
#  FreqItemset(items=['ACM Great Lakes Symposium on VLSI'], freq=2193),
#  FreqItemset(items=['IEEE Trans. Evolutionary Computation'], freq=1408),
#  FreqItemset(items=['J. Digital Imaging'], freq=2655),
#  FreqItemset(items=['J. Symb. Log.'], freq=2264),
#  FreqItemset(items=['WAIM'], freq=1433),
#  FreqItemset(items=['ICIP'], freq=12538),
#  FreqItemset(items=['ICIP', 'CoRR'], freq=1429),
#  FreqItemset(items=['CHI'], freq=5518),
#  FreqItemset(items=['CHI', 'CHI Extended Abstracts'], freq=1808),
#  FreqItemset(items=['ACM SIGSOFT Software Engineering Notes'], freq=1929),
#  FreqItemset(items=['Computational Statistics & Data Analysis'], freq=4659),
#  FreqItemset(items=['JACIII'], freq=2341),
#  FreqItemset(items=['ISVC (2)'], freq=1463),
#  FreqItemset(items=['AICCSA'], freq=2444),
#  FreqItemset(items=['GI Jahrestagung (1)'], freq=2129),
#  FreqItemset(items=['J. Global Optimization'], freq=1312),
#  FreqItemset(items=['PAKDD'], freq=1995),
#  FreqItemset(items=['ICCHP'], freq=1503),
#  FreqItemset(items=['SECON'], freq=1538),
#  FreqItemset(items=['NOMS'], freq=2535),
#  FreqItemset(items=[' and Cybernetics'], freq=8731),
#  FreqItemset(items=[' and Cybernetics', ' Man'], freq=8731),
#  FreqItemset(items=['ICWET'], freq=1340),
#  FreqItemset(items=['MICAI'], freq=1564),
#  FreqItemset(items=['SIGMETRICS'], freq=2061),
#  FreqItemset(items=['TACAS'], freq=1281),
#  FreqItemset(items=['IEEE Communications Letters'], freq=6519),
#  FreqItemset(items=['IEEE Communications Letters', 'GLOBECOM'], freq=2395),
#  FreqItemset(items=['IEEE Communications Letters', 'GLOBECOM', 'ICC'], freq=1686),
#  FreqItemset(items=['IEEE Communications Letters', 'ICC'], freq=2429),
#  FreqItemset(items=['IEEE Communications Letters', 'IEEE Transactions on Communications'], freq=1634),
#  FreqItemset(items=['IEEE Communications Letters', 'WCNC'], freq=1414),
#  FreqItemset(items=['IEEE Communications Letters', 'VTC Spring'], freq=1383),
#  FreqItemset(items=['IEEE Communications Letters', 'CoRR'], freq=1467),
#  FreqItemset(items=['ICWN'], freq=1376),
#  FreqItemset(items=['ICCSA (2)'], freq=2212),
#  FreqItemset(items=['J. Bioinformatics and Computational Biology'], freq=1617),
#  FreqItemset(items=['DEXA Workshops'], freq=2932),
#  FreqItemset(items=['INFOCOM'], freq=7771),
#  FreqItemset(items=['INFOCOM', 'GLOBECOM'], freq=2185),
#  FreqItemset(items=['INFOCOM', 'GLOBECOM', 'ICC'], freq=1387),
#  FreqItemset(items=['INFOCOM', 'Computer Communications'], freq=1387),
#  FreqItemset(items=['INFOCOM', 'ICC'], freq=2089),
#  FreqItemset(items=['INFOCOM', 'CoRR'], freq=1967),
#  FreqItemset(items=['J. Algorithms'], freq=1548),
#  FreqItemset(items=['Pattern Recognition'], freq=9255),
#  FreqItemset(items=['Pattern Recognition', 'ICIP'], freq=1509),
#  FreqItemset(items=['TREC'], freq=2278),
#  FreqItemset(items=[' and Computers'], freq=2155),
#  FreqItemset(items=[' and Computers', ' Systems'], freq=2155),
#  FreqItemset(items=[' and Computers', ' Systems', 'Journal of Circuits'], freq=2155),
#  FreqItemset(items=[' and Computers', 'Journal of Circuits'], freq=2155),
#  FreqItemset(items=['DICTA'], freq=1382),
#  FreqItemset(items=['NeuroImage'], freq=14700),
#  FreqItemset(items=['KI'], freq=2829),
#  FreqItemset(items=['ICIC (3)'], freq=1445),
#  FreqItemset(items=['ISNN (3)'], freq=1481),
#  FreqItemset(items=['CASE'], freq=2364),
#  FreqItemset(items=['Australian Conference on Artificial Intelligence'], freq=1419),
#  FreqItemset(items=['AI Magazine'], freq=2471),
#  FreqItemset(items=['ERCIM News'], freq=1668),
#  FreqItemset(items=['Games and Economic Behavior'], freq=1514),
#  FreqItemset(items=['MICCAI (1)'], freq=3053),
#  FreqItemset(items=['ITiCSE'], freq=2598),
#  FreqItemset(items=['Computers and Their Applications'], freq=1708),
#  FreqItemset(items=['CSCWD'], freq=2680),
#  FreqItemset(items=['SPAA'], freq=1567),
#  FreqItemset(items=['RECOMB'], freq=1491),
#  FreqItemset(items=['APSEC'], freq=2393),
#  FreqItemset(items=['eScience'], freq=1721),
#  FreqItemset(items=['ICIS'], freq=3857),
#  FreqItemset(items=['ICIS', 'AMCIS'], freq=1276),
#  FreqItemset(items=['Concurrency - Practice and Experience'], freq=1557),
#  FreqItemset(items=['IEA/AIE'], freq=3342),
#  FreqItemset(items=['DASFAA'], freq=1761),
#  FreqItemset(items=['Artif. Intell.'], freq=2713),
#  FreqItemset(items=['Artif. Intell.', 'IJCAI'], freq=1360),
#  FreqItemset(items=['Computer Standards & Interfaces'], freq=1532),
#  FreqItemset(items=['ECDL'], freq=1806),
#  FreqItemset(items=['IEEE Trans. Consumer Electronics'], freq=3599),
#  FreqItemset(items=['POPL'], freq=1641),
#  FreqItemset(items=['IGARSS (2)'], freq=1843),
#  FreqItemset(items=['HiPC'], freq=1573),
#  FreqItemset(items=['Int. J. Comput. Math.'], freq=2854),
#  FreqItemset(items=[' Ser. B'], freq=1682),
#  FreqItemset(items=[' Ser. B', 'J. Comb. Theory'], freq=1682),
#  FreqItemset(items=['Bildverarbeitung für die Medizin'], freq=2990),
#  FreqItemset(items=['Wireless Communications and Mobile Computing'], freq=2493),
#  FreqItemset(items=['ISCAS (4)'], freq=3112),
#  FreqItemset(items=['Journal of Computer-Aided Molecular Design'], freq=2628),
#  FreqItemset(items=['CoRR'], freq=51437),
#  FreqItemset(items=['EURASIP J. Wireless Comm. and Networking'], freq=4150),
#  FreqItemset(items=['EURASIP J. Wireless Comm. and Networking', 'GLOBECOM'], freq=1525),
#  FreqItemset(items=['EURASIP J. Wireless Comm. and Networking', 'ICC'], freq=1506),
#  FreqItemset(items=['Ad Hoc Networks'], freq=1632),
#  FreqItemset(items=['Computer Vision and Image Understanding'], freq=2954),
#  FreqItemset(items=['CIVR'], freq=1253),
#  FreqItemset(items=['DSN'], freq=1931),
#  FreqItemset(items=['CVPR'], freq=4675),
#  FreqItemset(items=['CVPR', 'IEEE Trans. Pattern Anal. Mach. Intell.'], freq=1613),
#  FreqItemset(items=['CVPR', 'ICIP'], freq=1272),
#  FreqItemset(items=['J. Solid-State Circuits'], freq=3526),
#  FreqItemset(items=['J. Solid-State Circuits', 'ISSCC'], freq=1930),
#  FreqItemset(items=['ICMLC'], freq=3073),
#  FreqItemset(items=['APCCAS'], freq=1712),
#  FreqItemset(items=['J. Computational Applied Mathematics'], freq=3282),
#  FreqItemset(items=['MSN'], freq=1312),
#  FreqItemset(items=['IEEE Congress on Evolutionary Computation'], freq=5522),
#  FreqItemset(items=['COLING'], freq=3821),
#  FreqItemset(items=['Int. J. Found. Comput. Sci.'], freq=1833),
#  FreqItemset(items=['OOPSLA'], freq=1753),
#  FreqItemset(items=['Graphs and Combinatorics'], freq=1572),
#  FreqItemset(items=['ICTAI'], freq=2836),
#  FreqItemset(items=['Auton. Robots'], freq=1890),
#  FreqItemset(items=['ICIP (1)'], freq=4351),
#  FreqItemset(items=['ICIP (1)', 'ICIP (3)'], freq=1315),
#  FreqItemset(items=['ICIP (1)', 'IEEE Transactions on Image Processing'], freq=1318),
#  FreqItemset(items=['ICIP (1)', 'ICIP'], freq=1768),
#  FreqItemset(items=['SIGPLAN Notices'], freq=1679),
#  FreqItemset(items=['GRID'], freq=1283),
#  FreqItemset(items=['VR'], freq=2003),
#  FreqItemset(items=['UAI'], freq=1796),
#  FreqItemset(items=['UAI', 'CoRR'], freq=1448),
#  FreqItemset(items=['Computer Networks and ISDN Systems'], freq=1300),
#  FreqItemset(items=['DAC'], freq=9297),
#  FreqItemset(items=['Appl. Math. Lett.'], freq=4754),
#  FreqItemset(items=['Appl. Math. Lett.', 'Applied Mathematics and Computation'], freq=1243),
#  FreqItemset(items=['Applied Artificial Intelligence'], freq=1905),
#  FreqItemset(items=['Digital Signal Processing'], freq=1726),
#  FreqItemset(items=['ASE'], freq=2109),
#  FreqItemset(items=['LCN'], freq=4242),
#  FreqItemset(items=['ICEIS (1)'], freq=1951),
#  FreqItemset(items=['SIAM J. Control and Optimization'], freq=1850),
#  FreqItemset(items=['IEEE T. Automation Science and Engineering'], freq=1328),
#  FreqItemset(items=['BMVC'], freq=2013),
#  FreqItemset(items=['NTMS'], freq=1258),
#  FreqItemset(items=['ACM Multimedia'], freq=5773),
#  FreqItemset(items=['ACM Multimedia', 'ICME'], freq=1492),
#  FreqItemset(items=['Fuzzy Sets and Systems'], freq=3399),
#  FreqItemset(items=['ICMLA'], freq=1768),
#  FreqItemset(items=['Computer-Aided Design'], freq=3633),
#  FreqItemset(items=['IEEE Transactions on Reliability'], freq=1357),
#  FreqItemset(items=[' Systems'], freq=2155),
#  FreqItemset(items=[' Systems', 'Journal of Circuits'], freq=2155),
#  FreqItemset(items=['EURASIP J. Adv. Sig. Proc.'], freq=6774),
#  FreqItemset(items=['EURASIP J. Adv. Sig. Proc.', 'IEEE Transactions on Signal Processing'], freq=1328),
#  FreqItemset(items=['EURASIP J. Adv. Sig. Proc.', 'ICASSP'], freq=1504),
#  FreqItemset(items=['IEEE Trans. Computers'], freq=7849),
#  FreqItemset(items=['Appl. Intell.'], freq=1810),
#  FreqItemset(items=['EUROSPEECH'], freq=4452),
#  FreqItemset(items=['EUROSPEECH', 'INTERSPEECH'], freq=1530),
#  FreqItemset(items=['Appl. Soft Comput.'], freq=3903),
#  FreqItemset(items=['PARA'], freq=1387),
#  FreqItemset(items=['Mach. Vis. Appl.'], freq=2213),
#  FreqItemset(items=['ASAP'], freq=1421),
#  FreqItemset(items=['International Journal of Uncertainty'], freq=1304),
#  FreqItemset(items=['IEEE Visualization'], freq=2171),
#  FreqItemset(items=['AMCIS'], freq=7079),
#  FreqItemset(items=['AMCIS', 'HICSS'], freq=1766),
#  FreqItemset(items=['STACS'], freq=2036),
#  FreqItemset(items=['STACS', 'CoRR'], freq=1241),
#  FreqItemset(items=['ACM Trans. Math. Softw.'], freq=1532),
#  FreqItemset(items=['ICPR (4)'], freq=1400),
#  FreqItemset(items=['Inf. Sci.'], freq=8240),
#  FreqItemset(items=['CSCW'], freq=2234),
#  FreqItemset(items=['JASIS'], freq=1366),
#  FreqItemset(items=['Commun. ACM'], freq=10669),
#  FreqItemset(items=['ISER'], freq=1233),
#  FreqItemset(items=['FSKD'], freq=4301),
#  FreqItemset(items=['SocialCom/PASSAT'], freq=1457),
#  FreqItemset(items=['IEEE Communications Magazine'], freq=2315),
#  FreqItemset(items=['IGARSS (3)'], freq=1976),
#  FreqItemset(items=['CIKM'], freq=4982),
#  FreqItemset(items=['CIKM', 'CoRR'], freq=1240),
#  FreqItemset(items=['INTERACT'], freq=1493),
#  FreqItemset(items=[' Speech & Language Processing'], freq=2496),
#  FreqItemset(items=[' Speech & Language Processing', 'IEEE Transactions on Audio'], freq=2496),
#  FreqItemset(items=['SEC'], freq=1338),
#  FreqItemset(items=['SIGUCCS'], freq=1862),
#  FreqItemset(items=['NCM'], freq=1428),
#  FreqItemset(items=['iiWAS'], freq=1920),
#  FreqItemset(items=['ISMAR'], freq=1272),
#  FreqItemset(items=['IEEE Trans. Pattern Anal. Mach. Intell.'], freq=6076),
#  FreqItemset(items=['IEEE Trans. Pattern Anal. Mach. Intell.', 'ICPR'], freq=1286),
#  FreqItemset(items=['IEEE Trans. Pattern Anal. Mach. Intell.', 'Pattern Recognition'], freq=1534),
#  FreqItemset(items=['ISCC'], freq=4563),
#  FreqItemset(items=['International Journal of Computer Vision'], freq=2396),
#  FreqItemset(items=['Advances in Engineering Software'], freq=2122),
#  FreqItemset(items=['Expert Syst. Appl.'], freq=12968),
#  FreqItemset(items=['ICPR (1)'], freq=1595),
#  FreqItemset(items=['TSD'], freq=1466),
#  FreqItemset(items=['Int. J. Hum.-Comput. Stud.'], freq=2447),
#  FreqItemset(items=[' Part C'], freq=2072),
#  FreqItemset(items=[' Part C', ' Man'], freq=2072),
#  FreqItemset(items=[' Part C', 'IEEE Transactions on Systems'], freq=2072),
#  FreqItemset(items=[' Part C', 'IEEE Transactions on Systems', ' Man'], freq=2072),
#  FreqItemset(items=[' Part C', 'IEEE Transactions on Systems', ' and Cybernetics'], freq=2072),
#  FreqItemset(items=[' Part C', 'IEEE Transactions on Systems', ' and Cybernetics', ' Man'], freq=2072),
#  FreqItemset(items=[' Part C', ' and Cybernetics'], freq=2072),
#  FreqItemset(items=[' Part C', ' and Cybernetics', ' Man'], freq=2072),
#  FreqItemset(items=['TBC'], freq=1540),
#  FreqItemset(items=['D-Lib Magazine'], freq=1344),
#  FreqItemset(items=['ICALP'], freq=2264),
#  FreqItemset(items=['ICALP', 'Theor. Comput. Sci.'], freq=1570),
#  FreqItemset(items=[' Man'], freq=8731),
#  FreqItemset(items=['SCIENCE CHINA Information Sciences'], freq=2134),
#  FreqItemset(items=['JCM'], freq=1376),
#  FreqItemset(items=['Inf. Process. Lett.'], freq=7473),
#  FreqItemset(items=['Inf. Process. Lett.', 'Theor. Comput. Sci.'], freq=2371),
#  FreqItemset(items=['Inf. Process. Lett.', 'Theor. Comput. Sci.', 'CoRR'], freq=1270),
#  FreqItemset(items=['Inf. Process. Lett.', 'CoRR'], freq=2295),
#  FreqItemset(items=['ICMI'], freq=1564),
#  FreqItemset(items=['ICDCS Workshops'], freq=2804),
#  FreqItemset(items=['PerCom Workshops'], freq=2341),
#  FreqItemset(items=['GI Jahrestagung (2)'], freq=2195),
#  FreqItemset(items=['Cognitive Science'], freq=1408),
#  FreqItemset(items=['COMPCON'], freq=1652),
#  FreqItemset(items=['MICCAI (2)'], freq=2915),
#  FreqItemset(items=['ECBS'], freq=1504),
#  FreqItemset(items=['Edutainment'], freq=1433),
#  FreqItemset(items=['ICDM Workshops'], freq=2540),
#  FreqItemset(items=['IEEE Computer'], freq=6533),
#  FreqItemset(items=['CCECE'], freq=2656),
#  FreqItemset(items=['HPDC'], freq=2365),
#  FreqItemset(items=['ICC'], freq=14904),
#  FreqItemset(items=['ICC', 'IEICE Transactions'], freq=1910),
#  FreqItemset(items=['ICC', 'CoRR'], freq=2800),
#  FreqItemset(items=['Interacting with Computers'], freq=1709),
#  FreqItemset(items=['IEEE Signal Process. Lett.'], freq=1548),
#  FreqItemset(items=['Int. J. Systems Science'], freq=3234),
#  FreqItemset(items=['J. Electronic Imaging'], freq=2683),
#  FreqItemset(items=['ISCAS (2)'], freq=2474),
#  FreqItemset(items=['Parallel Processing Letters'], freq=1517),
#  FreqItemset(items=[' Part A'], freq=3519),
#  FreqItemset(items=[' Part A', ' Man'], freq=3519),
#  FreqItemset(items=[' Part A', 'IEEE Transactions on Systems'], freq=3519),
#  FreqItemset(items=[' Part A', 'IEEE Transactions on Systems', ' Man'], freq=3519),
#  FreqItemset(items=[' Part A', 'IEEE Transactions on Systems', ' and Cybernetics'], freq=3519),
#  FreqItemset(items=[' Part A', 'IEEE Transactions on Systems', ' and Cybernetics', ' Man'], freq=3519),
#  FreqItemset(items=[' Part A', ' and Cybernetics'], freq=3519),
#  FreqItemset(items=[' Part A', ' and Cybernetics', ' Man'], freq=3519),
#  FreqItemset(items=['Electr. J. Comb.'], freq=2289),
#  FreqItemset(items=['PACIS'], freq=3054),
#  FreqItemset(items=['MVA'], freq=2599),
#  FreqItemset(items=['J. Sci. Comput.'], freq=1483),
#  FreqItemset(items=['Asian Test Symposium'], freq=1746),
#  FreqItemset(items=['IPCV'], freq=1568),
#  FreqItemset(items=['J. Inf. Sci. Eng.'], freq=2830),
#  FreqItemset(items=['SenSys'], freq=1788),
#  FreqItemset(items=['ICEIS (3)'], freq=1624),
#  FreqItemset(items=['ISCIS'], freq=1669),
#  FreqItemset(items=['Decision Support Systems'], freq=2938),
#  FreqItemset(items=['IWANN (2)'], freq=1447),
#  FreqItemset(items=['Neural Computing and Applications'], freq=2628),
#  FreqItemset(items=['KES (1)'], freq=1807),
#  FreqItemset(items=['Journal of Chemical Information and Computer Sciences'], freq=3871),
#  FreqItemset(items=['SIAM J. Comput.'], freq=3000),
#  FreqItemset(items=['SIAM J. Comput.', 'Theor. Comput. Sci.'], freq=1349),
#  FreqItemset(items=['SIAM J. Comput.', 'Inf. Process. Lett.'], freq=1249),
#  FreqItemset(items=['SIAM J. Comput.', 'CoRR'], freq=1455),
#  FreqItemset(items=['Artificial Intelligence in Medicine'], freq=2714),
#  FreqItemset(items=['ISPAN'], freq=1577),
#  FreqItemset(items=['PODC'], freq=1696),
#  FreqItemset(items=['SIGMOD Conference'], freq=4198),
#  FreqItemset(items=['SIGMOD Conference', 'ICDE'], freq=1632),
#  FreqItemset(items=['CISIS'], freq=1903),
#  FreqItemset(items=['ICCCN'], freq=3124),
#  FreqItemset(items=['IAT'], freq=1724),
#  FreqItemset(items=['Signal Processing Systems'], freq=1646),
#  FreqItemset(items=['CVPR (1)'], freq=1258),
#  FreqItemset(items=['ISVLSI'], freq=1943),
#  FreqItemset(items=['WWW (Companion Volume)'], freq=1290),
#  FreqItemset(items=['DEXA Workshop'], freq=1762),
#  FreqItemset(items=['Comp. in Bio. and Med.'], freq=3600),
#  FreqItemset(items=['Computational Intelligence'], freq=1558),
#  FreqItemset(items=['IEEE/ACM Trans. Comput. Biology Bioinform.'], freq=1847),
#  FreqItemset(items=['IEEE Trans. Parallel Distrib. Syst.'], freq=4424),
#  FreqItemset(items=['IEEE Trans. Parallel Distrib. Syst.', 'IPDPS'], freq=1255),
#  FreqItemset(items=['CCGRID'], freq=3348),
#  FreqItemset(items=['Electronic Notes in Discrete Mathematics'], freq=2879),
#  FreqItemset(items=['IEEE Trans. Mob. Comput.'], freq=2164),
#  FreqItemset(items=['Mobile HCI'], freq=1914),
#  FreqItemset(items=['Mathematics and Computers in Simulation'], freq=3461),
#  FreqItemset(items=['ICPP'], freq=3653),
#  FreqItemset(items=['ICPR (2)'], freq=1815),
#  FreqItemset(items=['CISS'], freq=1735),
#  FreqItemset(items=['MONET'], freq=2119),
#  FreqItemset(items=['APSCC'], freq=1858),
#  FreqItemset(items=['J. Comb. Theory'], freq=4298),
#  FreqItemset(items=['J. Comb. Theory', 'Discrete Mathematics'], freq=2123),
#  FreqItemset(items=['IEEE Software'], freq=3179),
#  FreqItemset(items=[' Ser. A'], freq=3031),
#  FreqItemset(items=[' Ser. A', 'J. Comb. Theory'], freq=3031),
#  FreqItemset(items=[' Ser. A', 'J. Comb. Theory', 'Discrete Mathematics'], freq=1401),
#  FreqItemset(items=[' Ser. A', 'Discrete Mathematics'], freq=1401),
#  FreqItemset(items=['RTCSA'], freq=1391),
#  FreqItemset(items=['ICADL'], freq=1265),
#  FreqItemset(items=['ICARCV'], freq=4545),
#  FreqItemset(items=['Computers & Chemistry'], freq=1970),
#  FreqItemset(items=['ACM Conference on Computer Science'], freq=1778),
#  FreqItemset(items=['IBM Journal of Research and Development'], freq=4974),
#  FreqItemset(items=['FCCM'], freq=1703),
#  FreqItemset(items=['PerCom'], freq=1303),
#  FreqItemset(items=['ISBI'], freq=6928),
#  FreqItemset(items=['AFIPS National Computer Conference'], freq=2031),
#  FreqItemset(items=['J. Comp. Assisted Learning'], freq=1331),
#  FreqItemset(items=['Computers & OR'], freq=5997),
#  FreqItemset(items=['Computers & OR', 'European Journal of Operational Research'], freq=2136),
#  FreqItemset(items=['ICDCS'], freq=3972),
#  FreqItemset(items=['ISORC'], freq=1358),
#  FreqItemset(items=['HPCN Europe'], freq=2054),
#  FreqItemset(items=['LREC'], freq=5493),
#  FreqItemset(items=['IEEE Transactions on Image Processing'], freq=6476),
#  FreqItemset(items=['IEEE Transactions on Image Processing', 'ICASSP'], freq=1251),
#  FreqItemset(items=['IEEE Transactions on Image Processing', 'ICIP'], freq=2497),
#  FreqItemset(items=['VLSI Design'], freq=4144),
#  FreqItemset(items=['Journal of Visualization and Computer Animation'], freq=1502),
#  FreqItemset(items=['Robotica'], freq=2127),
#  FreqItemset(items=['CTS'], freq=1375),
#  FreqItemset(items=['DATE'], freq=7295),
#  FreqItemset(items=['DATE', 'DAC'], freq=1912),
#  FreqItemset(items=['International Journal of Software Engineering and Knowledge Engineering'], freq=1831),
#  FreqItemset(items=['ICCSA (4)'], freq=1405),
#  FreqItemset(items=['MASS'], freq=2263),
#  FreqItemset(items=['Applied Mathematics and Computation'], freq=11702),
#  FreqItemset(items=['VLDB J.'], freq=1248),
#  FreqItemset(items=['ACM Trans. Program. Lang. Syst.'], freq=1460),
#  FreqItemset(items=['CIMCA/IAWTIC'], freq=1340),
#  FreqItemset(items=['Computers & Electrical Engineering'], freq=1877),
#  FreqItemset(items=['ICALT'], freq=4342),
#  FreqItemset(items=['ICCV'], freq=3722),
#  FreqItemset(items=['ICCV', 'CVPR'], freq=1731),
#  FreqItemset(items=['ICCV', 'IEEE Trans. Pattern Anal. Mach. Intell.'], freq=1463),
#  FreqItemset(items=['HPCC'], freq=2191),
#  FreqItemset(items=['SIGGRAPH'], freq=1927),
#  FreqItemset(items=['Journal of Approximation Theory'], freq=1278),
#  FreqItemset(items=['IEEE Transactions on Systems'], freq=8731),
#  FreqItemset(items=['IEEE Transactions on Systems', ' Man'], freq=8731),
#  FreqItemset(items=['IEEE Transactions on Systems', ' and Cybernetics'], freq=8731),
#  FreqItemset(items=['IEEE Transactions on Systems', ' and Cybernetics', ' Man'], freq=8731),
#  FreqItemset(items=['IEEE Trans. Software Eng.'], freq=4659),
#  FreqItemset(items=['HCI (1)'], freq=1995),
#  FreqItemset(items=['Rel. Eng. & Sys. Safety'], freq=2419),
#  FreqItemset(items=['Information and Control'], freq=1433),
#  FreqItemset(items=['ICUIMC'], freq=1312),
#  FreqItemset(items=['Simulation Modelling Practice and Theory'], freq=2334),
#  FreqItemset(items=['JNW'], freq=2210),
#  FreqItemset(items=['ICNC'], freq=4730),
#  FreqItemset(items=['CAiSE'], freq=1611),
#  FreqItemset(items=['MIE'], freq=1441),
#  FreqItemset(items=['BMC Bioinformatics'], freq=14448),
#  FreqItemset(items=['BMC Bioinformatics', 'Bioinformatics'], freq=4700),
#  FreqItemset(items=['BMC Bioinformatics', 'Nucleic Acids Research'], freq=2727),
#  FreqItemset(items=['BMC Bioinformatics', 'Nucleic Acids Research', 'Bioinformatics'], freq=1598),
#  FreqItemset(items=['Journal of Systems and Software'], freq=5764),
#  FreqItemset(items=['KES (2)'], freq=2105),
#  FreqItemset(items=['Industrial Management and Data Systems'], freq=1480),
#  FreqItemset(items=['Symposium on Computational Geometry'], freq=1354),
#  FreqItemset(items=['J. Medical Systems'], freq=2464),
#  FreqItemset(items=['WOWMOM'], freq=2154),
#  FreqItemset(items=['Cluster Computing'], freq=1324),
#  FreqItemset(items=['PVLDB'], freq=2011),
#  FreqItemset(items=['Pattern Recognition Letters'], freq=7714),
#  FreqItemset(items=['Pattern Recognition Letters', 'ICIP'], freq=1396),
#  FreqItemset(items=['Pattern Recognition Letters', 'ICPR'], freq=1491),
#  FreqItemset(items=['Pattern Recognition Letters', 'Pattern Recognition'], freq=2107),
#  FreqItemset(items=['Journal of Intelligent and Robotic Systems'], freq=2823),
#  FreqItemset(items=['NEMS'], freq=2578),
#  FreqItemset(items=['IPCCC'], freq=1547),
#  FreqItemset(items=['Ann. Pure Appl. Logic'], freq=1418),
#  FreqItemset(items=['ETFA'], freq=2670),
#  FreqItemset(items=['IEEE Trans. Biomed. Engineering'], freq=9050),
#  FreqItemset(items=['HIS'], freq=2277),
#  FreqItemset(items=['Humanoids'], freq=1565),
#  FreqItemset(items=['International Conference on Computational Science'], freq=2364),
#  FreqItemset(items=['Computers & Mathematics with Applications'], freq=6670),
#  FreqItemset(items=['Computers & Mathematics with Applications', 'Applied Mathematics and Computation'], freq=1757),
#  FreqItemset(items=['ICONIP (2)'], freq=1511),
#  FreqItemset(items=['ICECCS'], freq=1379),
#  FreqItemset(items=['GCC'], freq=1714),
#  FreqItemset(items=['EUC'], freq=1641),
#  FreqItemset(items=['IEEE Trans. Vis. Comput. Graph.'], freq=3322),
#  FreqItemset(items=['AINA'], freq=2985),
#  FreqItemset(items=['IPDPS'], freq=8084),
#  FreqItemset(items=['IPDPS', 'CoRR'], freq=1380),
#  FreqItemset(items=['VRST'], freq=1426),
#  FreqItemset(items=['J. Symb. Comput.'], freq=2310),
#  FreqItemset(items=['IEICE Transactions'], freq=22145),
#  FreqItemset(items=['IEICE Transactions', 'CoRR'], freq=1346),
#  FreqItemset(items=['ISNN (2)'], freq=3109),
#  FreqItemset(items=['IEEE Transactions on Speech and Audio Processing'], freq=1491),
#  FreqItemset(items=['PDP'], freq=2493),
#  FreqItemset(items=['Science in China Series F: Information Sciences'], freq=1754),
#  FreqItemset(items=['ISMIS'], freq=1682),
#  FreqItemset(items=['HPCS'], freq=1528),
#  FreqItemset(items=['ISPA'], freq=2622),
#  FreqItemset(items=['SRDS'], freq=1553),
#  FreqItemset(items=['Management Science'], freq=2227),
#  FreqItemset(items=['INTERSPEECH'], freq=10255),
#  FreqItemset(items=['INTERSPEECH', 'ICASSP'], freq=2206),
#  FreqItemset(items=['The Journal of Supercomputing'], freq=2710),
#  FreqItemset(items=['Journal of Systems Architecture'], freq=1572),
#  FreqItemset(items=['ACM Conference on Computer and Communications Security'], freq=1451),
#  FreqItemset(items=['IC-AI'], freq=2847),
#  FreqItemset(items=['ICOIN'], freq=2388),
#  FreqItemset(items=['Computers & Chemical Engineering'], freq=3918),
#  FreqItemset(items=['Briefings in Bioinformatics'], freq=1563),
#  FreqItemset(items=['J. Comput. Sci. Technol.'], freq=3437),
#  FreqItemset(items=['ICDE Workshops'], freq=1775),
#  FreqItemset(items=['IPDPS Workshops'], freq=2780),
#  FreqItemset(items=['Ann. Math. Artif. Intell.'], freq=1588),
#  FreqItemset(items=['IEEE MultiMedia'], freq=1855),
#  FreqItemset(items=['J. Cognitive Neuroscience'], freq=4271),
#  FreqItemset(items=['J. Cognitive Neuroscience', 'NeuroImage'], freq=1516),
#  FreqItemset(items=['Int. J. Computer Assisted Radiology and Surgery'], freq=1912),
#  FreqItemset(items=['Int. J. Approx. Reasoning'], freq=1814),
#  FreqItemset(items=['Computer Applications in the Biosciences'], freq=1651),
#  FreqItemset(items=['ISIT'], freq=3020),
#  FreqItemset(items=['ISIT', 'IEEE Transactions on Information Theory'], freq=1518),
#  FreqItemset(items=['ISIT', 'IEEE Transactions on Information Theory', 'CoRR'], freq=1282),
#  FreqItemset(items=['ISIT', 'CoRR'], freq=2133),
#  FreqItemset(items=['ISLPED'], freq=2527),
#  FreqItemset(items=['SIBGRAPI'], freq=1259),
#  FreqItemset(items=['Robotics and Autonomous Systems'], freq=3643),
#  FreqItemset(items=['Robotics and Autonomous Systems', 'IROS'], freq=1260),
#  FreqItemset(items=['Robotics and Autonomous Systems', 'ICRA'], freq=1568),
#  FreqItemset(items=['HRI'], freq=1728),
#  FreqItemset(items=['IAS'], freq=2905),
#  FreqItemset(items=['Information and Management'], freq=1699),
#  FreqItemset(items=['ICSC'], freq=1537),
#  FreqItemset(items=['Advanced Robotics'], freq=3161),
#  FreqItemset(items=['Advanced Robotics', 'IROS'], freq=1324),
#  FreqItemset(items=['Advanced Robotics', 'ICRA'], freq=1482),
#  FreqItemset(items=['SODA'], freq=2645),
#  FreqItemset(items=['SODA', 'CoRR'], freq=1614),
#  FreqItemset(items=['Systems and Computers in Japan'], freq=3053),
#  FreqItemset(items=['J. Parallel Distrib. Comput.'], freq=5033),
#  FreqItemset(items=['J. Parallel Distrib. Comput.', 'IPDPS'], freq=1368),
#  FreqItemset(items=['FPGA'], freq=1924),
#  FreqItemset(items=['APWeb'], freq=1744),
#  FreqItemset(items=['JCP'], freq=3502),
#  FreqItemset(items=['IEEE T. Vehicular Technology'], freq=1339),
#  FreqItemset(items=['ACM Southeast Regional Conference'], freq=2124),
#  FreqItemset(items=['RAM'], freq=1305),
#  FreqItemset(items=['SIAM J. Numerical Analysis'], freq=1825),
#  FreqItemset(items=['ICPADS'], freq=3693),
#  FreqItemset(items=['Math. Meth. of OR'], freq=1666),
#  FreqItemset(items=['Future Generation Comp. Syst.'], freq=4053),
#  FreqItemset(items=['Medical Image Analysis'], freq=1983),
#  FreqItemset(items=['Softw.'], freq=4636),
#  FreqItemset(items=['Softw.', ' Pract. Exper.'], freq=4636),
#  FreqItemset(items=['International Conference on Computational Science (1)'], freq=1870),
#  FreqItemset(items=['ICLP'], freq=1235),
#  FreqItemset(items=['Machine Learning'], freq=1707),
#  FreqItemset(items=['SIGCSE'], freq=4329),
#  FreqItemset(items=['IBM Systems Journal'], freq=3193),
#  FreqItemset(items=['J. Network and Computer Applications'], freq=2038),
#  FreqItemset(items=['Technique et Science Informatiques'], freq=1274),
#  FreqItemset(items=['Electr. Notes Theor. Comput. Sci.'], freq=6163),
#  FreqItemset(items=['Electr. Notes Theor. Comput. Sci.', 'Theor. Comput. Sci.'], freq=1500),
#  FreqItemset(items=['Electr. Notes Theor. Comput. Sci.', 'CoRR'], freq=1810),
#  FreqItemset(items=['CIARP'], freq=1783),
#  FreqItemset(items=['PARCO'], freq=1372),
#  FreqItemset(items=['The Visual Computer'], freq=2926),
#  FreqItemset(items=['Personal and Ubiquitous Computing'], freq=1934),
#  FreqItemset(items=['Integration'], freq=1289),
#  FreqItemset(items=['IEEE Transactions on Communications'], freq=6614),
#  FreqItemset(items=['IEEE Transactions on Communications', 'GLOBECOM'], freq=2428),
#  FreqItemset(items=['IEEE Transactions on Communications', 'GLOBECOM', 'ICC'], freq=1775),
#  FreqItemset(items=['IEEE Transactions on Communications', 'ICC'], freq=2602),
#  FreqItemset(items=['IEEE Transactions on Communications', 'IEEE Transactions on Information Theory'], freq=1366),
#  FreqItemset(items=['IEEE Transactions on Communications', 'IEEE Transactions on Signal Processing'], freq=1439),
#  FreqItemset(items=['IEEE Transactions on Communications', 'WCNC'], freq=1267),
#  FreqItemset(items=['IEEE Transactions on Communications', 'IEEE Journal on Selected Areas in Communications'], freq=1411),
#  FreqItemset(items=['IEEE Transactions on Communications', 'CoRR'], freq=1583),
#  FreqItemset(items=['SC'], freq=4706),
#  FreqItemset(items=['CVPR (2)'], freq=1317),
#  FreqItemset(items=['WCNC'], freq=7542),
#  FreqItemset(items=['WCNC', 'GLOBECOM'], freq=3103),
#  FreqItemset(items=['WCNC', 'GLOBECOM', 'ICC'], freq=2084),
#  FreqItemset(items=['WCNC', 'ICC'], freq=2952),
#  FreqItemset(items=['WCNC', 'CoRR'], freq=1519),
#  FreqItemset(items=['PDCAT'], freq=2085),
#  FreqItemset(items=['Educational Technology & Society'], freq=2274),
#  FreqItemset(items=['ICWE'], freq=1377),
#  FreqItemset(items=['CCCG'], freq=1257),
#  FreqItemset(items=['WebNet'], freq=3583),
#  FreqItemset(items=['Int. J. Computer Integrated Manufacturing'], freq=2140),
#  FreqItemset(items=['CLUSTER'], freq=2004),
#  FreqItemset(items=['SNPD'], freq=1803),
#  FreqItemset(items=['Discrete Applied Mathematics'], freq=5711),
#  FreqItemset(items=['Discrete Applied Mathematics', 'Theor. Comput. Sci.'], freq=1473),
#  FreqItemset(items=['Discrete Applied Mathematics', 'Inf. Process. Lett.'], freq=1329),
#  FreqItemset(items=['Discrete Applied Mathematics', 'Discrete Mathematics'], freq=1875),
#  FreqItemset(items=['Discrete Applied Mathematics', 'CoRR'], freq=1557),
#  FreqItemset(items=['Environmental Modelling and Software'], freq=3855),
#  FreqItemset(items=['ARES'], freq=1843),
#  FreqItemset(items=['ICECS'], freq=2205),
#  FreqItemset(items=['ACIVS'], freq=1413),
#  FreqItemset(items=['ICEBE'], freq=1348),
#  FreqItemset(items=['Microelectronics Reliability'], freq=8982),
#  FreqItemset(items=['ICCD'], freq=4173),
#  FreqItemset(items=['IGARSS (4)'], freq=1894),
#  FreqItemset(items=['Computers & Graphics'], freq=4418),
#  FreqItemset(items=['Journal of Mathematical Imaging and Vision'], freq=1438),
#  FreqItemset(items=['IEEE Computer Graphics and Applications'], freq=2360),
#  FreqItemset(items=['ISCAS'], freq=13498),
#  FreqItemset(items=['ISCAS', 'IEICE Transactions'], freq=1356),
#  FreqItemset(items=['IJCAT'], freq=2117),
#  FreqItemset(items=['Neural Processing Letters'], freq=1358),
#  FreqItemset(items=['SAC'], freq=9624),
#  FreqItemset(items=['SAC', 'CoRR'], freq=1408),
#  FreqItemset(items=['CDC'], freq=6840),
#  FreqItemset(items=['Algorithmica'], freq=2696),
#  FreqItemset(items=['Algorithmica', 'CoRR'], freq=1331),
#  FreqItemset(items=['Communications in Statistics - Simulation and Computation'], freq=1388),
#  FreqItemset(items=['ICRA'], freq=17989),
#  FreqItemset(items=['ICPP Workshops'], freq=2378),
#  FreqItemset(items=['Wirtschaftsinformatik'], freq=2217),
#  FreqItemset(items=['ISAAC'], freq=1957),
#  FreqItemset(items=['ICDE'], freq=4872),
#  FreqItemset(items=['WISE'], freq=1484),
#  FreqItemset(items=['JCDL'], freq=2486),
#  FreqItemset(items=['IDEAL'], freq=2293),
#  FreqItemset(items=['Int. J. Intell. Syst.'], freq=1449),
#  FreqItemset(items=['HPCA'], freq=1329),
#  FreqItemset(items=['NIPS'], freq=5863),
#  FreqItemset(items=['NIPS', 'CoRR'], freq=1845),
#  FreqItemset(items=['ISCAS (1)'], freq=2610),
#  FreqItemset(items=['ICANN (1)'], freq=1552),
#  FreqItemset(items=['Computers & Industrial Engineering'], freq=2159),
#  FreqItemset(items=['ICPR'], freq=7915),
#  FreqItemset(items=['ICPR', 'ICIP'], freq=2035),
#  FreqItemset(items=['ICPR', 'Pattern Recognition'], freq=1671),
#  FreqItemset(items=['I. J. Bifurcation and Chaos'], freq=4523),
#  FreqItemset(items=['IEEE Geosci. Remote Sensing Lett.'], freq=1422),
#  FreqItemset(items=['NaBIC'], freq=1300),
#  FreqItemset(items=['Presence'], freq=2021),
#  FreqItemset(items=['IWANN'], freq=1524),
#  FreqItemset(items=['European Journal of Operational Research'], freq=11168),
#  FreqItemset(items=['CHI Extended Abstracts'], freq=7251),
#  FreqItemset(items=['JSW'], freq=2757),
#  FreqItemset(items=['IKE'], freq=1403),
#  FreqItemset(items=['Telecommunication Systems'], freq=2255),
#  FreqItemset(items=['ICME'], freq=8499),
#  FreqItemset(items=['ICME', 'ICASSP'], freq=1431),
#  FreqItemset(items=['ICME', 'ICIP'], freq=2212),
#  FreqItemset(items=['ICANN (2)'], freq=1648),
#  FreqItemset(items=['MICRO'], freq=1559),
#  FreqItemset(items=['GI Jahrestagung'], freq=3010),
#  FreqItemset(items=['ICDIM'], freq=1430),
#  FreqItemset(items=['CAV'], freq=1457),
#  FreqItemset(items=['IEEE Design & Test of Computers'], freq=2320),
#  FreqItemset(items=['Discrete & Computational Geometry'], freq=1699),
#  FreqItemset(items=['Speech Communication'], freq=3143),
#  FreqItemset(items=['Speech Communication', 'INTERSPEECH'], freq=1546),
#  FreqItemset(items=['DAGM-Symposium'], freq=2635),
#  FreqItemset(items=['Multimedia Syst.'], freq=1497),
#  FreqItemset(items=['HCI (2)'], freq=2399),
#  FreqItemset(items=['Eng. Appl. of AI'], freq=2508),
#  ...]

# %%
venue2 = FPGrowth.train(venue_train, 0.4e-3, 2)
venue_res2 = venue2.freqItemsets().collect()

# %%
venue_res2

# %% [markdown]
# With the same trend as in Problem 2, as the support threshold goes small, the frequent itemset becomes bigger and bigger, and the frequency is also increasing. And also the same out of memory error when I try to train the model with the smallest support threshold.

# %% [markdown]
# ### Part b

# %%
def findVenue(fis, name):
    l = []
    for fi in fis:
        if name in fi[0]:
            l.append(fi)
    l.sort(key=takeSecond, reverse=True)
    return l[:15]
nips = findVenue(venue_res2, 'NIPS')
kdd = findVenue(venue_res2, 'KDD')
vldb = findVenue(venue_res2, 'VLDB')
infocom = findVenue(venue_res2, 'INFOCOM')
acl = findVenue(venue_res2, 'ACL')

# %%
nips

# %% [markdown]
# Within the area of machine learning, based on NIPS, the top 10 venues that authors also publish in are CoRR, ICML, Neural Computation, Journal of Machine Learning Research - Proceedings Track, Journal of Machine Learning Research, IEEE Trans. Pattern Anal. Mach. Intell., CVPR, Neurocomputing and Neural Networks.

# %%
kdd

# %% [markdown]
# Within the area of data mining, based on KDD, the top 10 venues that authors also publish in are CoRR, ICDM, CIKM, IEEE Trans. Knowl. Data Eng., SDM, ICML, WWW.

# %%
vldb

# %% [markdown]
# Within the area of database, based on VLDB, the top 10 venues that authors also publish in are ICDE, SIGMOD Conference, CoRR, IEEE Trans. Knowl. Data Eng., SIGMOD Record, EDBT, CIKM, IEEE Data Eng. Bull., VLDB J., ACM Trans. Database Syst..

# %%
infocom

# %% [markdown]
# Within the area of computer networks, based on INFOCOM, the top 10 venues that authors also publish in are GLOBECOM, ICC, CoRR, IEEE/ACM Trans. Netw., IEEE Journal on Selected Areas in Communications, Computer Networks, Computer Communications, ICDCS, IEEE Trans. Parallel Distrib. Syst..

# %%
acl

# %% [markdown]
# Within the area of natural language processing, based on ACL, the top 10 venues that authors also publish in are COLING, LREC, CoRR, EMNLP, HLT-NAACL, INTERSPEECH.
